# %% [markdown]
# # Forecasting Brazil’s Oil Production using an ARIMA model and ANP data
# <b>Luís Eduardo Anunciado Silva</b> - BS Student in Information Technology, Federal University of Rio Grande do Norte<br>
#
# <b>Date</b>: December 5, 2018
#
# ## Introduction
# My project aims to predict the yearly oil production of a given petroleum reservoir over a given time period, using an <b>ARIMA model</b> for <b>time series forecasting</b> and the [ANP public data base](http://www.anp.gov.br/dados-estatisticos).
#
# <p>I also aim to predict the top-10 petroleum reservoir in the Brazil that which will produce the largest amount of oil in the next 10 years.</p>
#
#
# ### OBJECTIVE 1: Predicting the Oil Production of a Petroleum Reservoir across a Specified Time Period
# <p> Using the ANP public data base, we will do the following steps below:</p>
#
# <b>Pre-Processing:</b><br>
# <ol>
# <li>Build a dataframe with the columns: dt (in DateTime format), well, latitude, longitude.</li>
# <li>Dropping irrelevant columns and removing rows with NaN values</li>
# </ol>
# <b>Processing:</b><br>
# ARIMA models need the data to be stationary i.e. the data must not exhibit trend and/or seasonality. To identify and remove trend and seasonality, we used the following methods:
# <ol>
# <li>Plotting the time series to visually check for trend and seasonality</li>
# <li>Checking if the histogram of the data fits a Gaussian Curve, and then splitting data into two parts, calculating means and variances and seeing if they vary</li>
# <li>Calculating the Augmented Dickey-Fuller Test statistic and using the p-value to determine stationarity</li>
# </ol>
# If the data was not stationary, we performed <b>differencing</b> to make it stationary.
# <br><br>
# <b>Fitting the ARIMA model:</b><br>
# We performed a grid-search to estimate the best p, q values for the model, for the given data.<br>
# We then fit the ARIMA model using the calculated p, q values.
# <br><br>
# <b>Evaluation:</b><br>
# We calculated the <b>Mean Squared Error (MSE)</b> to estimate the performance of the model.

# %%
# import packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_model import ARIMA, ARMAResults
from sklearn.metrics import mean_squared_error
import ipywidgets as widgets
import plotly.plotly as py
import seaborn as sns
import folium
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.graph_objs as go
from os import walk
from unicodedata import normalize
init_notebook_mode(connected=True)

# hide warnings
import warnings
warnings.simplefilter("ignore")
# Out:
# <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script><script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window._Plotly) {require(['plotly'],function(plotly) {window._Plotly=plotly;});}</script>

# %%
#read file with the weels
dfs = pd.read_excel('../data/table_of_wells_april_2018.xlsx', sheet_name='Plan1')
dfs = dfs.drop({'CADASTRO', 'OPERADOR', 'POCO_OPERADOR', 'ESTADO', 'BACIA', 'BLOCO', 'SIG_CAMPO', 'CAMPO', 'TERRA_MAR', 
                'POCO_POS_ANP', 'INICIO', 'TERMINO', 'CONCLUSAO', 'TITULARIDADE', 'LATITUDE_BASE_4C', 
                'LONGITUDE_BASE_4C', 'DATUM_HORIZONTAL', 'TIPO_DE_COORDENADA_DE_BASE', 'DIRECAO', 'PROFUNDIDADE_VERTICAL_M',
                'PROFUNDIDADE_SONDADOR_M','PROFUNDIDADE_MEDIDA_M', 'REFERENCIA_DE_PROFUNDIDADE', 'MESA_ROTATIVA', 
                'COTA_ALTIMETRICA_M','LAMINA_D_AGUA_M', 'DATUM_VERTICAL', 'UNIDADE_ESTRATIGRAFICA', 'GEOLOGIA_GRUPO_FINAL',
                'GEOLOGIA_FORMACAO_FINAL', 'GEOLOGIA_MEMBRO_FINAL', 'CDPE', 'AGP', 'PC', 'PAG', 'PERFIS_CONVENCIONAIS',
                'DURANTE_PERFURACAO', 'PERFIS_DIGITAIS', 'PERFIS_PROCESSADOS', 'PERFIS_ESPECIAIS', 'AMOSTRA_LATERAL', 
                'SISMICA', 'TABELA_TEMPO_PROFUNDIDADE', 'DADOS_DIRECIONAIS', 'TESTE_A_CABO', 'CANHONEIO', 'TESTEMUNHO', 
                'GEOQUIMICA', 'SIG_SONDA', 'NOM_SONDA', 'DHA_ATUALIZACAO'}, 1)

# %%
def get_produtors(dfs):
    '''
    Filters producting wells in a field
    '''
    productor = dfs[(dfs['TIPO']==u'Explotatório') & 
                    (dfs['SITUACAO']=='PRODUZINDO') & 
                    (dfs['CATEGORIA']=='Desenvolvimento') & 
                    (dfs['RECLASSIFICACAO']==u'PRODUTOR COMERCIAL DE PETRÓLEO')]
    productor.reset_index(inplace=True)
    return productor

# %%
def get_injections(dfs):
    '''
    Filters the injection wells in a field
    '''
    injector = dfs[(dfs['TIPO']==u'Explotatório') & 
                   (dfs['SITUACAO']=='INJETANDO') &
                   (dfs['CATEGORIA']==u'Injeção') & 
                   (dfs['RECLASSIFICACAO']==u'INJEÇÃO DE ÁGUA')]
    injector.reset_index(inplace=True)
    return injector

# %%
produtor = get_produtors(dfs)
injetor = get_injections(dfs)
pai = pd.concat([produtor, injetor])
pai.reset_index(inplace=True)
pai = pai.drop({'level_0', 'index'}, 1)

# %%
pocos = pai["POCO"].tolist()
pocos = [poco.lower().replace(' ', '').replace('-', '') for poco in pocos]
pocos[:5]
# Out:
# ['7sz514se', '7mll44hprjs', '7fp398rn', '7fp375rn', '7fp376rn']

# %%
files = []
for (dirpath, dirnames, filenames) in walk('../data/production-by-well'):
    for filename in filenames:
        if filename.endswith('.xls') or filename.endswith('.xlsx'):
            files.append('%s/%s' % (dirpath, filename))

wells = []
for file in sorted(files):
    excel_file = pd.read_excel(file)
    initial_column = excel_file.columns[0]

    period_value = None
    well_data = None
    production_data = None
    try:
        if initial_column.startswith('ANP - Agência Nacional do Petroleo'):
            data = pd.read_excel(file, skiprows=4, header=[0, 1], index_col=None)

            period = data.xs('Período', axis=1, level=0, drop_level=True).iloc[:, 0]
            period = period.dropna().unique()
            period = period[0].replace('/', '-')

            production_col = None
            field_col = None
            for column in data.columns:
                if column[0].startswith('Petróleo (bbl/dia)'):
                    production_col = column
                if column[0].startswith('Campo'):
                    field_col = column
            selected_data = data[[('Nome Poço', 'ANP'), field_col, production_col]]

            period_value = period
            well_data = selected_data[('Nome Poço', 'ANP')].values
            field_data = selected_data[field_col].values
            production_data = selected_data[production_col].values

        elif initial_column.startswith('COD_POCO') or initial_column.startswith('NOM_POCO_ANP'):
            data = pd.read_excel(file)

            period = data['PERIODO'].dropna().unique()
            period = period[0].replace('_', '-')

            selected_data = data[['NOM_POCO_ANP', 'NOM_CAMPO', 'OLEO_BBL_DIA']]

            well_data = pd.DataFrame(columns=['well', 'production_%s' % period])

            period_value = period
            well_data = data['NOM_POCO_ANP'].values
            field_data = data['NOM_CAMPO'].values
            production_data = data['OLEO_BBL_DIA'].values

    except Exception as exc:
        print('********** Exception **********', exc)

    well_df = pd.DataFrame(columns=['well', 'field', '%s-01' % period])
    well_df['well'] = well_data
    well_df['field'] = field_data
    well_df['%s-01' % period] = pd.to_numeric(production_data)

    # Remove nan in well index.
    well_df = well_df.drop(well_df.loc[well_df.well.isnull()].index, axis=0)
    # Remove nan in field index.
    well_df = well_df.drop(well_df.loc[well_df.field.isnull()].index, axis=0)
    # Remove description index.
    well_df = well_df.drop(well_df.loc[well_df.well.map(len) > 50].index, axis=0)

    well_df.well = well_df.well.map(str.strip)
    well_df.well = well_df.well.map(str.lower)
    well_df.field = well_df.field.map(str.strip)
    well_df.field = well_df.field.map(str.lower)

    def normalize_str(input_str):
        return normalize('NFKD', input_str).encode('ascii', 'ignore').decode('utf-8')
    well_df.well = well_df.well.map(normalize_str)
    well_df.field = well_df.field.map(normalize_str)

    def replace_str(input_str):
        return input_str.replace(' ', '').replace('-', '')
    well_df.well = well_df.well.map(replace_str)
    well_df.field = well_df.field.map(replace_str)
    
    well_df = well_df.dropna()
    well_df['index'] = well_df.apply(lambda row: '%s' % (row['well']), axis=1)

    well_df = well_df.drop('well', axis=1)
    well_df = well_df.drop('field', axis=1)
    well_df = well_df.set_index('index')

    well_df = well_df[~well_df.index.duplicated(keep='first')]
    
    wells.append(well_df) 

salt_df = pd.concat(wells, axis=1)
salt_df
# Out:
#                2016-01-01  2016-02-01  2016-03-01  2016-04-01  2016-05-01  \
# 1brsa108aess          NaN         NaN         NaN         NaN         NaN
# 1brsa1116rjs          NaN         NaN         NaN         NaN         NaN
# 1brsa1146rjs          NaN         NaN         NaN         NaN         NaN
# 1brsa594sps           NaN         NaN         NaN         NaN         NaN
# 1brsa976rjs           NaN   4038.4289         NaN         NaN  16793.2997
# 2anp1rjs              NaN         NaN         NaN         NaN         NaN
# 3brsa1017drjs   3217.8084    940.7094   1039.1168   1645.0457   1578.5540
# 3brsa1053rjs    3444.0484  13159.8767     20.1903         NaN   3389.5847
# 3brsa1054drjs   3089.7979   3020.2906   3049.9899    408.6213         NaN
# 3brsa1064rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1132rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1172rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1184rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1201rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1215rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1243rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1305arjs         NaN         NaN         NaN         NaN         NaN
# 3brsa1350rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa496rjs    21806.3831  21900.5478  22259.9048  10113.8224  18571.4009
# 3brsa788sps    25972.5761  20186.7470  15274.7232  21989.9431  17651.8362
# 3brsa821rjs           NaN         NaN   2012.6820         NaN   4352.8143
# 3brsa830rjs           NaN         NaN         NaN         NaN  11202.3624
# 3brsa839arjs          NaN         NaN         NaN         NaN         NaN
# 3brsa854rjs           NaN         NaN         NaN         NaN         NaN
# 3brsa861sps           NaN         NaN         NaN         NaN         NaN
# 3brsa865arjs          NaN         NaN         NaN         NaN         NaN
# 3brsa883rjs           NaN         NaN         NaN         NaN         NaN
# 3li0001rjs            NaN         NaN         NaN         NaN         NaN
# 3pm0002rjs            NaN         NaN         NaN         NaN         NaN
# 3pm0003arjs           NaN         NaN         NaN         NaN         NaN
# ...                   ...         ...         ...         ...         ...
# 8ll81drjs             NaN         NaN         NaN    367.8763         NaN
# 8ll87drjs             NaN         NaN         NaN         NaN         NaN
# 8lpa2dsps             NaN         NaN         NaN         NaN         NaN
# 8srr1arjs             NaN         NaN         NaN         NaN         NaN
# 9atp1rjs         412.9565    395.4946         NaN         NaN         NaN
# 9atp3rjs              NaN         NaN         NaN         NaN         NaN
# 9bbg1drjs             NaN         NaN         NaN         NaN         NaN
# 9brsa1191rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1192sps          NaN         NaN         NaN         NaN         NaN
# 9brsa1197rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1212rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1254rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1284rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa716rjs    22103.1498  22207.9325  22361.7354  12456.0433  14567.2424
# 9brsa908drjs   13856.5582  13533.3875  13417.0412   8202.8515  13082.2245
# 9brsa928sps     6484.2449  10367.1932  24688.8344   2116.2395  14485.2884
# 9buz1rjs              NaN         NaN         NaN         NaN         NaN
# 9buz2rjs              NaN         NaN         NaN         NaN         NaN
# 9buz3rjs              NaN         NaN         NaN         NaN         NaN
# 9buz4rjs              NaN         NaN         NaN         NaN         NaN
# 9buz7rjs              NaN         NaN         NaN         NaN         NaN
# 9buz8rjs              NaN         NaN         NaN         NaN         NaN
# 9ll12drjs             NaN  24150.7969  32948.5508  32196.6184  33494.9688
# 9ll19rjs       25174.7099  23005.6134   7030.1326   9255.1860  17353.1954
# 9ll20drjs      27981.0206  22378.0029  26645.4111  30788.5424  20002.4287
# 9ll2rjs        28186.6944  33315.4448  29282.1853  31070.9978  30334.7783
# 9ll6arjs       24746.3310  20402.5434  22622.2979  29061.8352  16222.2626
# 9ll7rjs               NaN         NaN         NaN         NaN         NaN
# 9mrl231darjs          NaN         NaN         NaN         NaN         NaN
# 9sep1rjs              NaN         NaN         NaN         NaN         NaN
#
#                2016-06-01  2016-07-01  2016-08-01  2016-09-01  2016-10-01  \
# 1brsa108aess          NaN         NaN         NaN         NaN      0.0000
# 1brsa1116rjs          NaN         NaN    222.1723         NaN      0.0000
# 1brsa1146rjs          NaN         NaN         NaN         NaN      0.0000
# 1brsa594sps           NaN         NaN         NaN         NaN      0.0000
# 1brsa976rjs    19357.6807  17324.6283  19303.0414    421.0546      0.0000
# 2anp1rjs              NaN         NaN         NaN         NaN      0.0000
# 3brsa1017drjs   1555.8059   1554.5046   1668.1607   1594.7409   1728.0598
# 3brsa1053rjs          NaN         NaN         NaN         NaN      0.0000
# 3brsa1054drjs         NaN         NaN         NaN         NaN      0.0000
# 3brsa1064rjs          NaN         NaN         NaN         NaN      0.0000
# 3brsa1132rjs          NaN         NaN         NaN         NaN      0.0000
# 3brsa1172rjs          NaN         NaN         NaN         NaN      0.0000
# 3brsa1184rjs          NaN         NaN         NaN         NaN      0.0000
# 3brsa1201rjs          NaN         NaN         NaN         NaN      0.0000
# 3brsa1215rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1243rjs          NaN         NaN         NaN         NaN      0.0000
# 3brsa1305arjs         NaN         NaN         NaN         NaN         NaN
# 3brsa1350rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa496rjs    21956.2511  22511.5325  20002.4388  21239.8556  15338.7192
# 3brsa788sps    13338.3866  20088.7421  20518.7056  24938.9971  23737.4376
# 3brsa821rjs    11347.9087   2481.2793  13555.1659  14471.0598   9567.5976
# 3brsa830rjs    15316.2205  16289.3414  18387.9566  20330.7717   9219.2716
# 3brsa839arjs          NaN         NaN         NaN         NaN         NaN
# 3brsa854rjs           NaN         NaN         NaN         NaN      0.0000
# 3brsa861sps           NaN         NaN      0.0000      0.0000      0.0000
# 3brsa865arjs          NaN         NaN         NaN         NaN         NaN
# 3brsa883rjs           NaN         NaN         NaN         NaN         NaN
# 3li0001rjs            NaN         NaN         NaN         NaN      0.0000
# 3pm0002rjs            NaN         NaN         NaN         NaN      0.0000
# 3pm0003arjs           NaN         NaN         NaN         NaN      0.0000
# ...                   ...         ...         ...         ...         ...
# 8ll81drjs             NaN  22291.1374  30106.2709  30238.1966  29048.3255
# 8ll87drjs             NaN         NaN         NaN         NaN         NaN
# 8lpa2dsps             NaN         NaN         NaN         NaN         NaN
# 8srr1arjs             NaN         NaN         NaN         NaN         NaN
# 9atp1rjs              NaN         NaN         NaN         NaN         NaN
# 9atp3rjs              NaN         NaN         NaN         NaN         NaN
# 9bbg1drjs             NaN         NaN         NaN         NaN         NaN
# 9brsa1191rjs          NaN         NaN         NaN         NaN      0.0000
# 9brsa1192sps          NaN         NaN         NaN         NaN         NaN
# 9brsa1197rjs          NaN         NaN         NaN         NaN      0.0000
# 9brsa1212rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1254rjs          NaN         NaN         NaN         NaN      0.0000
# 9brsa1284rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa716rjs     9401.5409  15153.1996  13150.3592  13689.8673   6158.8184
# 9brsa908drjs   13146.4325  13195.8227  13082.7589  12874.5697  10880.6705
# 9brsa928sps    22314.0839  27081.4678  22586.5081  22128.8557  23042.3809
# 9buz1rjs              NaN         NaN         NaN         NaN      0.0000
# 9buz2rjs              NaN         NaN         NaN         NaN      0.0000
# 9buz3rjs              NaN         NaN         NaN         NaN      0.0000
# 9buz4rjs              NaN   3759.2165  15098.0802  13195.5643  14071.0070
# 9buz7rjs              NaN         NaN         NaN         NaN         NaN
# 9buz8rjs              NaN         NaN         NaN         NaN         NaN
# 9ll12drjs      33015.3630  33048.6822  27500.6023  30051.4519  30394.3221
# 9ll19rjs        9670.4214  16278.5025         NaN  15932.2978  24999.0383
# 9ll20drjs      28179.6468  25707.6662  16705.1910  28589.3346  28668.0316
# 9ll2rjs        34322.7501  32292.9629  32333.3934  28995.9882  29146.6555
# 9ll6arjs       20648.8869  17332.8491  15499.6369  27829.5765  28915.3956
# 9ll7rjs               NaN         NaN         NaN         NaN  20663.9268
# 9mrl231darjs          NaN         NaN         NaN         NaN         NaN
# 9sep1rjs              NaN         NaN         NaN         NaN      0.0000
#
#                   ...      2017-12-01  2018-01-01  2018-02-01  2018-03-01  \
# 1brsa108aess      ...             NaN         NaN         NaN         NaN
# 1brsa1116rjs      ...       3033.0093         NaN         NaN         NaN
# 1brsa1146rjs      ...             NaN         NaN         NaN         NaN
# 1brsa594sps       ...             NaN         NaN         NaN         NaN
# 1brsa976rjs       ...             NaN         NaN         NaN         NaN
# 2anp1rjs          ...             NaN         NaN         NaN         NaN
# 3brsa1017drjs     ...       2858.4587   3107.4003   3024.9240   2992.8340
# 3brsa1053rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1054drjs     ...             NaN         NaN         NaN         NaN
# 3brsa1064rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1132rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1172rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1184rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1201rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1215rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1243rjs      ...             NaN         NaN         NaN         NaN
# 3brsa1305arjs     ...      10698.2748  13565.2473  16317.7729  25573.9250
# 3brsa1350rjs      ...             NaN         NaN         NaN         NaN
# 3brsa496rjs       ...      12310.9461  17644.5019  19575.6865  19839.9511
# 3brsa788sps       ...      21639.3270  21270.4296  22947.5755  22012.1845
# 3brsa821rjs       ...             NaN         NaN   1039.7364         NaN
# 3brsa830rjs       ...       6611.7629  13024.3930  13308.0096  10887.4580
# 3brsa839arjs      ...      22013.2643  21385.6117  22637.8695  13067.2893
# 3brsa854rjs       ...             NaN         NaN         NaN         NaN
# 3brsa861sps       ...             NaN         NaN         NaN         NaN
# 3brsa865arjs      ...      19532.3666  18739.6801  17245.4199  17271.5823
# 3brsa883rjs       ...       6001.4415  13722.6747  14830.7657   3408.9104
# 3li0001rjs        ...             NaN         NaN         NaN         NaN
# 3pm0002rjs        ...             NaN         NaN         NaN         NaN
# 3pm0003arjs       ...             NaN         NaN         NaN         NaN
# ...               ...             ...         ...         ...         ...
# 8ll81drjs         ...      28713.7950  28103.4818  29571.5705  29066.8208
# 8ll87drjs         ...      25866.9739  28182.8523  33249.1707  30035.0603
# 8lpa2dsps         ...      16159.4984  15372.4422  15667.2990  16418.9444
# 8srr1arjs         ...             NaN         NaN         NaN         NaN
# 9atp1rjs          ...             NaN         NaN         NaN         NaN
# 9atp3rjs          ...             NaN         NaN         NaN         NaN
# 9bbg1drjs         ...             NaN         NaN         NaN         NaN
# 9brsa1191rjs      ...             NaN         NaN         NaN         NaN
# 9brsa1192sps      ...             NaN         NaN         NaN         NaN
# 9brsa1197rjs      ...             NaN         NaN         NaN         NaN
# 9brsa1212rjs      ...             NaN         NaN  12536.8313  16835.6686
# 9brsa1254rjs      ...             NaN         NaN         NaN         NaN
# 9brsa1284rjs      ...             NaN         NaN         NaN         NaN
# 9brsa716rjs       ...             NaN         NaN         NaN         NaN
# 9brsa908drjs      ...      15257.5456  13800.0921  13063.5528   8969.5635
# 9brsa928sps       ...      24766.3393  24759.1880  25459.3679  24854.0247
# 9buz1rjs          ...             NaN         NaN         NaN         NaN
# 9buz2rjs          ...             NaN         NaN         NaN         NaN
# 9buz3rjs          ...             NaN         NaN         NaN         NaN
# 9buz4rjs          ...             NaN         NaN         NaN         NaN
# 9buz7rjs          ...             NaN         NaN         NaN         NaN
# 9buz8rjs          ...             NaN         NaN         NaN         NaN
# 9ll12drjs         ...      26011.9838  27709.8527  26068.4927  21892.0467
# 9ll19rjs          ...      23640.3462  24716.9728  21604.8484  22121.5773
# 9ll20drjs         ...      26340.0114  27673.1042  28382.5365  27244.6381
# 9ll2rjs           ...      16614.6066  19425.7146  20662.3071  21777.7290
# 9ll6arjs          ...             NaN         NaN         NaN         NaN
# 9ll7rjs           ...      25477.6935  24427.0231  25898.1806  25007.3577
# 9mrl231darjs      ...             NaN    295.9543         NaN         NaN
# 9sep1rjs          ...             NaN         NaN         NaN         NaN
#
#                2018-04-01  2018-05-01  2018-06-01  2018-07-01  2018-08-01  \
# 1brsa108aess          NaN         NaN         NaN         NaN         NaN
# 1brsa1116rjs          NaN         NaN         NaN         NaN         NaN
# 1brsa1146rjs          NaN         NaN         NaN         NaN         NaN
# 1brsa594sps           NaN         NaN         NaN         NaN         NaN
# 1brsa976rjs           NaN         NaN         NaN         NaN         NaN
# 2anp1rjs              NaN         NaN         NaN         NaN         NaN
# 3brsa1017drjs   1745.1677    586.4773    711.2949    693.0370    504.9356
# 3brsa1053rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1054drjs         NaN         NaN         NaN         NaN         NaN
# 3brsa1064rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1132rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1172rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1184rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1201rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1215rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1243rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa1305arjs  36085.0088  39918.0538  40975.2165  38846.0388  38577.1779
# 3brsa1350rjs          NaN         NaN         NaN         NaN         NaN
# 3brsa496rjs    23429.9532  22949.3915  19201.1114  18361.9418   8779.3012
# 3brsa788sps    22799.8014  22446.9169  20288.2610  22026.1444  22940.4320
# 3brsa821rjs      802.7104         NaN   6425.4644  10911.4175  11128.9070
# 3brsa830rjs    13804.0623  17785.6288   9968.7335   9785.9828         NaN
# 3brsa839arjs   24361.8760  20224.5773  21094.7851  21319.0462  22895.9576
# 3brsa854rjs           NaN         NaN         NaN         NaN         NaN
# 3brsa861sps           NaN         NaN         NaN         NaN         NaN
# 3brsa865arjs   17171.4966  16427.3555  16348.0217   6990.5675         NaN
# 3brsa883rjs    20257.4403  20945.1907  20134.6714  21921.5043  17734.7075
# 3li0001rjs            NaN         NaN         NaN         NaN         NaN
# 3pm0002rjs            NaN         NaN         NaN         NaN         NaN
# 3pm0003arjs           NaN         NaN         NaN         NaN         NaN
# ...                   ...         ...         ...         ...         ...
# 8ll81drjs      29012.8900  23192.7185  27678.4745  29070.6292  26508.6157
# 8ll87drjs      32568.6917  33990.6955  33712.1519  33488.4008  26807.2159
# 8lpa2dsps      16836.2929  16365.4891  17230.0959  17404.3527  17319.0202
# 8srr1arjs             NaN         NaN         NaN         NaN         NaN
# 9atp1rjs              NaN         NaN         NaN         NaN         NaN
# 9atp3rjs              NaN         NaN         NaN         NaN         NaN
# 9bbg1drjs             NaN         NaN         NaN         NaN         NaN
# 9brsa1191rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1192sps          NaN         NaN         NaN         NaN         NaN
# 9brsa1197rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1212rjs   16303.9633  16250.4201  16109.0987   9332.5117   1595.7836
# 9brsa1254rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa1284rjs          NaN         NaN         NaN         NaN         NaN
# 9brsa716rjs           NaN         NaN         NaN         NaN      0.7436
# 9brsa908drjs   12851.1737  13756.1606   7102.2727   6680.0087   4731.2235
# 9brsa928sps    12323.0419  24126.2471  25250.3097  22351.3773  13561.8593
# 9buz1rjs              NaN         NaN         NaN         NaN         NaN
# 9buz2rjs              NaN         NaN         NaN         NaN         NaN
# 9buz3rjs              NaN         NaN         NaN         NaN         NaN
# 9buz4rjs              NaN         NaN         NaN         NaN         NaN
# 9buz7rjs       10021.0972  31289.2016  32587.5664  29859.1118  24302.8012
# 9buz8rjs              NaN         NaN         NaN         NaN         NaN
# 9ll12drjs             NaN   4214.0613  10051.2931  18559.7068  24237.9594
# 9ll19rjs       22905.7604  23914.3750    174.1973         NaN         NaN
# 9ll20drjs      17736.4786  27492.6855  27706.4638  28773.2396  28775.1491
# 9ll2rjs        22109.4912  27928.3609  24858.2009  17535.5583  23610.1937
# 9ll6arjs              NaN         NaN         NaN         NaN         NaN
# 9ll7rjs        25219.2997  20450.6119  25317.9550  24528.6581  23660.0620
# 9mrl231darjs          NaN         NaN         NaN         NaN         NaN
# 9sep1rjs              NaN         NaN         NaN         NaN         NaN
#
#                2018-09-01
# 1brsa108aess          NaN
# 1brsa1116rjs          NaN
# 1brsa1146rjs          NaN
# 1brsa594sps           NaN
# 1brsa976rjs           NaN
# 2anp1rjs              NaN
# 3brsa1017drjs    683.4728
# 3brsa1053rjs          NaN
# 3brsa1054drjs         NaN
# 3brsa1064rjs          NaN
# 3brsa1132rjs          NaN
# 3brsa1172rjs          NaN
# 3brsa1184rjs          NaN
# 3brsa1201rjs          NaN
# 3brsa1215rjs          NaN
# 3brsa1243rjs          NaN
# 3brsa1305arjs  42678.7780
# 3brsa1350rjs          NaN
# 3brsa496rjs    22946.0829
# 3brsa788sps    23284.0363
# 3brsa821rjs    11193.3631
# 3brsa830rjs           NaN
# 3brsa839arjs   22733.3135
# 3brsa854rjs           NaN
# 3brsa861sps           NaN
# 3brsa865arjs          NaN
# 3brsa883rjs    17550.5640
# 3li0001rjs            NaN
# 3pm0002rjs            NaN
# 3pm0003arjs           NaN
# ...                   ...
# 8ll81drjs      28208.3948
# 8ll87drjs      31081.9306
# 8lpa2dsps      16695.4327
# 8srr1arjs             NaN
# 9atp1rjs              NaN
# 9atp3rjs              NaN
# 9bbg1drjs             NaN
# 9brsa1191rjs    4202.5766
# 9brsa1192sps          NaN
# 9brsa1197rjs          NaN
# 9brsa1212rjs          NaN
# 9brsa1254rjs          NaN
# 9brsa1284rjs          NaN
# 9brsa716rjs        2.2983
# 9brsa908drjs   13775.5785
# 9brsa928sps    16127.5915
# 9buz1rjs              NaN
# 9buz2rjs              NaN
# 9buz3rjs              NaN
# 9buz4rjs              NaN
# 9buz7rjs       30457.0734
# 9buz8rjs              NaN
# 9ll12drjs      31943.6618
# 9ll19rjs              NaN
# 9ll20drjs      21990.2310
# 9ll2rjs        26473.6820
# 9ll6arjs              NaN
# 9ll7rjs        24515.5681
# 9mrl231darjs          NaN
# 9sep1rjs              NaN
#
# [162 rows x 33 columns]

# %%
salt_df = salt_df.dropna()
salt_df
# Out:
#                2016-01-01  2016-02-01  2016-03-01  2016-04-01  2016-05-01  \
# 3brsa1017drjs   3217.8084    940.7094   1039.1168   1645.0457   1578.5540
# 3brsa788sps    25972.5761  20186.7470  15274.7232  21989.9431  17651.8362
# 6brsa631dbess  11377.5464   9830.6405  11525.5785  11252.9703  10194.6965
# 6brsa639ess    12840.5254  13698.7173   6923.1440  11459.4734  14967.2727
# 6brsa770drjs    2548.5201   1317.2642   1243.5922   2553.1378   2270.7188
# 6brsa817rjs    10071.3264   5741.2661   2265.7072   7852.9972   7183.5502
# 7baz3ess        4436.5189   3932.1075   3545.5746   6654.6156   6656.9308
# 7baz4ess       13205.9806  12422.1362  13260.7853  11857.5913  11585.3274
# 7baz8ess       11565.2467  15968.1131  13316.0419  13989.9581  13928.7149
# 7bfr12paess     6904.9319  10920.7156   9817.0115   9786.5999  10603.5989
# 7bfr7ess       10427.8930  14848.8533  14946.7701  15298.1904  15755.1229
# 7br69darjs       416.6289   6722.3120    409.3393    402.8069    402.4600
# 7crt49rjs        222.5762   5609.7281    159.3199    147.7115    295.4263
# 7jub34hess     32832.2391  31506.7820  32962.5181  32543.4753  32331.6723
# 7jub57dpaess    9979.3837  21697.3535  21136.5981  22984.1059  19688.3748
# 7jub58dpaess   13034.3217  20198.5909  20024.2243  20660.5146  20461.0486
# 7ll17drjs      18624.3930  24371.8428  16216.8114    266.6806  10227.1349
# 7ll22drjs      22597.8179  26208.9956  23475.8633   3733.1733  26561.9756
# 7ll27rjs       21191.2324  26818.7257  31630.9052  35488.4094  33069.2227
# 7ll28drjs      25939.2690  30481.8106  24374.2425  13920.8561  30111.6071
# 7ll31drjs      26750.2004  31350.6913  28403.5181  20708.0608  28650.9899
# 7ll3drjs       28103.3595  27993.5108  28111.8675  16280.9533  25167.6004
# 7mll72rjs       7546.0384   4775.4660   4008.2817   8097.7308   8109.9041
# 7mll73drjs     13278.5439   8195.9766  10247.6167  12583.8052  12545.8309
# 7sph1sps       31632.0975  33144.6429  33073.5785  30788.5007  33059.5926
# 7sph4dsps      23913.5407  28708.4262  28117.7215  27403.4507  19472.3696
# 7sph5sps       32821.8195  32120.1272  31926.4937  31334.5799  24365.0314
# 7sph7dsps      34089.8766  26642.0204  31535.7161  30954.0074  27612.9590
# 8jub39ess       5144.4668   9265.9737   8217.4623   9930.3191  10092.9507
# 9brsa908drjs   13856.5582  13533.3875  13417.0412   8202.8515  13082.2245
# 9brsa928sps     6484.2449  10367.1932  24688.8344   2116.2395  14485.2884
# 9ll20drjs      27981.0206  22378.0029  26645.4111  30788.5424  20002.4287
# 9ll2rjs        28186.6944  33315.4448  29282.1853  31070.9978  30334.7783
#
#                2016-06-01  2016-07-01  2016-08-01  2016-09-01  2016-10-01  \
# 3brsa1017drjs   1555.8059   1554.5046   1668.1607   1594.7409   1728.0598
# 3brsa788sps    13338.3866  20088.7421  20518.7056  24938.9971  23737.4376
# 6brsa631dbess   9691.8418  10830.6777  10147.0370   9488.7183   7226.1576
# 6brsa639ess    15687.5893  15587.3412  15591.7735  16179.1288  12238.6981
# 6brsa770drjs    2293.4372   2190.9819   2152.0535   2403.0289   2369.1957
# 6brsa817rjs     6947.5342   7040.0778   7880.5508   7886.8521   7001.7345
# 7baz3ess        6356.0224   6686.1739   6961.0573   6930.3781   4438.9393
# 7baz4ess        8634.8178   8341.2224   8474.0640   7617.2515   8213.5827
# 7baz8ess       14134.6646  14976.4306  14464.4920  15049.7670  13817.5630
# 7bfr12paess     5327.9779  11410.5628  11790.0080   6648.0652  10097.7304
# 7bfr7ess       15347.3488  15669.5999  15864.4907  17190.3512  16364.8021
# 7br69darjs       368.4746    357.0782    933.7034    925.1628    867.0567
# 7crt49rjs        291.8579    234.2117    639.6202    604.6625    661.7191
# 7jub34hess     32475.8841  33899.1168  33403.7694  32934.5796  26404.2728
# 7jub57dpaess   17217.3099  18357.2463  18636.5555  11689.1169  17481.4883
# 7jub58dpaess   20094.6745  21059.3363  22271.0435  17683.1477  19105.3825
# 7ll17drjs      11827.1591   9386.7753  22522.0850  23227.9033  22977.7606
# 7ll22drjs      27812.5108  20488.3348  27729.0951   9569.5482  15397.9830
# 7ll27rjs       32921.4834  31539.6858  32354.3342  30072.8970  29014.4058
# 7ll28drjs      30118.4900  28167.7417  31272.3088  31486.9482  23430.8879
# 7ll31drjs      28752.1508  32169.0874  30903.8105  30412.7633  29218.2084
# 7ll3drjs       22822.7343  24019.9036  23979.9384  26380.9547  23056.6024
# 7mll72rjs       7259.6207   7587.9901   8114.6511   7045.4514   4767.8373
# 7mll73drjs     12130.0795  11371.2471   8724.1645   8321.3803   8698.1492
# 7sph1sps       33027.9565  32595.2417  32139.4745  32231.9877  31973.8001
# 7sph4dsps      17084.9092  16684.3666  16111.1038  14396.8059  17557.5631
# 7sph5sps       20810.2274  16226.0256  21957.4526  24423.2798  21203.4772
# 7sph7dsps      30332.4901  30144.2991  28425.2912  33761.8209  31910.9807
# 8jub39ess      10039.6413  10224.8257  10503.4921   6859.5041   9992.4241
# 9brsa908drjs   13146.4325  13195.8227  13082.7589  12874.5697  10880.6705
# 9brsa928sps    22314.0839  27081.4678  22586.5081  22128.8557  23042.3809
# 9ll20drjs      28179.6468  25707.6662  16705.1910  28589.3346  28668.0316
# 9ll2rjs        34322.7501  32292.9629  32333.3934  28995.9882  29146.6555
#
#                   ...      2017-12-01  2018-01-01  2018-02-01  2018-03-01  \
# 3brsa1017drjs     ...       2858.4587   3107.4003   3024.9240   2992.8340
# 3brsa788sps       ...      21639.3270  21270.4296  22947.5755  22012.1845
# 6brsa631dbess     ...       6179.8248   5925.8579   6300.2255   6113.9548
# 6brsa639ess       ...      11638.5861   5917.6150   8114.1213  11324.5832
# 6brsa770drjs      ...       1505.3334   1995.8836   1685.7797   2068.7798
# 6brsa817rjs       ...       2875.6693   3860.5117   3268.9666   3679.1960
# 7baz3ess          ...       5706.8347   5284.8832   6071.7571   5096.8349
# 7baz4ess          ...       9561.7085   9057.5238   9665.1620   9832.4215
# 7baz8ess          ...      12195.3471  12989.3536  12784.2509  12869.2465
# 7bfr12paess       ...      17200.4754  16923.3518  15117.7230  15146.1041
# 7bfr7ess          ...      18334.4244  18945.6057  19165.9588  19856.6435
# 7br69darjs        ...       2925.2635   3906.8194   4298.0725    878.7360
# 7crt49rjs         ...       2531.7375   2519.2997   2498.7943    491.5111
# 7jub34hess        ...      19650.8269  19261.4605  20988.4567  22594.7926
# 7jub57dpaess      ...      16357.5812  13320.1218  11152.0092  13723.9775
# 7jub58dpaess      ...      20014.3418  20875.6856  21292.4131  18968.7473
# 7ll17drjs         ...      17874.3942  18008.7630  16658.4854  15587.3601
# 7ll22drjs         ...      25066.1100  26411.9581  25747.8231  22931.9787
# 7ll27rjs          ...      16126.9803  21024.1663  21742.6898  23172.1586
# 7ll28drjs         ...      21405.6612  11337.2797  21982.3482  20780.6742
# 7ll31drjs         ...      16732.7927  20043.8150  16970.6745  18964.0251
# 7ll3drjs          ...      18896.4944  17950.9276  10327.4320   4685.4312
# 7mll72rjs         ...       2967.5261   3743.8116   3806.2504   3723.6868
# 7mll73drjs        ...      10309.8550  10071.1247   9906.4043   9585.6867
# 7sph1sps          ...      28470.2319  28546.9497  29473.5483  28498.8199
# 7sph4dsps         ...      24232.7171  24261.3534  24836.0707  23917.0707
# 7sph5sps          ...      21395.1036  18462.8453  16149.8682  15141.1540
# 7sph7dsps         ...      27781.2487  26597.2931  27797.1913  28136.3860
# 8jub39ess         ...       9593.6214   9506.2573   9477.9357  10075.7962
# 9brsa908drjs      ...      15257.5456  13800.0921  13063.5528   8969.5635
# 9brsa928sps       ...      24766.3393  24759.1880  25459.3679  24854.0247
# 9ll20drjs         ...      26340.0114  27673.1042  28382.5365  27244.6381
# 9ll2rjs           ...      16614.6066  19425.7146  20662.3071  21777.7290
#
#                2018-04-01  2018-05-01  2018-06-01  2018-07-01  2018-08-01  \
# 3brsa1017drjs   1745.1677    586.4773    711.2949    693.0370    504.9356
# 3brsa788sps    22799.8014  22446.9169  20288.2610  22026.1444  22940.4320
# 6brsa631dbess   5842.4557   5529.0528   5470.2150   5445.7731   5263.9521
# 6brsa639ess    16975.9332  12241.8682  16080.7081  14592.7155  14211.6577
# 6brsa770drjs    2092.2242   2017.6544    579.5952   1303.8523     19.6171
# 6brsa817rjs     3296.0745   1766.4816   1917.6041   1997.3022   2213.7713
# 7baz3ess        5142.2157   5008.0952   4648.3296   4381.7633   4248.7153
# 7baz4ess        9562.7825   8581.2631   8211.7606   8287.8351   8073.9452
# 7baz8ess       12087.2298  12583.4923  10951.7532  12798.2203  13912.1526
# 7bfr12paess    13569.0023  13821.2944   8718.3031  13511.4978  13542.5597
# 7bfr7ess       20006.1471  19788.6859  17991.2675  20171.3210  21006.7281
# 7br69darjs       869.5364   4203.7132    289.1465   2341.5469   2405.1805
# 7crt49rjs        411.7587   2431.3197    177.0721   1470.0554   1610.7561
# 7jub34hess     23327.7092  22941.0354  21931.1393  19963.9363  21046.7297
# 7jub57dpaess   14170.5897  14146.3528  11210.9670  13804.9448  14304.8112
# 7jub58dpaess   18518.1366  19237.0189  16315.8546  18884.7205  16190.0466
# 7ll17drjs      16686.2606  16696.9842  10897.9865  15915.0604  15072.6621
# 7ll22drjs      24349.2657  25129.5040  15226.4767  25327.1272  24440.0587
# 7ll27rjs       23011.3254  29384.0896  28127.6204  26979.4378  28116.8517
# 7ll28drjs      23721.6301  22605.0776  18534.9951  30813.8851  30666.2600
# 7ll31drjs      16762.4692  17976.5034  23662.9607  18088.9110  23431.0755
# 7ll3drjs       14973.8779   4891.1348   6406.9994  15367.1216   2458.7762
# 7mll72rjs       3521.2770   2487.8045   2428.3489   2790.0280   3034.8774
# 7mll73drjs     10029.6985   7589.0605   8584.3268   8602.0647   8266.9026
# 7sph1sps       15091.4068  27950.3909  29209.2791  30890.8655  29672.4895
# 7sph4dsps      11687.6235  23417.7698  24872.3880  26042.2106  25666.0960
# 7sph5sps       11403.8771  21386.5414   6833.1661   6225.1359  10865.4408
# 7sph7dsps      27769.8229  26890.1537  24130.3315  26413.8986  27398.6775
# 8jub39ess      10035.5042   9937.2377   8960.7975   9895.8654   9860.5818
# 9brsa908drjs   12851.1737  13756.1606   7102.2727   6680.0087   4731.2235
# 9brsa928sps    12323.0419  24126.2471  25250.3097  22351.3773  13561.8593
# 9ll20drjs      17736.4786  27492.6855  27706.4638  28773.2396  28775.1491
# 9ll2rjs        22109.4912  27928.3609  24858.2009  17535.5583  23610.1937
#
#                2018-09-01
# 3brsa1017drjs    683.4728
# 3brsa788sps    23284.0363
# 6brsa631dbess   5164.5617
# 6brsa639ess    14975.7502
# 6brsa770drjs     126.0070
# 6brsa817rjs     1599.4272
# 7baz3ess        4016.5165
# 7baz4ess        7809.9120
# 7baz8ess       11735.5390
# 7bfr12paess     7733.7548
# 7bfr7ess       19659.8757
# 7br69darjs      2434.3869
# 7crt49rjs       1645.7955
# 7jub34hess     20994.7870
# 7jub57dpaess   10053.6851
# 7jub58dpaess   17035.5231
# 7ll17drjs      15299.6173
# 7ll22drjs      24782.0640
# 7ll27rjs       28981.0053
# 7ll28drjs      30756.3117
# 7ll31drjs      22167.2745
# 7ll3drjs       10177.9271
# 7mll72rjs       2335.5182
# 7mll73drjs      7393.5387
# 7sph1sps       28867.1360
# 7sph4dsps      25408.0794
# 7sph5sps        7644.0491
# 7sph7dsps      26010.6784
# 8jub39ess       9242.4171
# 9brsa908drjs   13775.5785
# 9brsa928sps    16127.5915
# 9ll20drjs      21990.2310
# 9ll2rjs        26473.6820
#
# [33 rows x 33 columns]

# %%
salt_time = salt_df.columns.values.tolist()
salt_wells = salt_df.index.tolist()

# %%
salt_time
# Out:
# ['2016-01-01',
#  '2016-02-01',
#  '2016-03-01',
#  '2016-04-01',
#  '2016-05-01',
#  '2016-06-01',
#  '2016-07-01',
#  '2016-08-01',
#  '2016-09-01',
#  '2016-10-01',
#  '2016-11-01',
#  '2016-12-01',
#  '2017-01-01',
#  '2017-02-01',
#  '2017-03-01',
#  '2017-04-01',
#  '2017-05-01',
#  '2017-06-01',
#  '2017-07-01',
#  '2017-08-01',
#  '2017-09-01',
#  '2017-10-01',
#  '2017-11-01',
#  '2017-12-01',
#  '2018-01-01',
#  '2018-02-01',
#  '2018-03-01',
#  '2018-04-01',
#  '2018-05-01',
#  '2018-06-01',
#  '2018-07-01',
#  '2018-08-01',
#  '2018-09-01']

# %%
salt_wells
# Out:
# ['3brsa1017drjs',
#  '3brsa788sps',
#  '6brsa631dbess',
#  '6brsa639ess',
#  '6brsa770drjs',
#  '6brsa817rjs',
#  '7baz3ess',
#  '7baz4ess',
#  '7baz8ess',
#  '7bfr12paess',
#  '7bfr7ess',
#  '7br69darjs',
#  '7crt49rjs',
#  '7jub34hess',
#  '7jub57dpaess',
#  '7jub58dpaess',
#  '7ll17drjs',
#  '7ll22drjs',
#  '7ll27rjs',
#  '7ll28drjs',
#  '7ll31drjs',
#  '7ll3drjs',
#  '7mll72rjs',
#  '7mll73drjs',
#  '7sph1sps',
#  '7sph4dsps',
#  '7sph5sps',
#  '7sph7dsps',
#  '8jub39ess',
#  '9brsa908drjs',
#  '9brsa928sps',
#  '9ll20drjs',
#  '9ll2rjs']

# %%
df = pd.DataFrame(columns=['dt', 'oil', 'well'])
for well in salt_wells:
    for time in salt_time:
        s = pd.Series([time, salt_df.loc[well, time], well], index=['dt', 'oil', 'well'])
        df = df.append(s,ignore_index=True)

# %%
# convert first column to DateTime format
df['dt'] = pd.to_datetime(df['dt'])

# set first column (dt) as the index column
df.index = df['dt']
del df['dt']

# %%
df
# Out:
#                    oil           well
# dt
# 2016-01-01   3217.8084  3brsa1017drjs
# 2016-02-01    940.7094  3brsa1017drjs
# 2016-03-01   1039.1168  3brsa1017drjs
# 2016-04-01   1645.0457  3brsa1017drjs
# 2016-05-01   1578.5540  3brsa1017drjs
# 2016-06-01   1555.8059  3brsa1017drjs
# 2016-07-01   1554.5046  3brsa1017drjs
# 2016-08-01   1668.1607  3brsa1017drjs
# 2016-09-01   1594.7409  3brsa1017drjs
# 2016-10-01   1728.0598  3brsa1017drjs
# 2016-11-01   1686.5849  3brsa1017drjs
# 2016-12-01   1164.8485  3brsa1017drjs
# 2017-01-01   1151.5995  3brsa1017drjs
# 2017-02-01   1023.0019  3brsa1017drjs
# 2017-03-01   1060.7174  3brsa1017drjs
# 2017-04-01    999.1382  3brsa1017drjs
# 2017-05-01   1879.5024  3brsa1017drjs
# 2017-06-01   3670.2664  3brsa1017drjs
# 2017-07-01   4472.9481  3brsa1017drjs
# 2017-08-01   2439.5030  3brsa1017drjs
# 2017-09-01   3013.7746  3brsa1017drjs
# 2017-10-01   2928.7530  3brsa1017drjs
# 2017-11-01   2677.8512  3brsa1017drjs
# 2017-12-01   2858.4587  3brsa1017drjs
# 2018-01-01   3107.4003  3brsa1017drjs
# 2018-02-01   3024.9240  3brsa1017drjs
# 2018-03-01   2992.8340  3brsa1017drjs
# 2018-04-01   1745.1677  3brsa1017drjs
# 2018-05-01    586.4773  3brsa1017drjs
# 2018-06-01    711.2949  3brsa1017drjs
# ...                ...            ...
# 2016-04-01  31070.9978        9ll2rjs
# 2016-05-01  30334.7783        9ll2rjs
# 2016-06-01  34322.7501        9ll2rjs
# 2016-07-01  32292.9629        9ll2rjs
# 2016-08-01  32333.3934        9ll2rjs
# 2016-09-01  28995.9882        9ll2rjs
# 2016-10-01  29146.6555        9ll2rjs
# 2016-11-01  28497.6068        9ll2rjs
# 2016-12-01  29130.8932        9ll2rjs
# 2017-01-01  28837.9557        9ll2rjs
# 2017-02-01  25549.5892        9ll2rjs
# 2017-03-01  28276.7608        9ll2rjs
# 2017-04-01  19148.2592        9ll2rjs
# 2017-05-01  25477.8562        9ll2rjs
# 2017-06-01  29330.4533        9ll2rjs
# 2017-07-01  29188.5272        9ll2rjs
# 2017-08-01  22875.6017        9ll2rjs
# 2017-09-01  17577.3982        9ll2rjs
# 2017-10-01  19851.2486        9ll2rjs
# 2017-11-01  28104.4555        9ll2rjs
# 2017-12-01  16614.6066        9ll2rjs
# 2018-01-01  19425.7146        9ll2rjs
# 2018-02-01  20662.3071        9ll2rjs
# 2018-03-01  21777.7290        9ll2rjs
# 2018-04-01  22109.4912        9ll2rjs
# 2018-05-01  27928.3609        9ll2rjs
# 2018-06-01  24858.2009        9ll2rjs
# 2018-07-01  17535.5583        9ll2rjs
# 2018-08-01  23610.1937        9ll2rjs
# 2018-09-01  26473.6820        9ll2rjs
#
# [1089 rows x 2 columns]

# %%
# check stationarity in time series data of a given well

def check_stationarity(well_df):
    # method1: plot the time series to check for trend and seasonality
    well_df.plot(figsize=(10, 10))
    
    # method 2: check if histogram fits a Gaussian Curve, then split data into two parts, calculate means and variances and see if they vary
    well_df.hist(figsize=(10, 10))
    plt.show()
    
    X = well_df["oil"].values
    split = int(len(X) / 2)
    X1, X2 = X[0:split], X[split:]
    mean1, mean2 = X1.mean(), X2.mean()
    var1, var2 = X1.var(), X2.var()
    print('mean1=%f, mean2=%f' % (mean1, mean2))
    print('variance1=%f, variance2=%f' % (var1, var2))
    
    # if corresponding means and variances differ slightly (by less than 10), we consider that the time series might be stationary
    if (abs(mean1-mean2) <= 10 and abs(var1-var2) <= 10):
        print("Time Series may be Stationary, since means and variances vary only slightly.\n")
    else:
        print("Time Series may NOT be Stationary, since means and variances vary significantly.\n")
        
    # method3: statistical test (Augmented Dickey-Fuller statistic)
    print("Performing Augmented Dickey-Fuller Test to confirm stationarity...")
    
    result = adfuller(X)
    print('ADF Statistic: %f' % result[0])
    print('p-value: %f' % result[1])
    
    p = result[1]
    if (p > 0.05):
        print("Time Series is NOT Stationary, since p-value > 0.05")
        well_df = well_df.diff()  # differencing to make data stationary
        return False
    else:
        print("Time Series is Stationary, since p-value <= 0.05")
        return True

# %%
# check stationarity for data of a specific city entered by the user

well_drop_down_menu = widgets.Dropdown(
    options=sorted(list(salt_wells)),
    value='3brsa1017drjs',
    description='well:',
    disabled=False,
)

well_drop_down_menu
# Out:
# Dropdown(description='well:', options=('3brsa1017drjs', '3brsa788sps', '6brsa631dbess', '6brsa639ess', '6brsa7…

# %%
chosen_well = well_drop_down_menu.value
well_df = df[df.well == chosen_well].drop("well", 1)

# %%
print ("Stationarity Check for %s" % chosen_well)
is_stationary = check_stationarity(well_df)
# Out:
# Stationarity Check for 3brsa1017drjs
# mean1=1475.524788, mean2=2234.741235
# variance1=283058.867714, variance2=1407401.483474
# Time Series may NOT be Stationary, since means and variances vary significantly.
#
# Performing Augmented Dickey-Fuller Test to confirm stationarity...
# ADF Statistic: -2.284942
# p-value: 0.176870
# Time Series is NOT Stationary, since p-value > 0.05

# %%
# ACF and PACF plots

plot_acf(well_df)
plot_pacf(well_df)
plt.show()

# setting d value for ARIMA model
if (is_stationary==True):
    d = 0
else:
    d = 1

# %%
p_range = q_range = list(range(0,3))  # taking values from 0 to 2

aic_values = []
bic_values = []
pq_values = []

for p in p_range:
    for q in q_range:
        try:
            model = ARIMA(well_df, order=(p, d, q))
            results = model.fit(disp=-1)
            aic_values.append(ARMAResults.aic(results))
            bic_values.append(ARMAResults.bic(results))
            pq_values.append((p, q))
        except:
            pass

best_pq = pq_values[aic_values.index(min(aic_values))]  # (p,q) corresponding to lowest AIC score
print("(p,q) corresponding to lowest AIC score: ", best_pq)
# Out:
# (p,q) corresponding to lowest AIC score:  (0, 0)

# %%
# fitting an ARIMA model with chosen p, d, q values and calculating the mean squared error
from sklearn.metrics import mean_absolute_error

arima_model = ARIMA(well_df, order=(best_pq[0], 0, best_pq[1])).fit()
predictions = arima_model.predict(start=0, end=len(well_df)-1)

mse = mean_squared_error(list(well_df.oil), list(predictions))
print("Mean Squared Error:", mse)

mae = mean_absolute_error(list(well_df.oil), list(predictions))
print("Mean Absolute Error:", mae)
# Out:
# Mean Squared Error: 1006235.747983351
# Mean Absolute Error: 841.4780975206611

# %%
# comparing first 100 predictions with actual values

plt.figure(figsize=(7.5,7.5))
plt.plot(list(well_df.oil)[:100], label="Actual")
plt.plot(list(predictions)[:100], 'r', label="Predicted")

plt.xlabel("Time (in Months)")
plt.ylabel("Oil (b/day)")
plt.title("Actual and Predicted Oil Production Values")

plt.legend(loc='upper center', bbox_to_anchor=(1.45, 0.8))
plt.show()

# %% [markdown]
# ### OBJECTIVE 2: Top-10 Wells in the Brazil with Maximum Production of Oil

# %%
changes = []  # stores temperature change for cities
avg_2013 = []  # stores average of 2013 temperature for each city
avg_2023 = []  # stores average of 2023 temperature for each city

for each_well in set(salt_wells):
    new_well_df = df[df.well == each_well].drop("well", 1)  # new df for each city
    new_well_df_mean = new_well_df.resample("A").mean()  # stores yearly mean temperature values for city
    new_well_df_mean = new_well_df_mean.dropna()
    last_year_average = new_well_df_mean['oil'][-1]  # average of last year temperature for comparison later
    avg_2013.append(last_year_average)
    
    # making predictions for city for next 10 years
    p_range = q_range = [i for i in range(0,3)]  # taking values from 0 to 2

    aic_values = []
    bic_values = []
    pq_values = []

    for p in p_range:
        for q in q_range:
            try:
                model = ARIMA(new_well_df, order=(p, 0, q))
                results = model.fit(disp=-1)
                aic_values.append(ARMAResults.aic(results))
                bic_values.append(ARMAResults.bic(results))
                pq_values.append((p, q))
            except:
                pass
    
    best_pq = pq_values[aic_values.index(min(aic_values))]  # (p,q) corresponding to lowest AIC score
    
    arima_model = ARIMA(new_well_df, order=(best_pq[0], 0, best_pq[1])).fit()
    
    # make prediction for next 10 years using 120 steps
    out_of_sample_forecast = arima_model.forecast(steps=120)[0]
    average_after_10_years = np.mean(out_of_sample_forecast[-9:])  # average of 10th year's values (after 10 years) i.e. average of last 9 values (Jan-Sep because 2013 values end at September)
    avg_2023.append(average_after_10_years)
    
    changes.append(abs(last_year_average - average_after_10_years))
    
    top_10_changes_indices = sorted(range(len(changes)), key=lambda i: changes[i], reverse=True)[:10]
    top_10_well = [salt_wells[x] for x in top_10_changes_indices]
    top_10_well

# %%
top_10_well
# Out:
# ['6brsa631dbess',
#  '6brsa639ess',
#  '7jub57dpaess',
#  '7baz8ess',
#  '6brsa770drjs',
#  '9ll2rjs',
#  '7mll73drjs',
#  '7ll17drjs',
#  '7baz3ess',
#  '9brsa908drjs']

# %%
def create_folium_map(lat, lot, zfact):
    '''
    Cria um objeto Folium.Map do tipo OpenStreetMap centrado em (lat,lot) com nível de zoom zfact
    '''
    import folium
    tiles = 'http://server.arcgisonline.com/ArcGIS/rest/services/NatGeo_World_Map/MapServer/tile/{z}/{y}/{x}'
    attr = ('Tiles &copy; Esri &mdash; Sources: GEBCO, NOAA, CHS, OSU, UNH, CSUMB, National Geographic, DeLorme, NAVTEQ, and Esri')
    m = folium.Map(location=[lat,lot], 
            tiles=tiles,
            attr=attr,
            zoom_start=zfact)
    return m

# %%
m = create_folium_map(-22.0,-40.0,8)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def add_pocos_mapa(mapa, pocos, cor, kind=1, nome_grupo=u'default'):
    if kind != 1 and kind != 2:
        print("Erro: Tipo de marcação no mapa indisponível!")
        return False
    else:
        pocos_len = pocos.shape[0]
        grupo = folium.FeatureGroup(nome_grupo)
        for i in range(pocos_len):
            lat, lont = float(pocos['LATITUDE_BASE_DD'][i].replace(",",".")), float(pocos['LONGITUDE_BASE_DD'][i].replace(",","."))
            if kind==1:
                folium.Marker(
                    location=[lat, lont],
                    popup=pocos['POCO'][i],
                    icon=folium.Icon(color=cor),
                    ).add_to(grupo)
            if kind==2:
                folium.Circle(
                    location=[lat, lont],
                    popup=pocos['POCO'][i],
                    radius=15,
                    color='red',
                    fill=True,
                    fill_color='crimson'
                    ).add_to(grupo)
            grupo.add_to(mapa)

# %%
for index, row in pai.iterrows():
    poco_name = [poco.lower().replace(' ', '').replace('-', '') for poco in pocos]
# Out:
# 7-SZ-514-SE
# 7-MLL-44HP-RJS
# 7-FP-398-RN
# 7-FP-375-RN
# 7-FP-376-RN
# 7-FP-382-RN
# 7-ARG-753-RN
# 7-FP-399-RN
# 7-ET-1019-RN
# 7-ET-1002-RN
# 7-SZ-524D-SE
# 7-LAR-12-RN
# 7-FSL-45-ES
# 7-CAM-1102-RN
# 7-ARG-722-RN
# 7-ARG-719-RN
# 7-ARG-718-RN
# 7-ARG-715-RN
# 7-ARG-709-RN
# 7-ARG-708-RN
# 7-MAG-71-RN
# 7-ET-1015D-RN
# 7-ANB-10D-AL
# 7-CP-1724-SE
# 7-SCR-89D-RN
# 7BA  0139  BA
# 7SI  0045  BA
# 7FP  0135  RN
# 7-FBM-248D-BA
# 7-SZ-510D-SE
# 7-CP-1691-SE
# 7-MG-501D-BA
# 7-FP-389-RN
# 7-ARG-733-RN
# 7-FP-413-RN
# 7-CP-1800-SE
# 7-FP-373-RN
# 7-CAM-1251-RN
# 7-CAM-1096-RN
# 7-RO-574-SE
# 7-ARG-776-RN
# 7CP  0232  SE
# 7-RO-571-SE
# 7-MG-502D-BA
# 7-ET-1037-RN
# 7FQ  0025  ES
# 7CAM 0141  RN
# 7-ARG-742-RN
# 7-RBU-103D-BA
# 7-CAM-1319-RN
# 7-CAM-1168-RN
# 7-ET-997-RN
# 7-FSR-40-ES
# 7-CP-11-ES
# 7-FI-110D-BA
# 7-ET-999-RN
# 7-ET-990-RN
# 7-ET-994-RN
# 7-ET-988-RN
# 7-ET-998-RN
# 7TM  0016  AL
# 7ARG 0037  RN
# 7-DJ-804-BA
# 7BA  0211  BA
# 7ARG 0055  RN
# 7-ET-1082D-RN
# 7-ET-1083D-RN
# 7-ET-1090D-RN
# 7-ET-1053D-RN
# 7-ARG-729-RN
# 7CN  0017  RN
# 7-BA-430D-BA
# 7-FBL-20D-BA
# 7-CAM-1357-RN
# 7-JUB-14HA-ESS
# 7-IBU-12D-ES
# 7-RCB-75D-BA
# 7-CAM-1098-RN
# 7-FSL-40-ES
# 7-SZ-483DA-SE
# 7-POL-15H-RJS
# 7-CP-1577D-SE
# 7-CP-1581D-SE
# 7-CP-1660D-SE
# 7-SCR-92D-RN
# 7-SCR-90D-RN
# 7-MLS-97HP-RJS
# 7-ET-1011-RN
# 7-CP-1752-SE
# 7-SC-20D-BA
# 7-ARG-740-RN
# 7-FSL-41-ES
# 7FI  0075  BA
# 7RO  0017  BA
# 7LV  0027  RN
# 7MO  0062  RN
# 7CAM 0508  RN
# 7-CAM-786-RN
# 7VRG 0003  RN
# 7ET  0763  RN
# 7BEN 0010  RN
# 7-AP-291-RN
# 7CP  1277  SE
# 7CP  1345D SE
# 7FZB 0448  CE
# 7CP  1365D SE
# 7ARG 0181  RN
# 7SM  0057  ES
# 7FC  0009  RN
# 7CAM 0563  RN
# 7ARG 0423  RN
# 7FZB 0131  CE
# 7GP  0022D RJS
# 7CP  1245  SE
# 7CP  1252  SE
# 7CAM 0244  RN
# 7CAM 0705D RN
# 7SZ  0374  SE
# 7AP  0271  RN
# 7RO  0034  SE
# 7BA  0225  BA
# 7AR  0202  BA
# 7CS  0108  BA
# 7ET  0415  RN
# 7RO  0103  BA
# 7FZB 0546  CE
# 7BA  0374D BA
# 7RP  0105  RN
# 7AR  0108  BA
# 7CP  0530  SE
# 7RO  0353  SE
# 7BA  0239  BA
# 7ET  0241  RN
# 7ARG 0238  RN
# 7BA  0325A BA
# 7FBM 0204  BA
# 7AP  0168  RN
# 7ET  0035  RN
# 7-FP-345-RN
# 7-FZB-683-CE
# 7-FZB-713-CE
# 7SZ  0298  SE
# 7LS  0032  ES
# 7ET  0290  RN
# 7CP  0920  SE
# 7AR  0146  BA
# 7FZB 0239  CE
# 7RFQ 0024D RN
# 7ET  0678  RN
# 7SZ  0372  SE
# 7SZ  0040  SE
# 7ET  0051  RN
# 7FI  0051  BA
# 7FZB 0440  CE
# 7-FZB-660-CE
# 7-ARG-565-RN
# 7-AG-406P-BA
# 7-ML-38D-BA
# 7-CAM-1154-RN
# 7-FR-15HP-RJS
# 7-ARG-744-RN
# 7-CAM-1384D-RN
# 7-AR-312D-BA
# 7-CAM-1372D-RN
# 7-CAM-1386D-RN
# 7-CAM-1373D-RN
# 7-CAM-1374D-RN
# 7ET  0348  RN
# 7-SZ-395D-SE
# 7CAM 0291  RN
# 7-FP-288-RN
# 7-ET-1086D-RN
# 7-CAM-1387D-RN
# 7-RO-549-SE
# 7-ET-1061D-RN
# 7-ET-1059D-RN
# 7-ET-1055D-RN
# 7-CP-1799-SE
# 7-FP-48D-BA
# 7CP  0237  SE
# 7CP  0248  SE
# 7CP  0251  SE
# 7ARG 0290  RN
# 7CH  0024D RJS
# 7LOR 0021  RN
# 7RI  0019  BA
# 7CP  1091  SE
# 7FP  0201  RN
# 7AP  0249  RN
# 7FZB 0558  CE
# 7ARG 0475  RN
# 7CN  0072D RN
# 7ARG 0486  RN
# 7PM  0037D RJS
# 7FZB 0586D CE
# 7-ARG-747-RN
# 7-ET-1046D-RN
# 7-CAM-1351-RN
# 7CAM 0730  RN
# 7-SMI-29-RN
# 7-ARG-556-RN
# 7-MOR-15-RN
# 7-FBM-233D-BA
# 7-CAM-1057-RN
# 7-JND-25D-BA
# 7-OST-3H-ESS
# 7-CP-1754-SE
# 7-CAM-1131D-RN
# 7-RI-45D-BA
# 7-ARG-763-RN
# 7-ARG-762-RN
# 7PL  0012  RN
# 7XA  0020D CES
# 7RSM 0031  ES
# 7PIR 0041  AL
# 7ET  0239  RN
# 7C   0043  BA
# 7-JND-14D-BA
# 7-ARG-652-RN
# 7-FZB-690-CE
# 7-CAM-1037-RN
# 7-BA-418-BA
# 7REP 0055  RN
# 7FSL 0024  ES
# 7-CAM-1073-RN
# 7-CAM-1221-RN
# 7-FZB-732-CE
# 7BA  0383D BA
# 7-BVS-54-RN
# 7-TQ-187D-BA
# 7-MAG-28-RN
# 7-AR-314D-BA
# 7-CAM-1158-RN
# 7-CAM-1053D-RN
# 7-ARG-769-RN
# 7-ARG-771-RN
# 7-ARG-772-RN
# 7-CAM-1119D-RN
# 7-MA-31HPB-RJS
# 7-CAM-1163D-RN
# 7-ET-1058D-RN
# 7-FP-408-RN
# 7-CP-1781D-SE
# 7ARG 0192  RN
# 7ET  0342  RN
# 7FZB 0412  CE
# 7PIR 0112  AL
# 7SZ  0379D SE
# 7FSL 0025  ES
# 7FMQ 0025  RN
# 7FP  0224  RN
# 7-JND-48D-BA
# 7-CAM-1088-RN
# 7-CAM-1093-RN
# 7-ARG-687-RN
# 7-CAM-1043-RN
# 7-GMR-83-RN
# 7-GMR-71-RN
# 7-MLL-34HPB-RJS
# 7-CAM-1265-RN
# 7-ET-981-RN
# 7-ET-980-RN
# 7-SZ-494-SE
# 7-CP-1648-SE
# 7-CP-1635D-SE
# 7-CAM-1185D-RN
# 7-CAM-1202-RN
# 7-ET-948-RN
# 7-FZB-777-CE
# 7-SCR-82-RN
# 7-CAM-1206-RN
# 7-CAM-1218-RN
# 7-JND-41D-BA
# 7-FZB-794-CE
# 7-SER-23D-RNS
# 7-ARG-655-RN
# 7-ARG-656-RN
# 7-FZB-751-CE
# 7-FZB-752-CE
# 7-SER-22D-RNS
# 7-FZB-778-CE
# 7-CP-1711-SE
# 7-CP-1727D-SE
# 7-CAM-1231-RN
# 7-CAM-1246-RN
# 7-FZB-754-CE
# 7-FZB-759-CE
# 7-CAM-1261-RN
# 7-CAM-1256-RN
# 7-CAM-1213D-RN
# 7-FZB-773-CE
# 7-CAM-1300-RN
# 7-CP-1701D-SE
# 7-CP-1676D-SE
# 7-CP-1805D-SE
# 7-CAM-1109-RN
# 7-RUC-60HP-AM
# 7-CP-1653-SE
# 7-RO-530-SE
# 7-CAM-1208-RN
# 7-RBU-97D-BA
# 7-CAM-1239-RN
# 7-FBM-239D-BA
# 7-POL-11HP-RJS
# 7-CAM-1226-RN
# 7-FZB-775-CE
# 7-PTS-1-RN
# 7-MAG-64-RN
# 7-MAG-65-RN
# 7-CP-1609-SE
# 7-ET-961-RN
# 7-CP-1777DA-SE
# 7-RO-518-SE
# 7-FR-2HP-RJS
# 7-CP-1631-SE
# 7-SCR-85D-RN
# 7-CP-1733DA-SE
# 7-CP-1652D-SE
# 7-CP-1783D-SE
# 7-CP-1689D-SE
# 7-CP-1659D-SE
# 7-ET-992-RN
# 7-ET-993-RN
# 7-FP-341-RN
# 7-SZ-473D-SE
# 7-SE-58-RN
# 7-CP-1621-SE
# 7-CAM-1058-RN
# 7-CAM-1051-RN
# 7-CP-1607-SE
# 7-CP-1696D-SE
# 7-CAM-1161-RN
# 7-CAM-1006-RN
# 7-BE-29-RN
# 7-BE-30-RN
# 7-GMR-81-RN
# 7-CAM-1244-RN
# 7-FZB-788-CE
# 7-SCR-83-RN
# 7-CP-1612-SE
# 7-FZB-748-CE
# 7-CAM-1171-RN
# 7-ARG-690-RN
# 7-RFQ-40D-RN
# 7-CAM-1160-RN
# 7-FU-152D-AL
# 7ET  0144  RN
# 7ET  0150  RN
# 7FZB 0089  CE
# 7FZB 0213  CE
# 7FZB 0061  CE
# 7RP  0052  RN
# 7FAV 0027  BA
# 7CRP 0011  RJS
# 7CP  1171  SE
# 7AR  0282  BA
# 7FZB 0471  CE
# 7SUS 0011  BA
# 7ARG 0160  RN
# 7TQ  0145  BA
# 7FZB 0532  CE
# 7-MP-23D-BA
# 7-CL-49HP-SE
# 7-CAM-859-RN
# 7-AG-15D-SE
# 7ET  0228  RN
# 7BA  0125  BA
# 7RO  0014  BA
# 7CP  0665  SE
# 7FZB 0162  CE
# 7TM  0024D AL
# 7RI  0051  ES
# 7SI  0030  BA
# 7RP  0016  RN
# 7GMR 0010  RN
# 7CP  0865  SE
# 7ET  0361  RN
# 7XA  0009  CES
# 7-CP-1465D-SE
# 7ARG 0170  RN
# 7SZ  0250  SE
# 7ET  0210  RN
# 7CS  0126  BA
# 7CAM 0341  RN
# 7FBM 0188  BA
# 7CAM 0238  RN
# 7CP  1243  SE
# 7ARG 0064  RN
# 7FZB 0064  CE
# 7FP  0169  RN
# 7TQ  0158  BA
# 7ARG 0312  RN
# 7AT  0019D CES
# 7C   0158  BA
# 7CP  0021  SE
# 7-ET-858-RN
# 7CP  1099  SE
# 7CS  0088  BA
# 7CP  1259  SE
# 7RFQ 0030D RN
# 7ARG 0490D RN
# 7REP 0060  RN
# 7ET  0744  RN
# 7ET  0737  RN
# 7ET  0719D RN
# 7-BE-14-RN
# 7-RO-451-SE
# 7-FZB-703-CE
# 7-FP-357-RN
# 7MJ  0027  BA
# 7C   0113  BA
# 7-CAM-1449-RN
# 7-JUB-37H-ESS
# 7-CAM-1492-RN
# 7-FAL-119-ES
# 7-RO-628-SE
# 7-RE-44-RN
# 7-ET-1258-RN
# 7-ET-1261-RN
# 7-ET-1263D-RN
# 7-ET-1260D-RN
# 7-ET-1289D-RN
# 7-ET-1286D-RN
# 7-FAV-132D-BA
# 7-FSL-56-ES
# 7-CAM-1414D-RN
# 7-FSR-57-ES
# 7-ET-1407D-RN
# 7-CS-219-BA
# 7-FZB-866-CE
# 7-FSL-58-ES
# 7-RBU-117D-BA
# 7-IBU-27-ES
# 7-ET-1085-RN
# 7-CP-1938-SE
# 7-ET-1184D-RN
# 7-BAZ-8-ESS
# 7-ML-54D-BA
# 7-IBU-28D-ES
# 7-CP-1923-SE
# 7-ET-1097-RN
# 7-MRL-206HB-RJS
# 7-FAL-103-ES
# 7-GC-6-RN
# 7-GC-12-RN
# 7-GC-13-RN
# 7-GC-8-RN
# 7-ROL-1-RN
# 7-LV-65D-RN
# 7-DJ-870-BA
# 7-SZ-641-SE
# 7-FZB-911-CE
# 7-MLS-217HPA-RJS
# 7-ARG-866-RN
# 7-FI-121D-BA
# 7-RO-625D-SE
# 7-RBU-120D-BA
# 7-FZB-896-CE
# 7-FZB-904-CE
# 7-FZB-907-CE
# 7-FZB-885-CE
# 7-ET-1276D-RN
# 7-ET-1294D-RN
# 7-ET-1287D-RN
# 7-SCR-129D-RN
# 7-RO-640-SE
# 7-CAM-1338-RN
# 7-SZ-557-SE
# 7-FI-122D-BA
# 7-CP-1941-SE
# 7-FI-118D-BA
# 7-LPX-18D-RN
# 7-CP-1564D-SE
# 7-SZ-594-SE
# 7-RO-133HP-RJS
# 7-CAM-1461-RN
# 7-ARG-865-RN
# 7-ARG-858-RN
# 7-ARG-842-RN
# 7-AR-349DP-BA
# 7-ET-1351-RN
# 7-PML-34-RN
# 7-FP-73D-BA
# 7-ET-1271-RN
# 7-ET-1298-RN
# 7-ET-1290D-RN
# 7-ET-1297D-RN
# 7-ET-1299-RN
# 7-IBU-31D-ES
# 7-RBU-123D-BA
# 7-SZ-541D-SE
# 7-ET-1338D-RN
# 7-RO-141HP-RJS
# 7-PTS-15-RN
# 7-BAN-1-SPS
# 7-ET-1257-RN
# 7-ET-1411D-RN
# 7-LL-15D-RJS
# 7-TQ-216D-BA
# 7-TQ-217D-BA
# 7-CP-1921-SE
# 7-CL-84D-SE
# 7-ML-55D-BA
# 7-ET-1107-RN
# 7-MRL-210HPA-RJS
# 7-SCR-134D-RN
# 7-FSL-65D-ES
# 7-ET-1250D-RN
# 7-ET-1147D-RN
# 7-ET-1255-RN
# 7-ET-1252-RN
# 7-ET-1091D-RN
# 7-ET-1247D-RN
# 7-ET-1253-RN
# 7-ET-1282D-RN
# 7-ET-1291D-RN
# 7-ET-1113-RN
# 7-ET-1164-RN
# 7-SCR-98-RN
# 7-ET-1397D-RN
# 7-ET-1323D-RN
# 7-ET-1415-RN
# 7-MLS-214HPA-RJS
# 7-CP-1954D-SE
# 7-PIR-266D-AL
# 7-ET-1163-RN
# 7-ET-1087-RN
# 7-ET-1188-RN
# 7-CRT-49-RJS
# 7-MG-509D-BA
# 7-CS-225-BA
# 7-MLS-195H-RJS
# 7-CAM-1309-RN
# 7-ET-1178D-RN
# 7-ET-1108-RN
# 7-TQ-218D-BA
# 7-ET-1433D-RN
# 7-AR-329D-BA
# 7-CNC-39-ES
# 7-ET-1321D-RN
# 7-BFR-12PA-ESS
# 7-CAM-1446D-RN
# 7-RFQ-51D-RN
# 7-LV-58D-RN
# 7-ET-1284D-RN
# 7-DJ-842-BA
# 7-RFQ-53D-RN
# 7-ARG-777-RN
# 7-ET-1215-RN
# 7-FMQ-34-RN
# 7-CP-1519D-SE
# 7-AR-357D-BA
# 7MA  0006D RJS
# 7ET  0599  RN
# 7-ET-1412D-RN
# 7-DJ-861-BA
# 7-ARG-871-RN
# 7-AR-346D-BA
# 7-CP-1562-SE
# 7-RO-708-SE
# 7-ET-1162-RN
# 7-ET-1057-RN
# 7-SZ-609-SE
# 7-CAM-1495-RN
# 7-CL-72D-SE
# 7-CL-79D-SE
# 7-RO-108D-BA
# 7-MRL-222HPA-RJS
# 7-CNC-27D-ES
# 7-ET-1278D-RN
# 7-ET-1281-RN
# 7-MRL-226HPA-RJS
# 7-ET-847-RN
# 7-AG-388D-BA
# 7-FZB-702-CE
# 7-ET-1185-RN
# 7SI  0011  BA
# 7-DJ-853H-BA
# 7-CL-64D-SE
# 7-CL-88D-SE
# 7-SPH-5-SPS
# 7-MRL-223HP-RJS
# 7-RBU-119D-BA
# 7-RBU-121D-BA
# 7-FAV-131D-BA
# 7-CNC-13-ES
# 7-CNC-14-ES
# 7-FZB-857-CE
# 7-FZB-864-CE
# 7-FZB-871-CE
# 7-BA-449D-BA
# 7-SZ-589-SE
# 7-FZB-844-CE
# 7MG  0235  BA
# 7ARG 0132  RN
# 7ARG 0097  RN
# 7-LV-69-RN
# 7-LV-68-RN
# 7-CAM-1452-RN
# 7-JUB-44-ESS
# 7-JUB-55-ESS
# 7-FZB-878-CE
# 7-FSL-57A-ES
# 7-CNC-19-ES
# 7-GC-9-RN
# 7-GC-7-RN
# 7-GC-10-RN
# 7-SPH-4D-SPS
# 7-ET-1404-RN
# 7-CP-1918-SE
# 7-MG-121-SE
# 7-ET-1403-RN
# 7-ET-1394D-RN
# 7-SZ-608D-SE
# 7-CLD-15-RN
# 7-CP-1914-SE
# 7-ET-1306-RN
# 7-ET-1296D-RN
# 7-ET-1292D-RN
# 7-ET-1283-RN
# 7-ET-1175-RN
# 7-CP-1942D-SE
# 7TM  0051D AL
# 7ARG 0088  RN
# 7SMC 0033  AL
# 7ET  0057  RN
# 7TM  0049  AL
# 7FP  0018  RN
# 7CRP 0059D RJS
# 7CAM 0606  RN
# 7-FZB-898-CE
# 7-ET-1165-RN
# 7-CP-1627D-SE
# 7-RO-144HP-RJS
# 7-ET-1396D-RN
# 7-ET-1410-RN
# 7-MLS-211H-RJS
# 7-SZ-596-SE
# 7-CAM-1433D-RN
# 7-CNC-32-ES
# 7-BAN-2-SPS
# 7-AR-353D-BA
# 7-ET-1269D-RN
# 7ET  0014  RN
# 7ET  0602  RN
# 7AP  0144  RN
# 7-ET-1416D-RN
# 7-DJM-856H-BAS
# 7-CL-65D-SE
# 7-ET-1198-RN
# 7-CP-1936-SE
# 7-ET-1104D-RN
# 7-ET-1119D-RN
# 7-ET-1182D-RN
# 7-ET-1062D-RN
# 7-CL-78D-SE
# 7-SZ-618-SE
# 7-ET-1262-RN
# 7-ET-1307D-RN
# 7-RS-31-BA
# 7-CP-1913D-SE
# 7CX  0033  BA
# 7FP  0181  RN
# 7RPJ 0050  BA
# 7-PRA-2-SPS
# 7-ET-1125-RN
# 7-CS-217-BA
# 7-SZ-640D-SE
# 7-SCR-106D-RN
# 7-ET-1127-RN
# 7-ET-1239D-RN
# 7-ET-1246D-RN
# 7-ET-1243D-RN
# 7-ET-1251D-RN
# 7-ET-1232D-RN
# 7-BVS-65-RN
# 7-FBE-66DP-BA
# 7-ET-1254D-RN
# 7-SZS-1-SE
# 7-SPH-7D-SPS
# 7-SPH-8-SPS
# 7-SZ-611D-SE
# 7-LL-31D-RJS
# 7-CAM-1494-RN
# 7-CAM-1487-RN
# 7-CAM-1479-RN
# 7-CAM-1454-RN
# 7-CAM-1453-RN
# 7-CAM-1445-RN
# 7-SER-39D-RNS
# 7-AR-355D-BA
# 7-ET-861-RN
# 7-FZB-712-CE
# 7-CP-1393D-SE
# 7-PC-15-RN
# 7-FBM-230D-BA
# 7-PTS-16-RN
# 7-TQ-215D-BA
# 7-ET-1275D-RN
# 7-CP-1943D-SE
# 7-CP-1944-SE
# 7-ET-1199-RN
# 7-SER-38D-RNS
# 7-RO-638D-SE
# 7-CNC-22-ES
# 7-CNC-20-ES
# 7-PML-35-RN
# 7-ET-1391-RN
# 7-ET-1150-RN
# 7-ET-1148-RN
# 7AG  0204  BA
# 7CP  0174D SE
# 7C   0203D BA
# 7-BE-32-RN
# 7-ARG-785D-RN
# 7-ET-1117-RN
# 7-CP-1920D-SE
# 7-CP-1928D-SE
# 7-SC-30D-BA
# 7-FZB-876-CE
# 7-FMQ-47-RN
# 7-RO-704-SE
# 7-FZB-889-CE
# 7-FZB-910-CE
# 7-SZ-572D-SE
# 7-SPH-14D-SPS
# 7-CAM-1497-RN
# 7-RO-110D-BA
# 7-ET-1330D-RN
# 7-ET-1103D-RN
# 7-ET-1237D-RN
# 7-ET-1121D-RN
# 7-SPH-1-SPS
# 7-MLL-72-RJS
# 7-ET-1320D-RN
# 7-CP-1927D-SE
# 7GMR 0021  RN
# 7ET  0164  RN
# 7FZB 0099  CE
# 7ET  0191  RN
# 7FP  0095  RN
# 7CP  1234  SE
# 7FZB 0450  CE
# 7-ARG-787D-RN
# 7-FZB-913-CE
# 7-FZB-892-CE
# 7-RBU-113D-BA
# 7-CAM-1409-RN
# 7-ET-1353-RN
# 7-ET-1359-RN
# 7-ET-1375-RN
# 7-CAM-1444-RN
# 7-SZ-610D-SE
# 7-ARG-867-RN
# 7-RO-620D-SE
# 7-CAM-1489D-RN
# 7-CP-1922D-SE
# 7-SZ-619-SE
# 7CG  0008  ES
# 7CP  1195  SE
# 7CP  1204  SE
# 7AP  0007  RN
# 7CAM 0313  RN
# 7-CAM-998-RN
# 7-MO-88D-RN
# 7-DJM-857H-BAS
# 7-DJ-878H-BA
# 7-SCR-137D-RN
# 7-ET-1399-RN
# 7-ET-1327D-RN
# 7-FSR-65-ES
# 7-SCR-136D-RN
# 7-PIR-268D-AL
# 7-ARG-876-RN
# 7-JUB-57DPA-ESS
# 7-CLD-18-RN
# 7-CLD-19-RN
# 7-LL-36A-RJS
# 7-AG-432D-BA
# 7-SC-29D-BA
# 7-SZ-559-SE
# 7-FZB-805-CE
# 7-FZB-816-CE
# 7-FZB-833-CE
# 7-FZB-851-CE
# 7-FSR-64-ES
# 7-RO-497-SE
# 7-AB-78H-RJS
# 7-CP-1445D-SE
# 7AR  0027  BA
# 7-ET-1101D-RN
# 7-CAM-1466D-RN
# 7-ET-1414D-RN
# 7-ET-1405D-RN
# 7-FZB-869-CE
# 7-ET-1318-RN
# 7-SCR-94-RN
# 7-SCR-133D-RN
# 7-SZ-578-SE
# 7-AG-427D-BA
# 7-LL-17D-RJS
# 7-FZB-829-CE
# 7-ET-1293D-RN
# 7-ET-1259D-RN
# 7-FZB-830-CE
# 7-FZB-831-CE
# 7-MLS-209HA-RJS
# 7-MLL-73D-RJS
# 7RO  0040  SE
# 7ET  0069  RN
# 7FZB 0267  CE
# 7PL  0034  RN
# 7-RO-612D-SE
# 7-ABL-84HP-RJS
# 7-CLD-13-RN
# 7-CLD-12-RN
# 7-CLD-11-RN
# 7-ET-1302-RN
# 7-ET-1303-RN
# 7-ET-1304-RN
# 7-ET-1295-RN
# 7-ET-1300D-RN
# 7-FZB-884-CE
# 7-ML-56D-BA
# 7-MG-87D-SE
# 7-FSR-59DP-ES
# 7-ET-1409-RN
# 7-ET-1402-RN
# 7ET  0110  RN
# 7FP  0026  RN
# 7FP  0173  RN
# 7AP  0036  RN
# 7CP  1191D SE
# 7ROU 0020  BA
# 7-IP-20D-SE
# 7-SZ-643D-SE
# 7-FSR-62-ES
# 7-FZB-879-CE
# 7-CAM-1435-RN
# 7-ET-1114-RN
# 7-TGA-9D-BA
# 7-ET-1311-RN
# 7-ET-1377-RN
# 7-ET-1366-RN
# 7-ET-1388-RN
# 7-CL-74D-SE
# 7-CL-61D-SE
# 7-ET-1096-RN
# 7-ET-1267-RN
# 7-ET-1264-RN
# 7-ET-1265D-RN
# 7-ET-1273-RN
# 7-ET-1277-RN
# 7-ET-1279-RN
# 7-ET-1280D-RN
# 7-RS-28D-BA
# 7-RS-29D-BA
# 7-RS-30-BA
# 7-FZB-856-CE
# 7-TQ-208D-BA
# 7-CP-1910-SE
# 7FBE 0034  BA
# 7ET  0431  RN
# 7-FZB-900-CE
# 7-FZB-936-CE
# 7-RO-709-SE
# 7-LL-22D-RJS
# 7-SZ-644D-SE
# 7-RO-685D-SE
# 7-MO-86D-RN
# 7-SC-35D-BA
# 7-CAM-1432-RN
# 7-CX-99D-BA
# 7-CNC-25-ES
# 7-MG-510D-BA
# 7-TGA-7D-BA
# 7-CS-218D-BA
# 7-RO-719-SE
# 7-RBU-90D-BA
# 7-ARG-634-RN
# 7RO  0079  SE
# 7CP  0204  SE
# 7-LOR-89-RN
# 7-ET-1443D-RN
# 7-SER-40D-RNS
# 7-AG-431D-BA
# 7-CLD-10-RN
# 7-ET-1326-RN
# 7-ET-1339-RN
# 7-ET-1336-RN
# 7-ET-1335-RN
# 7-ET-1328-RN
# 7-SCR-95-RN
# 7-ET-1398-RN
# 7-ET-1417D-RN
# 7-ET-1340-RN
# 7-SCR-121-RN
# 7-RO-135H-RJS
# 7-ET-1305D-RN
# 7-CS-227-BA
# 7-FCN-10-RN
# 7-ET-1122D-RN
# 7BA  0116  BA
# 7RP  0008  RN
# 7FZB 0275  CE
# 7ARG 0110  RN
# 7SZ  0283  SE
# 7ARG 0169  RN
# 7GMR 0042  RN
# 7PIR 0080  AL
# 7ARG 0224  RN
# 7-CAM-1323-RN
# 7-JAN-5-RN
# 7FZB 0048  CE
# 7RI  0029  ES
# 7FZB 0063  CE
# 7ARG 0007  RN
# 7CM  0080D SES
# 7CP  1142  SE
# 7AR  0209  BA
# 7FZB 0128  CE
# 7FZB 0138  CE
# 7CP  0087  SE
# 7BA  0118  BA
# 7CAM 0426  RN
# 7-MLS-117HP-RJS
# 7-GLF-28HA-ESS
# 7-CAM-1122-RN
# 7-CAM-1214-RN
# 7-CAM-1326-RN
# 7-SZ-502-SE
# 7-RO-538-SE
# 7MJ  0029  BA
# 7C   0116  BA
# 7-CP-1690-SE
# 7-CER-29D-BA
# 7ARG 0046  RN
# 7BA  0242  BA
# 7ET  0172  RN
# 7FP  0081  RN
# 7CH  0005D RJS
# 7BA  0343  BA
# 7CAM 0578  RN
# 7CAM 0585  RN
# 7CAM 0610  RN
# 7AP  0233  RN
# 7CAM 0657  RN
# 7ET  0547  RN
# 7ET  0560  RN
# 7CER 0014D BA
# 7-JUB-13HP-ESS
# 7-FBM-247D-BA
# 7-FP-395-RN
# 7-CAM-1308D-RN
# 7-CAM-1307D-RN
# 7-BAL-75-RN
# 7-CP-1819D-SE
# 7-FR-8HP-RJS
# 7-RO-561D-SE
# 7-GMR-77-RN
# 7-POL-24HP-RJS
# 7-MLS-167HPA-RJS
# 7-FZB-801-CE
# 7-CAM-1141D-RN
# 7-ARG-774-RN
# 7-FZB-849-CE
# 7-RBU-108D-BA
# 7ET  0587  RN
# 7ARG 0432  RN
# 7ARG 0446  RN
# 7ET  0760D RN
# 7FP  0194  RN
# 7-RO-583D-SE
# 7-RO-562-SE
# 7-RBU-101D-BA
# 7MO  0066  RN
# 7RO  0104  BA
# 7REP 0027  RN
# 7ET  0647  RN
# 7FZB 0533  CE
# 7-FSR-47-ES
# 7-RO-112HA-RJS
# 7FI  0073  BA
# 7RPJ 0061D BA
# 7FAV 0031  BA
# 7FP  0129  RN
# 7-FZB-677-CE
# 7-ARG-610-RN
# 7-MP-24D-BA
# 7-FZB-809-CE
# 7-TGA-1D-BA
# 7-ET-1071D-RN
# 7CP  0588  SE
# 7CP  0592  SE
# 7-FP-405-RN
# 7-RO-584-SE
# 7CP  1068  SE
# 7FAV 0075  BA
# 7FI  0101  BA
# 7FZB 0210  CE
# 7SI  0022  BA
# 7AP  0033  RN
# 7-ARG-730-RN
# 7-FP-397-RN
# 7-ET-1070D-RN
# 7PL  0022  RN
# 7RO  0344  SE
# 7SE  0032  RN
# 7SZ  0015  SE
# 7-ET-1030-RN
# 7-CP-1662-SE
# 7-FP-383-RN
# 7RCB 0071  BA
# 7MGN 0019  BA
# 7-SER-26D-RNS
# 7-MAG-66-RN
# 7-JAN-6-RN
# 7-BAL-72-RN
# 7-CAM-1101-RN
# 7-BAL-78-RN
# 7-CAM-1112-RN
# 7FP  0180  RN
# 7AP  0174  RN
# 7SCR 0015D RN
# 7BA  0289  BA
# 7FP  0119  RN
# 7CP  0973  SE
# 7FZB 0364  CE
# 7-BAL-61-RN
# 7-CP-1575D-SE
# 7-BAL-60-RN
# 7-ARG-745-RN
# 7-DJ-829-BA
# 7-MUI-18D-BA
# 7-LOR-81-RN
# 7-LOR-83-RN
# 7-LOR-77-RN
# 7-CP-1818-SE
# 7-RO-600-SE
# 7-RO-581-SE
# 7-CAM-1271-RN
# 7-CAM-1279-RN
# 7-FAL-95DP-ES
# 7-AB-95H-RJS
# 7-FZB-760-CE
# 7-MG-62-SE
# 7TQ  0074  BA
# 7FZB 0521  CE
# 7-CAM-1296D-RN
# 7-AB-117H-RJS
# 7-AR-315D-BA
# 7-RFQ-46D-RN
# 7-AR-320D-BA
# 7-SCR-110-RN
# 7-ET-1209-RN
# 7-ET-1216-RN
# 7-ET-1219-RN
# 7-ET-1220-RN
# 7-CAM-1345D-RN
# 7-CAM-1364D-RN
# 7-CP-1580-SE
# 7-CAM-1321-RN
# 7-CAM-1318-RN
# 7-ET-1012-RN
# 7-FSL-42-ES
# 7-CAM-1314-RN
# 7ARG 0108  RN
# 7SI  0024  BA
# 7ET  0079  RN
# 7MG  0342  BA
# 7FBM 0006  BA
# 7ET  0193  RN
# 7FZB 0310  CE
# 7-FBE-55D-BA
# 7-GMR-84-RN
# 7-ET-1069D-RN
# 7MG  0415  BA
# 7CAM 0209  RN
# 7-SCR-104D-RN
# 7-CAM-800-RN
# 7CP  0485  SE
# 7ARG 0113  RN
# 7ARG 0166  RN
# 7FAV 0009  BA
# 7TQ  0130  BA
# 7PIR 0042  AL
# 7-ET-1043D-RN
# 7BA  0246  BA
# 7CP  0136  SE
# 7-ET-1143-RN
# 7LP  0007D ES
# 7VM  0001  RJS
# 7VM  0029D RJS
# 7MG  0384  BA
# 7ET  0363  RN
# 7UB  0114D RNS
# 7-ET-1008D-RN
# 7-DJM-854H-BAS
# 7-CNC-1-ES
# 7CAM 0549D RN
# 7-LAR-11-RN
# 7-SC-21D-BA
# 7-FZB-764-CE
# 7-ET-1024-RN
# 7-ET-1028-RN
# 7-ET-1120D-RN
# 7-ET-1129-RN
# 7-AR-325D-BA
# 7-FBM-256D-BA
# 7-CP-1766D-SE
# 7ET  0637  RN
# 7ET  0649  RN
# 7ET  0660  RN
# 7ET  0706D RN
# 7ET  0717  RN
# 7BA  0370D BA
# 7ET  0371  RN
# 7FZB 0436  CE
# 7RP  0093  RN
# 7SG  0004  BA
# 7-ET-1021-RN
# 7-GMR-74-RN
# 7-DJ-819-BA
# 7-JUB-9HP-ESS
# 7-LUC-61HP-AM
# 7-TGA-4D-BA
# 7-CAM-1165-RN
# 7-ARG-716-RN
# 7-ET-1017-RN
# 7-BAL-79-RN
# 7-ET-1031-RN
# 7AG  0240D BA
# 7SZ  0122  SE
# 7-MRL-194HP-RJS
# 7-ET-1000D-RN
# 7-RO-86HP-RJS
# 7-FBM-255D-BA
# 7-RBU-109D-BA
# 7-FP-424-RN
# 7CX  0036  BA
# 7-ML-45D-BA
# 7-RO-555-SE
# 7-CAM-1274D-RN
# 7-CAM-1276-RN
# 7-BAL-77-RN
# 7-BAL-67-RN
# 7-BAL-71-RN
# 7-CP-1643-SE
# 7-RO-589-SE
# 7-MLL-56HP-RJS
# 7-CAM-1313-RN
# 7-CAM-1315-RN
# 7FZB 0372  CE
# 7RO  0222  SE
# 7CAM 0465  RN
# 7FZB 0477  CE
# 7CX  0067  BA
# 7-ARG-737-RN
# 7-FP-415-RN
# 7-FBM-260D-BA
# 7-ET-1077D-RN
# 7-NO-9-ES
# 7RO  0031  SE
# 7-CAM-1395-RN
# 7-CAM-1393D-RN
# 7-ET-1223D-RN
# 7FBM 0147  BA
# 7CP  1006  SE
# 7FBM 0071  BA
# 7FP  0150  RN
# 7FP  0151  RN
# 7ARG 0261  RN
# 7-BAL-76-RN
# 7FZB 0184  CE
# 7-CAM-1272-RN
# 7CP  0047  SE
# 7CP  0063  SE
# 7-JND-58DP-BA
# 7-ARG-739-RN
# 7-CAM-1353-RN
# 7-CAM-1382D-RN
# 7-CX-90D-BA
# 7CP  0296  SE
# 7ROV 0006  BA
# 7-FP-412-RN
# 7-ET-1144-RN
# 7-ET-1149-RN
# 7-ET-1092D-RN
# 7-FP-44D-BA
# 7-ET-1098D-RN
# 7-SZ-404D-SE
# 7-SER-8D-RNS
# 7FZB 0194  CE
# 7ET  0019  RN
# 7C   0087  BA
# 7ARG 0141  RN
# 7-DJ-833-BA
# 7-BAL-69-RN
# 7-CP-1651D-SE
# 7CAM 0327  RN
# 7FAV 0114  BA
# 7-RO-557D-SE
# 7-FZB-927-CE
# 7-FAV-127D-BA
# 7-FBM-259D-BA
# 7CAM 0382  RN
# 7CJ  0015  RN
# 7AP  0110  RN
# 7CX  0058  BA
# 7-DJ-812H-BA
# 7-MAG-76-RN
# 7-CAM-1115D-RN
# 7-CAM-1104D-RN
# 7-CAM-1355-RN
# 7-CAM-1066-RN
# 7-FP-385-RN
# 7-CAM-1320-RN
# 7-ARG-723-RN
# 7-CAM-1285-RN
# 7-CAM-1336-RN
# 7-CAM-1337-RN
# 7-CP-1812D-SE
# 7-CP-1813D-SE
# 7-SZ-501D-SE
# 7-SZ-509D-SE
# 7-DJ-831-BA
# 7-ARG-754-RN
# 7-CAM-1325-RN
# 7-CP-1803D-SE
# 7-DJ-823-BA
# 7-RO-558-SE
# 7ET  0521  RN
# 7CAM 0655  RN
# 7-ET-1076D-RN
# 7-ET-1079D-RN
# 7-CAM-1339D-RN
# 7-CAM-1284-RN
# 7-TGA-5D-BA
# 7-BE-28-RN
# 7-CAM-1331-RN
# 7-CAM-1347D-RN
# 7-AR-317D-BA
# 7FZB 0022  CE
# 7-BAL-62-RN
# 7-ET-1026-RN
# 7ET  0039  RN
# 7-BA-432D-BA
# 7-CP-1584D-SE
# 7-SCR-97-RN
# 7-JUB-16HP-ESS
# 7GMR 0058  RN
# 7-SCR-103-RN
# 7-CAM-1390D-RN
# 7-RO-592-SE
# 7-ET-1042D-RN
# 7-RBU-102D-BA
# 7-OST-9H-ESS
# 7-ET-1039D-RN
# 7-ET-1041D-RN
# 7-ET-982D-RN
# 7RCB 0019  BA
# 7FZB 0276  CE
# 7AP  0131  RN
# 7-FAV-122D-BA
# 7-CAM-1191D-RN
# 7-CAM-1237-RN
# 7-CHT-5HA-ESS
# 7-MG-55-SE
# 7-ET-965-RN
# 7-ET-962-RN
# 7-CP-1708-SE
# 7-DJ-834-BA
# 7-GMR-72-RN
# 7-BE-26-RN
# 7-CAM-1278-RN
# 7-IBU-11D-ES
# 7-LOR-73-RN
# 7-CAM-1294D-RN
# 7-RO-533-SE
# 7-SZ-466-SE
# 7-CP-1665D-SE
# 7-CAM-1130-RN
# 7-CP-1726D-SE
# 7-RE-43-RN
# 7-ET-977-RN
# 7-CRT-45HP-RJS
# 7-FZB-811-CE
# 7-FZB-681-CE
# 7-GMR-78-RN
# 7-FZB-779-CE
# 7-MGP-82P-BA
# 7-PML-31-RN
# 7-CP-1503D-SE
# 7-CP-1611D-SE
# 7ARG 0195  RN
# 7AG  0279  BA
# 7-AB-108HP-RJS
# 7-CP-1723D-SE
# 7-CCN-8-ES
# 7-MLS-63HPA-RJS
# 7-CNC-2-ES
# 7-RO-72HPB-RJS
# 7-FP-394-RN
# 7-MP-42D-BA
# 7-RBU-107D-BA
# 7CJ  0011  RN
# 7-FZB-727-CE
# 7-CAM-981-RN
# 7-CP-1555D-SE
# 7-AG-400D-BA
# 7-AR-308D-BA
# 7-CAM-988-RN
# 7-CP-1622D-SE
# 7-ARG-673-RN
# 7-ARG-671-RN
# 7-ET-950-RN
# 7-FBM-236D-BA
# 7-ET-955-RN
# 7-ET-953-RN
# 7-RFQ-41D-RN
# 7-MRL-188HA-RJS
# 7-ET-963-RN
# 7CAM 0419  RN
# 7-ET-1066D-RN
# 7-ET-1060D-RN
# 7-ET-1081D-RN
# 7FP  0058  RN
# 7FZB 0492  CE
# 7CAM 0491D RN
# 7-RO-74HP-RJS
# 7-SZ-487D-SE
# 7-FZB-786-CE
# 7-FZB-787-CE
# 7-FZB-789-CE
# 7-FZB-770-CE
# 7-FZB-694-CE
# 7-FZB-693-CE
# 7-FZB-685-CE
# 7-FP-348-RN
# 7-FP-329D-RN
# 7-RBU-98D-BA
# 7-ET-942-RN
# 7RO  0114  SE
# 7-BAL-66-RN
# 7-RO-541-SE
# 7-MG-66-SE
# 7-RO-580D-SE
# 7-SZ-522D-SE
# 7-CAM-1123-RN
# 7-RO-570-SE
# 7-ARG-743-RN
# 7-SA-7HP-RJS
# 7-DJ-830-BA
# 7-RO-526-SE
# 7-CAM-1260-RN
# 7-CAM-1262-RN
# 7-CAM-1263-RN
# 7-MRL-185HPA-RJS
# 7-FZB-761-CE
# 7-CP-1582D-SE
# 7-CAM-995-RN
# 7-FZB-755-CE
# 7-CAM-1200-RN
# 7-CAM-1039D-RN
# 7-FZB-735-CE
# 7-CP-1641-SE
# 7-POL-2HPB-RJS
# 7-CP-1750D-SE
# 7-CAM-1075-RN
# 7-BR-68-RN
# 7-FZB-753-CE
# 7-CP-1764D-SE
# 7-JUB-11HPA-ESS
# 7-IBU-13D-ES
# 7-ML-40D-BA
# 7-CP-1720D-SE
# 7-CP-1732D-SE
# 7-CP-1598D-SE
# 7-ARG-661-RN
# 7-CAM-1077-RN
# 7-CAM-1078-RN
# 7-CAM-1238-RN
# 7-CAM-1228-RN
# 7-CAM-1138D-RN
# 7-PIR-242D-AL
# 7-CAM-1264-RN
# 7-CAM-1072-RN
# 7-CAM-1188D-RN
# 7-CAM-1137-RN
# 7-CAM-1107-RN
# 7-CAM-1145D-RN
# 7-CAM-1121-RN
# 7-CP-1760D-SE
# 7-FZB-782-CE
# 7-AG-413D-BA
# 7-ET-984-RN
# 7-ET-986-RN
# 7RBU 0042  BA
# 7VM  0064D RJS
# 7CAM 0083  RN
# 7-TGA-2D-BA
# 7-ET-987-RN
# 7-FZB-807-CE
# 7-CAM-1232-RN
# 7-CAM-1169-RN
# 7-AR-313D-BA
# 7-BAL-59-RN
# 7-SZ-497-SE
# 7-SZ-489-SE
# 7-ET-960-RN
# 7-AR-310D-BA
# 7-PIR-241D-AL
# 7-ET-967-RN
# 7-ET-966-RN
# 7-CAC-26D-RN
# 7-LV-49D-RN
# 7-BA-417-BA
# 7-FBM-234D-BA
# 7-PTS-8-RN
# 7-CP-1751-SE
# 7-CP-1685D-SE
# 7-POL-7HP-RJS
# 7-FZB-774-CE
# 7-FZB-776-CE
# 7-CP-1686-SE
# 7-MRL-196HP-RJS
# 7-CAM-1329-RN
# 7-ARG-717-RN
# 7-CAM-1113D-RN
# 7C   0006  BA
# 7ARG 0124  RN
# 7SI  0028  BA
# 7-CAM-1248-RN
# 7-CP-1807-SE
# 7-ARG-666-RN
# 7-CP-1714D-SE
# 7-CP-1810D-SE
# 7-CAM-1199-RN
# 7-CAM-1182-RN
# 7-CAM-1203-RN
# 7-CAM-1022-RN
# 7-FSL-38-ES
# 7-ARG-688-RN
# 7-CP-1568-SE
# 7-JND-45D-BA
# 7-ARG-691-RN
# 7-SZ-490-SE
# 7-CP-1804-SE
# 7-ARG-674-RN
# 7-CAM-1229-RN
# 7-CP-1614-SE
# 7-RBU-99D-BA
# 7-FZB-783-CE
# 7-MLL-40HP-RJS
# 7-CAM-1166-RN
# 7-CAM-1170-RN
# 7-CAM-1212D-RN
# 7-ET-974-RN
# 7-ET-975-RN
# 7FU  0050  AL
# 7FU  0052  AL
# 7FZB 0092  CE
# 7ARG 0013  RN
# 7-CAM-1003-RN
# 7-CAM-1007-RN
# 7-FP-361-RN
# 7-CAM-969-RN
# 7-MLS-111HP-RJS
# 7-CAM-1194-RN
# 7-CAM-1236-RN
# 7-ROU-32D-BA
# 7-ET-968-RN
# 7-CAM-1074-RN
# 7-CAM-1092-RN
# 7-CAM-1189D-RN
# 7-FZB-808-CE
# 7-CAM-1081-RN
# 7-SER-20D-RNS
# 7-FZB-793-CE
# 7-FZB-743-CE
# 7-CAM-1127-RN
# 7-ARG-682-RN
# 7-JND-36DP-BA
# 7-CP-1815DP-SE
# 7-ARG-678-RN
# 7-CAM-1084-RN
# 7-CAM-1033D-RN
# 7-CAM-1148-RN
# 7-CAM-1083-RN
# 7-CAM-1142-RN
# 7-CP-10-ES
# 7-RO-569-SE
# 7-ML-43D-BA
# 7-CP-12-ES
# 7-FBE-54D-BA
# 7-CAM-1205-RN
# 7-CAM-1219-RN
# 7-ARG-695-RN
# 7-PTS-6-RN
# 7-ARG-693-RN
# 7-CAM-1227-RN
# 7-IBU-2D-ES
# 7-FZB-742-CE
# 7-ARG-679-RN
# 7-CP-1664D-SE
# 7-ET-978-RN
# 7-ML-39-BA
# 7-ARG-702-RN
# 7-ARG-703-RN
# 7-ARG-704-RN
# 7-RFQ-43D-RN
# 7-FZB-697-CE
# 7-CAM-1071-RN
# 7-ET-989-RN
# 7-CAM-1289-RN
# 7-ET-973-RN
# 7-OST-2H-ESS
# 7-OST-1H-ESS
# 7-CAM-1164-RN
# 7-PRM-9-SES
# 7FP  0012  RN
# 7ARG 0095  RN
# 7ET  0064  RN
# 7FZB 0251  CE
# 7ARG 0099  RN
# 7CP  1299D SE
# 7CAM 0375  RN
# 7AP  0085  RN
# 7CAM 0608  RN
# 7-RPO-22-ES
# 7-PC-17-RN
# 7-FZB-780-CE
# 7-FZB-781-CE
# 7-MRL-190HP-RJS
# 7-JND-39D-BA
# 7-CP-1809D-SE
# 7-RO-527-SE
# 7-CAM-1176-RN
# 7-FZB-738-CE
# 7-ET-940-RN
# 7-ARG-676-RN
# 7-ARG-675-RN
# 7-CP-1634D-SE
# 7-SZ-478-SE
# 7-CP-1761-SE
# 7-CAM-1224-RN
# 7-POL-12H-RJS
# 7-MRL-183HP-RJS
# 7-CP-1510D-SE
# 7-MLL-28HP-RJS
# 7-CP-1633-SE
# 7-FZB-726-CE
# 7-FZB-734-CE
# 7-FZB-736-CE
# 7SZ  0274  SE
# 7FP  0113  RN
# 7PG  0004  RJS
# 7-CAM-1143-RN
# 7-CAM-1140-RN
# 7-CAM-1252-RN
# 7-CAM-1253-RN
# 7-FZB-785-CE
# 7-SER-24DP-RNS
# 7-CAM-1311-RN
# 7-OST-7H-ESS
# 7-CAM-1159-RN
# 7-CAM-1153-RN
# 7-CAM-1152-RN
# 7-ARG-664-RN
# 7-ARG-663-RN
# 7-PM-50HP-RJS
# 7-IBU-8-ES
# 7-CP-1798-SE
# 7-CP-1632-SE
# 7-MP-36D-BA
# 7-LV-50D-RN
# 7-FBE-50D-BA
# 7-CAM-1186-RN
# 7-ET-956-RN
# 7-CAM-1110-RN
# 7-LAR-10-RN
# 7-MRL-198HP-RJS
# 7-MAG-67-RN
# 7-MAG-69-RN
# 7-DJ-828-BA
# 7-MAG-68-RN
# 7-MAG-74-RN
# 7-CAM-1293-RN
# 7-CP-1661-SE
# 7-CAM-1136-RN
# 7-DJ-791-BA
# 7-RO-511-SE
# 7-DJ-792-BA
# 7-CP-1554-SE
# 7-BAL-55-RN
# 7-MG-64-SE
# 7-FZB-819-CE
# 7-SZ-455D-SE
# 7-SCR-88D-RN
# 7-SCR-84D-RN
# 7-FZB-797-CE
# 7-RBU-100D-BA
# 7-CAM-1080-RN
# 7-ET-947-RN
# 7-FZB-765-CE
# 7-ARG-680-RN
# 7-LV-53D-RN
# 7-SCR-87DA-RN
# 7-CAM-1108-RN
# 7-POL-14H-RJS
# 7-CAM-1064-RN
# 7-SCR-71D-RN
# 7-SZ-511-SE
# 7-AB-110HP-RJS
# 7-FI-112D-BA
# 7-RCB-76D-BA
# 7-FZB-749-CE
# 7-FSR-43-ES
# 7-ARG-749-RN
# 7-CP-1838DP-SE
# 7-MLS-115HP-RJS
# 7-FZB-757-CE
# 7-CP-1745D-SE
# 7-CP-1721D-SE
# 7-FP-362-RN
# 7-MAG-63-RN
# 7-ET-951-RN
# 7-MLL-32HPB-RJS
# 7-SZ-479D-SE
# 7-CAM-1029-RN
# 7-CAM-1031-RN
# 7-CP-1684D-SE
# 7-CP-1602D-SE
# 7-LOR-71HA-RN
# 7-FO-9D-BA
# 7-ET-983-RN
# 7-ET-1005-RN
# 7-RO-546-SE
# 7-CAM-1103-RN
# 7-CAM-1333-RN
# 7-LAR-13-RN
# 7-CAM-1118D-RN
# 7-ARG-686-RN
# 7-ARG-672-RN
# 7-CP-1579D-SE
# 7-CP-1578D-SE
# 7-FZB-714-CE
# 7-CAM-1116-RN
# 7-ET-964-RN
# 7-CAM-1175-RN
# 7-FZB-814-CE
# 7-PV-5-RN
# 7-CAM-1184D-RN
# 7-CAM-1247-RN
# 7-RO-76H-RJS
# 7-FP-371-RN
# 7-BVS-64-RN
# 7-CAM-1147-RN
# 7-RE-41-RN
# 7-FZB-708-CE
# 7-CAM-937-RN
# 7-ET-971-RN
# 7-ARG-736-RN
# 7FZB 0434  CE
# 7RBU 0031  BA
# 7-GMR-79-RN
# 7-LV-54D-RN
# 7-RO-572-SE
# 7-ET-1047-RN
# 7-ET-1068-RN
# 7-SZ-486D-SE
# 7-ARG-696-RN
# 7-ARG-694-RN
# 7-ET-958-RN
# 7-CP-1775-SE
# 7-CAM-1079-RN
# 7-MG-61-SE
# 7-CP-1743-SE
# 7-CP-1640D-SE
# 7-ARG-657-RN
# 7-SZ-477D-SE
# 7-CAM-1086-RN
# 7-FZB-747-CE
# 7-RO-516D-SE
# 7-CP-1738-SE
# 7-CAM-1174-RN
# 7-CAM-1225-RN
# 7-ET-972-RN
# 7-ET-970-RN
# 7-FZB-728-CE
# 7-LOR-66D-RN
# 7-RPO-24-ES
# 7-ET-1067D-RN
# 7ARG 0133  RN
# 7RP  0005  RN
# 7-AR-316D-BA
# 7-DJ-824-BA
# 7-FBL-18D-BA
# 7-CCN-6-ES
# 7-SCR-72D-RN
# 7-MP-34D-BA
# 7-CRT-40HP-RJS
# 7-MAG-58-RN
# 7-PC-16-RN
# 7-MAG-61-RN
# 7-FZB-700-CE
# 7-MAG-60-RN
# 7-ET-945-RN
# 7-CAM-1472-RN
# 7-ASB-7D-RN
# 7-FBE-61D-BA
# 7-ET-1100D-RN
# 7CAM 0762  RN
# 7-ARG-510-RN
# 7TQ  0077  BA
# 7LP  0009  ES
# 7AR  0167  BA
# 7NMR 0010  RN
# 7-LV-67D-RN
# 7-CS-239D-BA
# 7-ET-1268D-RN
# 7-CAM-1407D-RN
# 7-MAG-86-RN
# 7-ET-1809D-RN
# 7-ET-1525-RN
# 7-FZB-659-CE
# 7-RO-162HP-RJS
# 7MA  0014D RJS
# 7-CAM-1483-RN
# 7RO  0239  SE
# 7BA  0151  BA
# 7CS  0082  BA
# 7CS  0093  BA
# 7CP  1081  SE
# 7CM  0069D SES
# 7FAV 0088  BA
# 7-ET-1138-RN
# 7-MG-93D-SE
# 7VM  0037D RJS
# 7FBM 0034  BA
# 7RPO 0018  ES
# 7RO  0093  BA
# 7-FZB-673-CE
# 7-CP-1460-SE
# 7-JND-26D-BA
# 7CP  0036  SE
# 7-BE-33-RN
# 7CAM 0636  RN
# 7-FP-429-RN
# 7-MOR-19-RN
# 7C   0212D BA
# 7ET  0298  RN
# 7FI  0094  BA
# 7FZB 0381  CE
# 7FP  0223  RN
# 7BA  0073  BA
# 7CP  1390  SE
# 7ARG 0080  RN
# 7FZB 0231  CE
# 7CP  0035  SE
# 7CP  0086  SE
# 7CP  0100  SE
# 7CP  0172  SE
# 7-GMR-101-RN
# 7PJ  0021  RN
# 7-RO-716-SE
# 7RO  0238  SE
# 7SM  0015  ES
# 7MAG 0023  RN
# 7FMQ 0026  RN
# 7-TQ-226D-BA
# 7-CP-1964D-SE
# 7CM  0032D SES
# 7SZ  0194  SE
# 7AR  0197  BA
# 7CP  0605  SE
# 7MG  0120  BA
# 7CP  0495  SE
# 7-FAL-93-ES
# 7RP  0046  RN
# 7-FP-452D-RN
# 7-FZB-1000-CE
# 7-ARG-795-RN
# 7RO  0129  SE
# 7C   0202D BA
# 7BA  0214  BA
# 7ROV 0021  BA
# 7BAL 0018  RN
# 7CAM 0049  RN
# 7CS  0111  BA
# 7ET  0333  RN
# 7ROU 0014  BA
# 7ET  0114  RN
# 7ET  0098  RN
# 7ARG 0116  RN
# 7NA  0007  RJS
# 7-ARG-584-RN
# 7REP 0052  RN
# 7-ET-1241D-RN
# 7MO  0069D RN
# 7CP  0326  SE
# 7CRP 0016D RJS
# 7ARG 0250  RN
# 7TQ  0131  BA
# 7LV  0034  RN
# 7-CAM-807D-RN
# 7PIR 0152D AL
# 7NA  0043D RJS
# 7AG  0314  BA
# 7CP  0607  SE
# 7AG  0316  BA
# 7FZB 0034  CE
# 7RO  0281  SE
# 7FP  0027  RN
# 7CP  0234  SE
# 7ET  0071  RN
# 7FZB 0495  CE
# 7-CAM-982-RN
# 7AG  0365  BA
# 7CAM 0634  RN
# 7AP  0220  RN
# 7ARG 0465  RN
# 7C   0112  BA
# 7FO  0005  BA
# 7-ARG-631-RN
# 7CAM 0713  RN
# 7-CP-1541D-SE
# 7-RI-41D-BA
# 7CN  0067D RN
# 7CH  0042DPRJS
# 7-ET-1519-RN
# 7-FU-140D-AL
# 7-CL-92D-SE
# 7-FAL-127D-ES
# 7-ET-991-RN
# 7BA  0203  BA
# 7ET  0111  RN
# 7FZB 0107  CE
# 7FZB 0125  CE
# 7FZB 0211  CE
# 7CP  1366D SE
# 7-AR-330D-BA
# 7-FP-419D-RN
# 7FQ  0047  ES
# 7CAM 0618  RN
# 7CN  0020  RN
# 7-RO-495-SE
# 7-CP-1553D-SE
# 7-FP-355-RN
# 7-BJ-12-BA
# 7-ET-1518-RN
# 7CP  0318  SE
# 7AR  0161  BA
# 7ROV 0010  BA
# 7FBM 0115  BA
# 7FBM 0138  BA
# 7-BAZ-4-ESS
# 7-FMQ-35-RN
# 7-RO-642D-SE
# 7-ET-1123D-RN
# 7-SZ-612D-SE
# 7-CP-1946-SE
# 7-CP-1897-SE
# 7-DJ-876H-BA
# 7-CAM-961-RN
# 7-ET-893-RN
# 7BA  0132  BA
# 7FSE 0012  BA
# 7PIR 0076  AL
# 7FZB 0341  CE
# 7-CP-1462-SE
# 7-MAG-30-RN
# 7-AR-362D-BA
# 7-CP-1704-SE
# 7-FP-402-RN
# 7-FMQ-41-RN
# 7FU  0017  AL
# 7AR  0087  BA
# 7ARG 0150  RN
# 7ET  0197  RN
# 7PIR 0027  AL
# 7BEN 0006  RN
# 7REP 0042  RN
# 7-FAL-10H-ES
# 7FP  0191  RN
# 7AP  0237  RN
# 7-FAV-128D-BA
# 7-FZB-891-CE
# 7-RO-702-SE
# 7-CAM-1488-RN
# 7-SZ-605D-SE
# 7-BR-75-RN
# 7-ET-1158-RN
# 7-CLD-16-RN
# 7FAV 0005  BA
# 7AG  0090  BA
# 7BA  0060  BA
# 7RCB 0006  BA
# 7CP  0609  SE
# 7FZB 0090  CE
# 7FZB 0208  CE
# 7SZ  0338  SE
# 7-AR-322D-BA
# 7-CX-97D-BA
# 7-ET-1159D-RN
# 7-ET-1226D-RN
# 7CN  0040D RN
# 7CAM 0221  RN
# 7-GMR-68-RN
# 7-FZB-668-CE
# 7-SMI-30-RN
# 7-FZB-701-CE
# 7RO  0188  SE
# 7RO  0195  SE
# 7CP  0268  SE
# 7FBM 0100  BA
# 7FBM 0120  BA
# 7MG  0019  SE
# 7FBM 0167  BA
# 7-LL-28D-RJS
# 7-FZB-905-CE
# 7-ET-1168-RN
# 7-PML-38-RN
# 7-RO-521-SE
# 7-CP-1603-SE
# 7-FBM-241D-BA
# 7AR  0148  BA
# 7CP  0345  SE
# 7ET  0359  RN
# 7ARG 0307  RN
# 7BAL 0021  RN
# 7MRL 0069  RJS
# 7-RO-470-SE
# 7PL  0065  RN
# 7-CAM-865-RN
# 7CP  0026  SE
# 7CP  0094  SE
# 7-FBM-265D-BA
# 7-FAV-129D-BA
# 7FP  0115  RN
# 7FZB 0357B CE
# 7SZ  0320  SE
# 7ET  0286  RN
# 7CN  0055D RN
# 7FP  0221  RN
# 7CAM 0759  RN
# 7-RO-463D-SE
# 7AR  0122  BA
# 7FZB 0274  CE
# 7-ET-1425D-RN
# 7-SER-37D-RNS
# 7-RO-718-SE
# 7-CLD-14-RN
# 7-AR-351D-BA
# 7-FAL-105D-ES
# 7-MAG-83-RN
# 7-ET-1454-RN
# 7-FP-438-RN
# 7-MLS-220HA-RJS
# 7-PML-40-RN
# 7-ET-1442D-RN
# 7-ET-1389-RN
# 7-CNC-37-ES
# 7CP  1215  SE
# 7CP  1114  SE
# 7CAM 0050  RN
# 7-CAM-1367D-RN
# 7-ET-1195D-RN
# 7-PV-10-RN
# 7-PV-12-RN
# 7-FAL-113D-ES
# 7-BA-442D-BA
# 7RP  0115  RN
# 7ARG 0485  RN
# 7IC  0008  CE
# 7AP  0215  RN
# 7ET  0369  RN
# 7FZB 0416  CE
# 7LOR 0024  RN
# 7AP  0053  RN
# 7-CAM-1478-RN
# 7UB  0076D RNS
# 7-LOR-79-RN
# 7FZB 0143  CE
# 7RI  0028  ES
# 7-RO-131HP-RJS
# 7-MRL-218HP-RJS
# 7-CP-1899-SE
# 7-CP-1903D-SE
# 7-RO-693D-SE
# 7-RO-697D-SE
# 7-MRL-208HB-RJS
# 7-CAM-1399D-RN
# 7-BA-446D-BA
# 7-CP-1773-SE
# 7CAM 0067  RN
# 7C   0136R BA
# 7CS  0021  BA
# 7CS  0028  BA
# 7AR  0039  BA
# 7ET  0648  RN
# 7ET  0754  RN
# 7FZB 0086  CE
# 7ARG 0035  RN
# 7FZB 0045  CE
# 7CX  0079D BA
# 7ET  0555  RN
# 7FZB 0103  CE
# 7-SZ-539-SE
# 7-AG-425D-BA
# 7-TQ-199D-BA
# 7-ET-1207D-RN
# 7-ET-1094D-RN
# 7-MLS-159HP-RJS
# 7-ET-1201-RN
# 7-MOR-4-RN
# 7-CAM-784D-RN
# 7-ET-772-RN
# 7FP  0037  BA
# 7CP  1244  SE
# 7CS  0168  BA
# 7CP  1236D SE
# 7TQ  0170  BA
# 7CAM 0281  RN
# 7CAM 0316  RN
# 7-CP-1787-SE
# 7-AR-354D-BA
# 7BA  0099  BA
# 7FP  0083  RN
# 7MG  0350  BA
# 7FI  0063  BA
# 7RI  0057  ES
# 7SE  0017  RN
# 7AR  0220  BA
# 7-CAM-1381D-RN
# 7-FAL-111D-ES
# 7-RI-46D-BA
# 7-JUB-31H-ESS
# 7AP  0273D RN
# 7RP  0119  RN
# 7CM  0028D SES
# 7ML  0026  BA
# 7RI  0025  ES
# 7-RBU-124D-BA
# 7-LL-58-RJS
# 7-GMR-106-RN
# 7-ET-1369-RN
# 7-RO-123HP-RJS
# 7-RO-115-RJS
# 7-RO-613-SE
# 7-RI-48D-BA
# 7-CS-210-BA
# 7-MJ-77-BA
# 7-CNC-7-ES
# 7-ET-1181-RN
# 7-SCR-114D-RN
# 7-CP-1511-SE
# 7SZ  0176  SE
# 7PL  0008  RN
# 7CAM 0478  RN
# 7-CAM-1397-RN
# 7CAM 0542D RN
# 7ARG 0357  RN
# 7CAM 0567  RN
# 7-PJ-40-RN
# 7-CAM-897-RN
# 7-FBM-229D-BA
# 7-CP-1647D-SE
# 7-JCT-5-ES
# 7-SZ-536D-SE
# 7-RO-629-SE
# 7-ET-1210-RN
# 7-SER-27D-RNS
# 7-ET-1221-RN
# 7-JCT-4D-ES
# 7-MRL-213HA-RJS
# 7-AR-341D-BA
# 7-SZ-558-SE
# 7AB  0012D RJS
# 7CAM 0369  RN
# 7SZ  0262  SE
# 7RP  0085  RN
# 7-CP-1471D-SE
# 7-CAM-1027-RN
# 7CP  0378  SE
# 7CP  0320  SE
# 7AG  0014D RNS
# 7CP  0305  SE
# 7-FBM-272D-BA
# 7-FAL-109D-ES
# 7-RO-107HP-RJS
# 7-FAL-108-ES
# 7-FZB-802-CE
# 7-ET-1054D-RN
# 7-ET-1222D-RN
# 7-RO-531D-SE
# 7-MAG-92-RN
# 7-MAG-77-RN
# 7-RO-710-SE
# 7-DJ-850H-BA
# 7-AG-409D-BA
# 7-ML-48D-BA
# 7-JCT-3D-ES
# 7ET  0567  RN
# 7ARG 0344  RN
# 7XA  0022D CES
# 7FZB 0236  CE
# 7GP  0013D RJS
# 7FAV 0058  BA
# 7RBU 0040  BA
# 7-MLS-177HP-RJS
# 7-CP-1893-SE
# 7-CP-1878D-SE
# 7-FP-57D-BA
# 7-LV-62-RN
# 7-CNC-8-ES
# 7-BA-436D-BA
# 7-CAM-1416-RN
# 7-ET-1109D-RN
# 7-RO-556-SE
# 7-CAM-1134D-RN
# 7FP  0211  RN
# 7-RO-469D-SE
# 7CAM 0149  RN
# 7CAM 0163  RN
# 7CAM 0035  RN
# 7-FZB-843-CE
# 7-CAM-1511-RN
# 7-FZB-806-CE
# 7-FP-440D-RN
# 7-CP-1951D-SE
# 7-FBE-64D-BA
# 7-FBE-59D-BA
# 7-RO-675-SE
# 7-FBM-273D-BA
# 7-FI-117D-BA
# 7-ET-1052-RN
# 7-PC-26-RN
# 7-CAM-1408-RN
# 7-SER-31D-RNS
# 7-SER-28D-RNS
# 7REP 0009  RN
# 7ARG 0482  RN
# 7ET  0644  RN
# 7FMQ 0023  RN
# 7ET  0749  RN
# 7RP  0120  RN
# 7-JUB-53H-ESS
# 7-RFQ-50D-RN
# 7-CAM-1467D-RN
# 7BA  0355D BA
# 7-CAM-1448-RN
# 7-CAM-1442D-RN
# 7-RO-650-SE
# 7-DJ-848H-BA
# 7-RO-654-SE
# 7-CAM-1388D-RN
# 7-TQ-206D-BA
# 7-MAG-107-RN
# 7-ML-52D-BA
# 7-MAG-102-RN
# 7-MAG-109-RN
# 7-RO-129H-RJS
# 7BA  0379D BA
# 7RP  0125  RN
# 7CP  1090  SE
# 7ARG 0293  RN
# 7REP 0019  RN
# 7ET  0143  RN
# 7ET  0230  RN
# 7ET  0680D RN
# 7CP  1412D SE
# 7-DJ-813H-BA
# 7-MP-48D-BA
# 7-ET-1187-RN
# 7-ET-1170D-RN
# 7-ET-1197D-RN
# 7-ET-1203D-RN
# 7-BA-435-BA
# 7-CNC-28-ES
# 7-RO-641D-SE
# 7-ET-1176D-RN
# 7-MRL-220HP-RJS
# 7-ET-1179-RN
# 7PIR 0151D AL
# 7-FAL-101D-ES
# 7-MG-504D-BA
# 7-MP-49D-BA
# 7-ET-1102D-RN
# 7-CP-1687-SE
# 7-LV-59-RN
# 7-FAL-104D-ES
# 7-PC-35D-RN
# 7-CL-66D-SE
# 7-DJM-882H-BAS
# 7-ET-1413D-RN
# 7-CP-1628D-SE
# 7-GMR-93-RN
# 7-GMR-94-RN
# 7-ET-1523D-RN
# 7-ET-1522-RN
# 7-ET-1374-RN
# 7-FAL-115D-ES
# 7-FAL-116D-ES
# 7-CP-1895-SE
# 7-FBE-62D-BA
# 7-BAZ-3-ESS
# 7-CAM-1361D-RN
# 7-CAM-1360D-RN
# 7-CAM-1359D-RN
# 7-CAM-1324D-RN
# 7-FAL-96-ES
# 7-PC-27-RN
# 7AG  0068  BA
# 7-LOR-88-RN
# 7-SZ-573-SE
# 7-PTS-14-RN
# 7-SZ-577D-SE
# 7-CAM-1471D-RN
# 7-MAG-78-RN
# 7-SER-33D-RNS
# 7-RO-679-SE
# 7FZB 0289  CE
# 7ET  0100  RN
# 7ET  0083  RN
# 7ARG 0012  RN
# 7ET  0728D RN
# 7-ET-949-RN
# 7-JND-44D-BA
# 7-CAM-1245-RN
# 7-BR-67-RN
# 7FU  0068  AL
# 7-ARG-758-RN
# 7-ET-1166D-RN
# 7-BR-72-RN
# 7FZB 0284  CE
# 7RBU 0079D BA
# 7AP  0282  RN
# 7RP  0146  RN
# 7BRG 0017  SE
# 7PG  0010D RJS
# 7FBM 0088  BA
# 7ET  0351  RN
# 7-RO-109D-BA
# 7-ET-1301-RN
# 7RO  0260  SE
# 7CP  0550  SE
# 7CP  0327  SE
# 7-FBL-22D-BA
# 7-AR-319D-BA
# 7-MLS-179HP-RJS
# 7-AR-336D-BA
# 7-AC-2-RN
# 7-ARG-757-RN
# 7MAG 0018  RN
# 7-RBU-118D-BA
# 7-AG-418DP-BA
# 7-SCR-132-RN
# 7-SZ-636-SE
# 7-JUB-51H-ESS
# 7BA  0068  BA
# 7ET  0044  RN
# 7CB  0030D SES
# 7-CAM-862-RN
# 7-ET-796-RN
# 7CAM 0728  RN
# 7CAM 0742  RN
# 7CAM 0737  RN
# 7FU  0027  AL
# 7PIR 0040  AL
# 7RBU 0057  BA
# 7CM  0011D SES
# 7MA  0017D RJS
# 7CAM 0506  RN
# 7BA  0062  BA
# 7GA  0055D SES
# 7GA  0023D SES
# 7AR  0173  BA
# 7ARG 0134  RN
# 7RPO 0017  ES
# 7RO  0420  SE
# 7CAM 0687  RN
# 7PJ  0008  RN
# 7AG  0007  SE
# 7BA  0012  BA
# 7BR  0031  RN
# 7CP  0061  SE
# 7CH  0023D RJS
# 7ET  0319  RN
# 7RP  0068  RN
# 7RM  0010  ES
# 7RPO 0014  ES
# 7FC  0029  ES
# 7CAM 0722  RN
# 7CAM 0741  RN
# 7-BVS-58-RN
# 7BVS 0033  RN
# 7MJ  0011  BA
# 7AG  0009D RNS
# 7ARG 0171  RN
# 7XA  0028D CES
# 7FBM 0112  BA
# 7CAM 0074  RN
# 7CP  1112  SE
# 7UB  0028D RNS
# 7FZB 0338  CE
# 7ARG 0217  RN
# 7ARG 0501  RN
# 7-RO-106-BA
# 7-RI-42D-BA
# 7-LOR-51-RN
# 7BA  0250  BA
# 7FP  0093  RN
# 7-ET-1322D-RN
# 7-SPH-17-SPS
# 7-CNC-35-ES
# 7-RO-158HP-RJS
# 7RO  0020  SE
# 7CP  0060  SE
# 7FZB 0070  CE
# 7CP  1177D SE
# 7FC  0006  RN
# 7FZB 0453  CE
# 7DJ  0104  BA
# 7MJ  0010  BA
# 7SZ  0098  SE
# 7RO  0071  SE
# 7ARG 0207  RN
# 7-FP-248-RN
# 7-FP-251-RN
# 7FP  0196  RN
# 7-ET-789-RN
# 7BA  0275  BA
# 7ET  0146  RN
# 7TM  0041D AL
# 7RPO 0003  ES
# 7RCB 0017  BA
# 7FZB 0458  CE
# 7ARG 0021  RN
# 7ARG 0029  RN
# 7ARG 0038  RN
# 7CP  0714  SE
# 7CAM 0616  RN
# 7CP  0324  SE
# 7ARG 0076  RN
# 7CP  0169  SE
# 7FZB 0158  CE
# 7ET  0362  RN
# 7ET  0331  RN
# 7VM  0016D RJS
# 7ET  0586  RN
# 7FZB 0517  CE
# 7FZB 0528  CE
# 7-LOR-67-RN
# 7-FBE-46D-BA
# 7-ET-1357D-RN
# 7-PAT-1D-RN
# 7NFC 0021  BA
# 7CAM 0021  RN
# 7-ET-1029-RN
# 7-RO-536-SE
# 7CS  0136  BA
# 7AR  0271  BA
# 7FQ  0042  ES
# 7AR  0072  BA
# 7PL  0051  RN
# 7TQ  0167  BA
# 7FP  0139  RN
# 7ARG 0226  RN
# 7CP  0654  SE
# 7ET  0255  RN
# 7-ET-1331D-RN
# 7AG  0362D BA
# 7ET  0500  RN
# 7FZB 0520  CE
# 7CRP 0055D RJS
# 7VR  0014  RN
# 7-AG-386-BA
# 7CP  1331D SE
# 7BR  0016  RN
# 7CAM 0303  RN
# 7CP  1175  SE
# 7RI  0019  ES
# 7CB  0026D SES
# 7CAC 0008  RN
# 7CP  1096  SE
# 7FQ  0023  ES
# 7BR  0018  RN
# 7CX  0078D BA
# 7CAM 0625  RN
# 7CN  0031D RN
# 7GMR 0052  RN
# 7FBM 0133  BA
# 7RCB 0020  BA
# 7ET  0055  RN
# 7CN  0016  RN
# 7CP  1156  SE
# 7ARG 0502  RN
# 7-RO-447-SE
# 7CP  0238  SE
# 7CB  0014D SES
# 7CAM 0679  RN
# 7RPJ 0060D BA
# 7FZB 0565D CE
# 7FP  0136  RN
# 7VM  0039D RJS
# 7ARG 0487  RN
# 7MRL 0084HPRJS
# 7CP  1000  SE
# 7CX  0023  BA
# 7PG  0012D RJS
# 7RCB 0065  BA
# 7-ET-1040D-RN
# 7CAM 0690  RN
# 7CS  0140  BA
# 7-ARG-713-RN
# 7-CCN-7-ES
# 7FU  0048  AL
# 7ET  0312  RN
# 7FP  0161  RN
# 7CRP 0040D RJS
# 7FBM 0056  BA
# 7VM  0019D RJS
# 7PG  0016D RJS
# 7PG  0014D RJS
# 7AG  0148  BA
# 7FZB 0259  CE
# 7FP  0041  RN
# 7FP  0049  RN
# 7AP  0013  RN
# 7CP  1261D SE
# 7AR  0239  BA
# 7-FZB-643-CE
# 7GMR 0013  RN
# 7FZB 0311  CE
# 7CAM 0253  RN
# 7CP  1194  SE
# 7C   0047  BA
# 7-ET-1036D-RN
# 7FZB 0154  CE
# 7FZB 0371  CE
# 7CRP 0015D RJS
# 7-BR-60HP-RJS
# 7BA  0270  BA
# 7FZB 0188  CE
# 7REP 0064  RN
# 7BA  0378D BA
# 7BA  0081  BA
# 7AG  0269  BA
# 7FZB 0053  CE
# 7FZB 0205  CE
# 7FZB 0041  CE
# 7FZB 0087  CE
# 7FZB 0112  CE
# 7CAM 0565D RN
# 7RP  0067  RN
# 7FBM 0076  BA
# 7-CAM-1198D-RN
# 7-CP-1747D-SE
# 7ET  0113  RN
# 7-FSR-41-ES
# 7-MLL-42HP-RJS
# 7VM  0009D RJS
# 7CAM 0288  RN
# 7RE  0032  RN
# 7AP  0031  RN
# 7RBU 0037  BA
# 7CAM 0552D RN
# 7-CP-1739D-SE
# 7-ARG-683-RN
# 7-RBU-93D-BA
# 7-RO-75HP-RJS
# 7-MP-37D-BA
# 7ARG 0274  RN
# 7ARG 0439  RN
# 7AB  0023D RJS
# 7ET  0481  RN
# 7CP  1241D SE
# 7GMR 0024  RN
# 7RCB 0040  BA
# 7TQ  0174  BA
# 7CAM 0293  RN
# 7CP  1193  SE
# 7UB  0094D RNS
# 7CP  0964  SE
# 7ARG 0234  RN
# 7ET  0329  RN
# 7AP  0062  RN
# 7ARG 0457  RN
# 7FBM 0163  BA
# 7-FZB-804-CE
# 7FI  0018  BA
# 7CP  0070  SE
# 7-RE-40-RN
# 7-RO-682D-SE
# 7-TQ-207D-BA
# 7-ML-53D-BA
# 7-CAM-1417-RN
# 7-MAG-82-RN
# 7-JND-40D-BA
# 7-CER-32D-BA
# 7-RO-563-SE
# 7-RFQ-47D-RN
# 7-FZB-848-CE
# 7-ET-1111D-RN
# 7-ET-1075D-RN
# 7-MG-41-SE
# 7-ET-1065D-RN
# 7-ET-1089D-RN
# 7-CAM-1401-RN
# 7-TQ-196D-BA
# 7-ET-1063D-RN
# 7-ET-1095-RN
# 7-MG-503D-BA
# 7-RO-637D-SE
# 7-AR-337D-BA
# 7-FAL-110D-ES
# 7-PC-32D-RN
# 7-FBM-264D-BA
# 7-CAM-1396-RN
# 7-CP-1767D-SE
# 7-FBM-249D-BA
# 7-ET-1106D-RN
# 7-FSR-49-ES
# 7-MG-506D-BA
# 7-BA-445D-BA
# 7-RO-111HP-RJS
# 7-FAL-107-ES
# 7-FZB-846-CE
# 7-FZB-836-CE
# 7-RO-597D-SE
# 7-ET-1048D-RN
# 7-CAM-1257D-RN
# 7-FP-400-RN
# 7-ET-1049D-RN
# 7RP  0061  RN
# 7UB  0105D RNS
# 7ET  0330  RN
# 7-FMQ-42-RN
# 7-FI-115D-BA
# 7-CAM-1362-RN
# 7-SZ-459-SE
# 7-FP-51DP-BA
# 7-MLS-169HP-RJS
# 7-BR-78D-RN
# 7-POL-32HP-RJS
# 7-FZB-841-CE
# 7-FZB-847-CE
# 7-FI-113D-BA
# 7-BR-73-RN
# 7-BR-71-RN
# 7-ET-1160D-RN
# 7-ET-1244D-RN
# 7-ET-1242D-RN
# 7-ARG-767-RN
# 7-MLS-93HP-RJS
# 7-AN-36-SE
# 7-CER-34D-BA
# 7-PML-39-RN
# 7-MAG-85-RN
# 7-MAG-99-RN
# 7-MAG-103-RN
# 7-MAG-98-RN
# 7-SCR-105D-RN
# 7-SCR-108D-RN
# 7-CS-213D-BA
# 7-ET-1245D-RN
# 7-ET-1230-RN
# 7-ET-1240D-RN
# 7-ET-1236D-RN
# 7-ET-1235D-RN
# 7-FBL-24DP-BA
# 7-LV-56D-RN
# 7-LV-63-RN
# 7-LV-64-RN
# 7-FSJ-44D-ES
# 7-FZB-696-CE
# 7RP  0107  RN
# 7REP 0045  RN
# 7-ARG-760-RN
# 7-CAM-1349D-RN
# 7-ET-1025-RN
# 7-MAG-72-RN
# 7-CP-1763-SE
# 7-GMR-87A-RN
# 7-BVS-66-RN
# 7-FP-403-RN
# 7-FP-404-RN
# 7-FP-406-RN
# 7-FP-409-RN
# 7-ET-1172-RN
# 7-ARG-788D-RN
# 7-ARG-783D-RN
# 7-ARG-782D-RN
# 7-ARG-755-RN
# 7-ARG-778-RN
# 7FSL 0021  ES
# 7-ET-1115D-RN
# 7-ARG-775-RN
# 7-CAM-1332D-RN
# 7-RFQ-44D-RN
# 7-SCR-100-RN
# 7-MP-47DP-BA
# 7-CP-1650D-SE
# 7-AR-333D-BA
# 7-FP-410-RN
# 7-FP-411-RN
# 7-MP-43D-BA
# 7-ET-1084D-RN
# 7-CP-1722-SE
# 7-RO-547D-SE
# 7-CAM-1254D-RN
# 7-CP-1801D-SE
# 7-FZB-894-CE
# 7-FAV-126D-BA
# 7-ET-1217-RN
# 7-ARG-794-RN
# 7-FP-422-RN
# 7-BA-438DP-BA
# 7-POL-20H-RJS
# 7-FP-421-RN
# 7-FP-423-RN
# 7-FP-425-RN
# 7-ARG-764-RN
# 7-ET-1105-RN
# 7-ET-1224D-RN
# 7-ET-1093D-RN
# 7-CAM-1378D-RN
# 7-ET-1214-RN
# 7-CNC-10-ES
# 7-BR-73HPA-RJS
# 7-FMQ-40-RN
# 7-FMQ-39-RN
# 7-ET-1174D-RN
# 7-FI-116D-BA
# 7-RO-635-SE
# 7-FP-418-RN
# 7-RO-564D-SE
# 7-JUB-19H-ESS
# 7-FP-420-RN
# 7-ET-1228-RN
# 7-ET-1229-RN
# 7AR  0277  BA
# 7CAM 0348  RN
# 7FBL 0011D BA
# 7BR  0014  RN
# 7CAM 0248  RN
# 7RCB 0070  BA
# 7CP  1246  SE
# 7CAM 0273  RN
# 7-MG-76-SE
# 7-RO-615-SE
# 7-RO-594-SE
# 7-FAL-118-ES
# 7-MA-32D-RN
# 7-RO-124HA-RJS
# 7-MRL-215HP-RJS
# 7-SZ-540-SE
# 7-GMR-91-RN
# 7-GMR-86-RN
# 7-GMR-89-RN
# 7-GMR-90-RN
# 7AP  0070  RN
# 7FZB 0511  CE
# 7FP  0184  RN
# 7-FP-407-RN
# 7-FBM-251D-BA
# 7-URG-10HP-RJS
# 7-RO-596-SE
# 7-RBU-106D-BA
# 7-CP-1637-SE
# 7-RO-77H-RJS
# 7-CAM-1179D-RN
# 7-CAM-1421-RN
# 7FP  0018  BA
# 7CP  0590  SE
# 7FZB 0050  CE
# 7-FP-417D-RN
# 7-ET-1190D-RN
# 7-ET-1183D-RN
# 7-CAM-1440-RN
# 7-CAM-1426D-RN
# 7-CAM-1422-RN
# 7-RPJ-75DP-BA
# 7-RO-684-SE
# 7-AR-327D-BA
# 7-CER-31D-BA
# 7-CAM-1125D-RN
# 7-CAM-1354-RN
# 7-CAM-1350-RN
# 7-ET-1180-RN
# 7-MLL-49H-RJS
# 7FP  0219  RN
# 7BVS 0048  RN
# 7RFQ 0032D RN
# 7CAM 0758  RN
# 7-FSJ-27H-ES
# 7-MLS-189HP-RJS
# 7-ARI-8-SE
# 7-PC-33D-RN
# 7-BR-76-RN
# 7-BR-77-RN
# 7-BR-74-RN
# 7-RO-653D-SE
# 7-SCR-113D-RN
# 7-SCR-111D-RN
# 7-MLS-157H-RJS
# 7-ET-1131-RN
# 7-ET-1135-RN
# 7-ET-1139-RN
# 7-ET-1145-RN
# 7-ET-1112-RN
# 7-ET-1118-RN
# 7-BA-433D-BA
# 7ET  0030  RN
# 7-ET-1196-RN
# 7-ET-1200-RN
# 7-FBE-63D-BA
# 7-CP-1845D-SE
# 7-MAG-108-RN
# 7-MAG-91-RN
# 7-MAG-89-RN
# 7-MAG-87-RN
# 7-RO-657-SE
# 7-RO-649-SE
# 7-SCR-125D-RN
# 7-ET-1208-RN
# 7-MRL-212HP-RJS
# 7-FP-428-RN
# 7-FP-427-RN
# 7-FP-426-RN
# 7-PTS-11-RN
# 7-PTS-12-RN
# 7-CS-211D-BA
# 7-RO-651D-SE
# 7-LOR-87-RN
# 7-CAM-1430-RN
# 7-JUB-27HP-ESS
# 7-BR-71HP-RJS
# 7-CAM-1412-RN
# 7-CAM-1411D-RN
# 7-ET-1186D-RN
# 7-FSR-44A-ES
# 7-ML-44D-BA
# 7-FBM-257D-BA
# 7-FI-114D-BA
# 7-CP-1765D-SE
# 7-ET-1044D-RN
# 7-ET-1051D-RN
# 7-ET-1146D-RN
# 7-ML-46D-BA
# 7-SCR-139-RN
# 7-AR-363D-BA
# 7-BA-456DP-BA
# 7-CS-233D-BA
# 7-SCR-127-RN
# 7-MO-85-RN
# 7-FMQ-44-RN
# 7-CP-1702-SE
# 7-RO-634-SE
# 7-RO-633-SE
# 7-CAM-1405-RN
# 7-CX-93D-BA
# 7-AR-335D-BA
# 7-RO-691D-SE
# 7-MP-50D-BA
# 7-LV-66D-RN
# 7-BA-443D-BA
# 7-BA-447D-BA
# 7RP  0123  RN
# 7REP 0047  RN
# 7CP  1414D SE
# 7PJ  0005  RN
# 7CN  0058D RN
# 7PG  0025D RJS
# 7PL  0055  RN
# 7-FAL-99D-ES
# 7-FAL-98D-ES
# 7-AR-334D-BA
# 7-DJ-839HA-BA
# 7-JUB-24H-ESS
# 7-FAL-102D-ES
# 7-ET-1064D-RN
# 7-ET-1073D-RN
# 7-RO-703-SE
# 7-MLS-187HP-RJS
# 7-CP-1786D-SE
# 7-ARG-712-RN
# 7-FP-387-RN
# 7-CAM-1151D-RN
# 7-RO-92D-RJS
# 7-RI-47D-BA
# 7-PV-11-RN
# 7-SZ-576D-SE
# 7-RO-699-SE
# 7-SZ-571-SE
# 7-ET-1171D-RN
# 7-ET-1169D-RN
# 7-ET-1193-RN
# 7-ET-1192-RN
# 7-ET-1189-RN
# 7-ET-1191-RN
# 7-RO-598-SE
# 7-SZ-496D-SE
# 7-MRL-207H-RJS
# 7-CP-1713D-SE
# 7-CAM-1394D-RN
# 7-FAL-100-ES
# 7-CAM-1420-RN
# 7-CX-91D-BA
# 7-SCR-101D-RN
# 7-SCR-96-RN
# 7-SCR-117D-RN
# 7-SCR-99-RN
# 7-RO-566-SE
# 7-ET-1038D-RN
# 7-DJ-815H-BA
# 7-ET-1211-RN
# 7-SCR-116D-RN
# 7-AR-332D-BA
# 7-SCR-119-RN
# 7-SCR-122-RN
# 7-RO-630-SE
# 7-FP-416D-RN
# 7-CP-1900D-SE
# 7-CAM-1371D-RN
# 7FZB 0245  CE
# 7ET  0065  RN
# 7SM  0033  ES
# 7ET  0196  RN
# 7-FAL-114D-ES
# 7-RO-680-SE
# 7-RBU-115D-BA
# 7-SZ-561-SE
# 7-CNC-15-ES
# 7-SCR-120-RN
# 7-FMQ-38-RN
# 7-CAM-1413D-RN
# 7-SZ-463D-SE
# 7-CAM-1368D-RN
# 7-ET-1206-RN
# 7-AR-331D-BA
# 7-ET-1213-RN
# 7-ET-1231D-RN
# 7-ET-1233-RN
# 7-ET-1194-RN
# 7-ARG-759-RN
# 7-ARG-761-RN
# 7-ARG-765-RN
# 7-ET-1078D-RN
# 7-ET-1234-RN
# 7-CP-1741D-SE
# 7-BR-80HP-RJS
# 7-RO-107D-BA
# 7-JND-66D-BA
# 7-RO-646-SE
# 7-FAV-130D-BA
# 7-FP-58D-BA
# 7-RE-45-RN
# 7-CS-212-BA
# 7-MAG-101-RN
# 7-MAG-100-RN
# 7-MAG-84-RN
# 7-LOR-82-RN
# 7BA  0307  BA
# 7PIR 0132D AL
# 7-MG-39-SE
# 7FBM 0063  BA
# 7MG  0381  BA
# 7LV  0007  RN
# 7FZB 0451  CE
# 7FZB 0156  CE
# 7CP  0655  SE
# 7FZB 0426  CE
# 7-CAM-763-RN
# 7-CAM-1508-RN
# 7-ET-1329-RN
# 7-ET-1440-RN
# 7-ET-1453-RN
# 7-FBL-25D-BA
# 7-ET-1342D-RN
# 7-PML-37-RN
# 7-CAM-1398A-RN
# 7-SER-29D-RNS
# 7-FZB-825-CE
# 7-ET-1392-RN
# 7-ET-1444D-RN
# 7CAM 0624  RN
# 7ARG 0489D RN
# 7CAM 0686  RN
# 7CS  0096  BA
# 7ET  0395  RN
# 7-BR-41-RN
# 7CP  0243  SE
# 7-ET-1248-RN
# 7-CAC-27D-RN
# 7-MA-31D-RNS
# 7-RO-154D-RJS
# 7-ET-1446-RN
# 7-ET-1456D-RN
# 7FZB 0129  CE
# 7ARG 0187  RN
# 7RCB 0047  BA
# 7RP  0055  RN
# 7-TGA-6D-BA
# 7CX  0068  BA
# 7SCR 0018D RN
# 7BA  0122  BA
# 7-CP-1520-SE
# 7-CP-1407-SE
# 7-CP-1892D-SE
# 7-SCR-130D-RN
# 7-RPJ-76D-BA
# 7-ET-1438-RN
# 7-ET-1457-RN
# 7-CP-1909-SE
# 7CP  0370  SE
# 7MG  0250  BA
# 7ARG 0208  RN
# 7CP  0173  SE
# 7AR  0166  BA
# 7ET  0134  RN
# 7ET  0180  RN
# 7GMR 0019  RN
# 7-ET-1429D-RN
# 7-ET-1427D-RN
# 7-FZB-822-CE
# 7-ET-1408D-RN
# 7GO  0008  BA
# 7BA  0145  BA
# 7FZB 0161  CE
# 7SI  0020  BA
# 7FZB 0366  CE
# 7CAM 0438  RN
# 7NFC 0040  BA
# 7MAG 0020  RN
# 7-CAM-780-RN
# 7BA  0212  BA
# 7-MP-52D-BA
# 7-RO-155D-RJS
# 7-ET-1099D-RN
# 7-RE-46-RN
# 7-DJ-886D-BA
# 7-ET-1382D-RN
# 7-ET-1371D-RN
# 7-ET-1334-RN
# 7ET  0250  RN
# 7-ET-1806-RN
# 7-ET-1817-RN
# 7-ET-1819-RN
# 7-PC-21-RN
# 7-ARG-832D-RN
# 7-FP-465-RN
# 7-FP-451-RN
# 7-ARG-791D-RN
# 7-FZB-918-CE
# 7CRP 0046D RJS
# 7BRG 0028  SE
# 7CM  0031D SES
# 7FSL 0026  ES
# 7ET  0190  RN
# 7UB  0092D RNS
# 7RP  0062  RN
# 7ARG 0180  RN
# 7DO  0016  SES
# 7-SCR-135D-RN
# 7-ET-1370-RN
# 7-CP-1961D-SE
# 7-CNC-36-ES
# 7-ET-1390D-RN
# 7-ET-1367D-RN
# 7-ET-1352D-RN
# 7-DJ-892D-BA
# 7-SC-37D-BA
# 7-FZB-883-CE
# 7-FZB-976-CE
# 7-FZB-838-CE
# 7-FZB-1018-CE
# 7-ET-1807-RN
# 7-MRL-224H-RJS
# 7-FP-430-RN
# 7-FP-483-RN
# 7-LPX-21D-RN
# 7-SCR-168D-RN
# 7-GMR-105-RN
# 7-FP-447D-RN
# 7AP  0099  RN
# 7ET  0377  RN
# 7FC  0030  ES
# 7-BR-40-RN
# 7-FAL-9H-ES
# 7FBM 0214D BA
# 7CP  1405  SE
# 7FZB 0207  CE
# 7-JUB-58DPA-ESS
# 7-CP-1952-SE
# 7-PC-22-RN
# 7-FZB-862-CE
# 7-ARG-857-RN
# 7-ARG-837-RN
# 7-ARG-836-RN
# 7-FZB-874-CE
# 7-FP-449D-RN
# 7-FP-441D-RN
# 7-FP-436D-RN
# 7-FP-434D-RN
# 7CAM 0243  RN
# 7-ET-954-RN
# 7-FZB-718-CE
# 7-ARG-684-RN
# 7CP  0534  SE
# 7UB  0078D RNS
# 7-ARG-803-RN
# 7-SC-31D-BA
# 7-SC-32D-BA
# 7-SZ-613-SE
# 7-BA-450D-BA
# 7-BA-452D-BA
# 7UB  0039D RNS
# 7CP  0387  SE
# 7FU  0044D AL
# 7PG  0011D RJS
# 7CAM 0411  RN
# 7BA  0336  BA
# 7AG  0333  BA
# 7-RP-174-RN
# 7-FSR-22D-ES
# 7ARG 0500  RN
# 7ET  0139  RN
# 7-ARG-868-RN
# 7-ET-1401-RN
# 7-ET-1142-RN
# 7-PTS-17-RN
# 7-PRM-5-SES
# 7-CNC-31-ES
# 7-MP-51D-BA
# 7-CS-223-BA
# 7-TQ-213D-BA
# 7-RO-624-SE
# 7-ARG-886D-RN
# 7FZB 0057  CE
# 7AG  0313  BA
# 7-ET-1559-RN
# 7-ET-1564-RN
# 7-FZB-1001-CE
# 7-FP-478-RN
# 7-GMR-92-RN
# 7-SCR-150D-RN
# 7-ARG-839D-RN
# 7-ARG-828-RN
# 7-ET-1813D-RN
# 7BE  0007  RN
# 7CAM 0071  RN
# 7FCN 0027  ES
# 7ET  0416  RN
# 7CP  1160  SE
# 7AN  0027  SE
# 7CS  0039  BA
# 7ET  0199  RN
# 7-ARG-885D-RN
# 7-ARG-888D-RN
# 7-ET-1270D-RN
# 7-ET-1272-RN
# 7-CLD-9-RN
# 7-LL-84D-RJS
# 7-LL-85-RJS
# 7-LL-79D-RJS
# 7-ET-1364D-RN
# 7-ET-1385-RN
# 7-CL-67D-SE
# 7-FZB-903-CE
# 7-FP-471-RN
# 7-FZB-953-CE
# 7-CP-1965D-SE
# 7-ET-1800D-RN
# 7-MAG-95D-RN
# 7-RO-560-SE
# 7FP  0170  RN
# 7CN  0011D RN
# 7CX  0054  BA
# 7CP  1343D SE
# 7SI  0037  BA
# 7MG  0231  BA
# 7-CAM-1465-RN
# 7-RO-148-RJS
# 7-ET-1432-RN
# 7-ET-1424-RN
# 7-ET-1450D-RN
# 7-CAM-1434-RN
# 7-LL-51-RJS
# 7-GMR-104-RN
# 7-ET-1386-RN
# 7-CNC-34-ES
# 7-ARG-824D-RN
# 7-SCR-169D-RN
# 7-BLA-1HA-ESS
# 7-FZB-922-CE
# 7-ARG-819D-RN
# 7-FP-476-RN
# 7-FP-464D-RN
# 7-FP-459D-RN
# 7-FP-445-RN
# 7-FAL-121D-ES
# 7-ET-1805-RN
# 7-CAM-777D-RN
# 7-MLS-37HP-RJS
# 7ARG 0298  RN
# 7SZ  0328  SE
# 7CAM 0051  RN
# 7FAV 0096  BA
# 7AR  0135  BA
# 7AG  0250  BA
# 7CS  0041  BA
# 7ARG 0048  RN
# 7-FZB-821-CE
# 7-FZB-820-CE
# 7-ET-1423-RN
# 7-FZB-865-CE
# 7-FZB-859-CE
# 7-SCR-142D-RN
# 7-SCR-149D-RN
# 7-DJ-887D-BA
# 7-TQ-224D-BA
# 7-CL-90D-SE
# 7-LAR-17-RN
# 7-FP-458-RN
# 7-SCR-158D-RN
# 7-MAG-106D-RN
# 7-ET-1811-RN
# 7-ARG-823D-RN
# 7-ARG-829D-RN
# 7-CAM-1477D-RN
# 7-ET-1345-RN
# 7-ARG-825D-RN
# 7-PC-44D-RN
# 7-ET-1770-RN
# 7-ET-1760-RN
# 7-ET-1378D-RN
# 7-FP-481-RN
# 7ET  0350  RN
# 7-RP-176-RN
# 7ET  0766H RN
# 7AP  0163D RN
# 7ET  0157  RN
# 7-CL-89D-SE
# 7-CL-82D-SE
# 7-CNC-38-ES
# 7-SCR-141D-RN
# 7-FP-432D-RN
# 7-ET-1455D-RN
# 7-FSR-67-ES
# 7-FZB-999-CE
# 7-ET-1802-RN
# 7-ET-1526D-RN
# 7-FZB-933-CE
# 7-ET-1460-RN
# 7-ARG-834-RN
# 7-ARG-816-RN
# 7-ARG-814D-RN
# 7-ARG-813-RN
# 7-ET-1381D-RN
# 7-FZB-998-CE
# 7MRL 0008D RJS
# 7CN  0014D RN
# 7CJ  0008  RN
# 7FZB 0489  CE
# 7CP  1328  SE
# 7FZB 0457  CE
# 7TQ  0032  BA
# 7-DJ-889D-BA
# 7-DJ-891D-BA
# 7-FMQ-33-RN
# 7-SCR-126D-RN
# 7-SCR-146D-RN
# 7-FZB-824-CE
# 7-ET-1363-RN
# 7-BR-69DA-RJS
# 7-FZB-912-CE
# 7-ET-1448D-RN
# 7-ET-1447-RN
# 7-MAG-104D-RN
# 7-FP-468-RN
# 7-FAL-122D-ES
# 7-MLS-225D-RJS
# 7-FP-435D-RN
# 7-SCR-155D-RN
# 7-SCR-163D-RN
# 7-CAM-1485-RN
# 7-FZB-939-CE
# 7-CLD-20-RN
# 7-CLD-22-RN
# 7VRG 0005D RN
# 7-ET-895-RN
# 7-ARG-635-RN
# 7-MRL-187HPA-RJS
# 7-CP-1778-SE
# 7CP  0612  SE
# 7FZB 0068  CE
# 7CM  0041D SES
# 7-TQ-225D-BA
# 7-ET-1445D-RN
# 7-SCR-143D-RN
# 7-FSR-61-ES
# 7-CS-236D-BA
# 7-ARG-792D-RN
# 7-CNC-26-ES
# 7-CNC-33-ES
# 7-CLD-23-RN
# 7-FZB-994-CE
# 7-ET-1348D-RN
# 7-ARG-807D-RN
# 7-FP-469-RN
# 7-FZB-975-CE
# 7-CAM-1456-RN
# 7-ARG-827-RN
# 7-LL-61-RJS
# 7-LL-73D-RJS
# 7-ARG-821-RN
# 7-FP-472-RN
# 7FZB 0385  CE
# 7FP  0109  RN
# 7ARG 0235  RN
# 7CAM 0434  RN
# 7-AB-64HA-RJS
# 7C   0173D BA
# 7-MP-53D-BA
# 7-RO-156D-RJS
# 7-CL-69D-SE
# 7-FZB-861-CE
# 7-ET-1140-RN
# 7-LL-45D-RJS
# 7-SCR-148-RN
# 7-CP-1929D-SE
# 7-CAM-1502-RN
# 7-FZB-832-CE
# 7-FZB-993-CE
# 7-FP-457-RN
# 7-ARG-800-RN
# 7-ET-1789-RN
# 7-CAM-1370D-RN
# 7-ARG-826D-RN
# 7-MLS-223HA-RJS
# 7-CAM-1504-RN
# 7FP  0217  RN
# 7-CAM-1046-RN
# 7-CAM-1156-RN
# 7-MAG-56-RN
# 7-FZB-758-CE
# 7-RO-548-SE
# 7-ET-979-RN
# 7-CP-1608-SE
# 7-MG-60-SE
# 7-ET-996-RN
# 7-SZ-491D-SE
# 7-CP-1674D-SE
# 7-CAM-1210-RN
# 7-PTR-1-RN
# 7-ET-1513-RN
# 7-AR-303D-BA
# 7-ARG-550-RN
# 7-ARG-561-RN
# 7-ARG-564-RN
# 7AR  0212  BA
# 7FP  0073A RN
# 7LP  0053  ES
# 7SE  0041  RN
# 7-FP-463-RN
# 7CP  0343  SE
# 7-ARG-811D-RN
# 7-FP-484-RN
# 7-FZB-946-CE
# 7-SCR-164D-RN
# 7-CL-59D-SE
# 7-CAM-1503-RN
# 7-FZB-850-CE
# 7-ARG-802-RN
# 7-APR-13D-BA
# 7-POL-4HP-RJS
# 7-CAM-1190D-RN
# 7-RO-528-SE
# 7-ET-1533D-RN
# 7-ET-1521D-RN
# 7-ET-1534-RN
# 7-SCR-124D-RN
# 7-FP-462-RN
# 7-CAM-863-RN
# 7-SZ-607D-SE
# 7-SZ-615D-SE
# 7-PC-23D-RN
# 7-ET-1797-RN
# 7-ET-1808-RN
# 7-ET-1796-RN
# 7-BA-457D-BA
# 7GP  0012D RJS
# 7-MAG-97D-RN
# 7-FP-442D-RN
# 7-FP-439-RN
# 7-MLS-222HP-RJS
# 7-SCR-153D-RN
# 7-AG-437D-BA
# 7-ET-1128-RN
# 7-ET-1815D-RN
# 7-ET-1816-RN
# 7-CAM-1280-RN
# 7-ET-1801D-RN
# 7-ARG-833-RN
# 7GP  0007  RJS
# 7CP  0736  SE
# 7ET  0116  RN
# 7ARG 0093  RN
# 7ARG 0179  RN
# 7GMR 0049  RN
# 7-CAM-992-RN
# 7-IBU-5-ES
# 7-CP-1500D-SE
# 7-AR-311D-BA
# 7FBM 0173  BA
# 7AR  0207  BA
# 7BA  0292  BA
# 7-AR-293-BA
# 7-ARG-779D-RN
# 7-ET-1434D-RN
# 7-ET-1080D-RN
# 7-ARG-748-RN
# 7PL  0032  RN
# 7ET  0335  RN
# 7AP  0127  RN
# 7CAM 0195  RN
# 7-ET-1356D-RN
# 7-ET-1132-RN
# 7-ET-1449-RN
# 7-RO-147D-RJS
# 7-SA-43DB-BA
# 7-ET-1419D-RN
# 7-CP-1522-SE
# 7-FZB-954-CE
# 7-FP-444-RN
# 7-ARG-840D-RN
# 7-FMQ-49-RN
# 7-SZ-606D-SE
# 7-RO-153H-RJS
# 7-CAM-1468D-RN
# 7-FZB-762-CE
# 7-FP-360-RN
# 7-CP-1728D-SE
# 7-CAM-1018-RN
# 7-JND-37D-BA
# 7-ARG-773-RN
# 7-FZB-790-CE
# 7-ET-1463D-RN
# 7-ET-1360D-RN
# 7-SCR-162D-RN
# 7-SZ-649D-SE
# 7-SZ-648D-SE
# 7-ET-1512-RN
# 7-FZB-915-CE
# 7MG  0251  BA
# 7FZB 0269  CE
# 7FZB 0273A CE
# 7CP  0711  SE
# 7FZB 0292  CE
# 7-ARG-806-RN
# 7-FZB-886-CE
# 7-ET-1380D-RN
# 7-ET-1365D-RN
# 7-FZB-943-CE
# 7-CAM-1457-RN
# 7-ARG-789D-RN
# 7-RO-617D-SE
# 7ML  0016  BA
# 7-AB-103HP-RJS
# 7LOR 0034  RN
# 7-BR-67HP-RJS
# 7-FZB-1002-CE
# 7CP  0135  SE
# 7UB  0109D RNS
# 7VM  0015D RJS
# 7-SCR-157-RN
# 7-ET-1497D-RN
# 7-ET-1130-RN
# 7-SZ-515-SE
# 7-SCR-140D-RN
# 7-FMQ-45-RN
# 7-ET-1212D-RN
# 7-FZB-1010-CE
# 7-FZB-924-CE
# 7-ET-1333-RN
# 7-ET-1136-RN
# 7-IC-11-CE
# 7-MG-500D-BA
# 7LS  0023  ES
# 7RCB 0035  BA
# 7-FZB-733-CE
# 7-BA-419D-BA
# 7-FP-467D-RN
# 7-ET-1483D-RN
# 7-FP-473D-RN
# 7-RE-53-RN
# 7-MAG-105-RN
# 7-CAM-1061-RN
# 7-SCR-86D-RN
# 7-CAM-1063-RN
# 7-SCR-73D-RN
# 7-ET-952-RN
# 7-CP-1682-SE
# 7-CAM-1082-RN
# 7-CAM-1180D-RN
# 7RS  0021  BA
# 7FZB 0356  CE
# 7CP  0990  SE
# 7MG  0123  BA
# 7-SZ-410-SE
# 7-SZ-423DP-SE
# 7-RCB-78D-BA
# 7-PTS-5-RN
# 7-CAM-1038-RN
# 7-CAM-1146-RN
# 7-CP-1748D-SE
# 7-CP-1749D-SE
# 7-ET-985-RN
# 7-CP-1649-SE
# 7-FZB-737-CE
# 7-ET-1007-RN
# 7-CAM-1193-RN
# 7-FBE-51D-BA
# 7CM  0029D SES
# 7-ARG-781D-RN
# 7-ET-1379D-RN
# 7-ET-1508-RN
# 7-PM-55DP-RJS
# 7-ET-1510-RN
# 7CP  0028  SE
# 7GO  0012  BA
# 7-ET-1074D-RN
# 7-CP-1841D-SE
# 7-CAM-1255D-RN
# 7-MAG-88-RN
# 7-CP-1762-SE
# 7-FMQ-37-RN
# 7-FI-111D-BA
# 7-BAL-74-RN
# 7-MAG-73-RN
# 7-ARG-746-RN
# 7-CAM-1111D-RN
# 7ARG 0094  RN
# 7ET  0082  RN
# 7CP  0722  SE
# 7-ET-1204-RN
# 7-AR-338D-BA
# 7-SCR-118D-RN
# 7-ET-1347-RN
# 7-MO-87D-RN
# 7-GC-11-RN
# 7-ET-1406D-RN
# 7-ARG-735-RN
# 7-CAM-1275-RN
# 7-C-226D-BA
# 7-ML-41D-BA
# 7BR  0008  RN
# 7-CAM-1132D-RN
# 7-CAM-1299-RN
# 7-GLF-27HA-ESS
# 7ET  0222  RN
# 7FP  0153  RN
# 7CP  0399  SE
# 7RO  0095  SE
# 7-ET-1173D-RN
# 7-SCR-131D-RN
# 7-CP-1566D-SE
# 7-FZB-895-CE
# 7-AG-429D-BA
# 7-SZ-604D-SE
# 7-FZB-858-CE
# 7-ET-1205D-RN
# 7-ET-1349-RN
# 7-RO-544-SE
# 7-ET-1010-RN
# 7-SCR-93-RN
# 7-PV-8-RN
# 7-CAM-1099D-RN
# 7-ET-1477-RN
# 7-ET-1471-RN
# 7ROV 0014  BA
# 7FZB 0232  CE
# 7FU  0113D AL
# 7-ET-1285-RN
# 7-ET-1116-RN
# 7-BFR-7-ESS
# 7-ET-1344D-RN
# 7-CAM-1330-RN
# 7-ARG-756-RN
# 7ET  0714  RN
# 7-RO-568-SE
# 7-AG-420D-BA
# 7FZB 0455  CE
# 7-ET-1027-RN
# 7-FP-431D-RN
# 7-CAM-1009-RN
# 7-FZB-730-CE
# 7RI  0026  ES
# 7-ARG-751-RN
# 7VM  0058D RJS
# 7ET  0344  RN
# 7MG  0104  BA
# 7-RP-167-RN
# 7CP  1315D SE
# 7BAL 0033  RN
# 7-CP-1782-SE
# 7PJ  0017  RN
# 7-CAM-1342-RN
# 7ARG 0011  RN
# 7-ET-1141-RN
# 7RP  0102  RN
# 7-CAM-1366D-RN
# 7-GMR-98-RN
# 7-GMR-99-RN
# 7-GMR-97-RN
# 7-ET-1500D-RN
# 7-GMR-102-RN
# 7-FP-443D-RN
# 7-ARG-796D-RN
# 7-PTR-4-RN
# 7-FZB-926-CE
# 7-FZB-930-CE
# 7-MLL-59DB-RJS
# 7-ET-1818-RN
# 7-CAM-1510-RN
# 7-CAM-1404-RN
# 7-LAR-16-RN
# 7-LAR-15-RN
# 7EN  0006  RJS
# 7CO  0003D RJS
# 7ARG 0045  RN
# 7ARG 0215  RN
# 7ET  0120  RN
# 7ARG 0015  RN
# 7-TQ-219D-BA
# 7-CAM-1343-RN
# 7-MLS-163HP-RJS
# 7-FZB-784-CE
# 7-AR-326D-BA
# 7-ARG-572-RN
# 7-CP-1663D-SE
# 7SZ  0277  SE
# 7MJ  0007  BA
# 7CP  0734  SE
# 7TQ  0144  BA
# 7CRP 0036D RJS
# 7ET  0378  RN
# 7FU  0104  AL
# 7-ET-1387D-RN
# 7-RE-42-RN
# 7-ET-1435-RN
# 7-SZ-639D-SE
# 7-ET-1451-RN
# 7-ET-1439D-RN
# 7RFQ 0017D RN
# 7PG  0024D RJS
# 7-CP-1785-SE
# 7-MAG-57-RN
# 7-TQ-190D-BA
# 7-CP-1576-SE
# 7-FZB-875-CE
# 7-FZB-937-CE
# 7-FZB-893-CE
# 7-ARG-605-RN
# 7CP  0024  SE
# 7RO  0199  SE
# 7TQ  0115  BA
# 7-ET-1799D-RN
# 7-ET-1469D-RN
# 7-ET-1814D-RN
# 7-ET-1803D-RN
# 7-ET-1790D-RN
# 7-FZB-873-CE
# 7-AB-130HP-RJS
# 7-ET-1550-RN
# ...
# 7ARG 0480  RN
# 7ET  0650H RN
# 7-ET-792-RN
# 7-RP-169-RN
# 7-CAM-789-RN
# 7-FP-247-RN
# 7BVS 0021  RN
# 7ET  0739H RN
# 7ET  0740H RN
# 7BE  0002  RN
# 7MA  0016D RJS
# 7-RO-494-SE
# 7-CAM-915-RN
# 7ARG 0479  RN
# 7-MRL-129HPA-RJS
# 7-PJ-29-RN
# 7-SMI-19-RN
# 7-RP-179-RN
# 7AP  0251  RN
# 7RP  0116  RN
# 7RP  0117  RN
# 7REP 0041  RN
# 7RP  0118  RN
# 7REP 0044  RN
# 7SZ  0367  SE
# 7BVS 0011  RN
# 7RP  0142  RN
# 7MAG 0021  RN
# 7-RO-466D-SE
# 7-RO-462D-SE
# 7-FZB-651-CE
# 7MRL 0112H RJS
# 7RP  0126  RN
# 7RP  0127  RN
# 7RP  0129  RN
# 7ET  0699  RN
# 7CAM 0691  RN
# 7ET  0679  RN
# 7MGP 0032D BA
# 7AP  0280  RN
# 7AP  0279  RN
# 7GA  0058D SES
# 7ET  0748  RN
# 7BVS 0012  RN
# 7MRL 0053D RJS
# 7VR  0012  RN
# 7FZB 0570  CE
# 7FZB 0562D CE
# 7FZB 0564D CE
# 7FZB 0563D CE
# 7ET  0656  RN
# 7ET  0657  RN
# 7CAM 0685  RN
# 7REP 0031  RN
# 7FZB 0576D CE
# 7FZB 0574D CE
# 7FZB 0577D CE
# 7VR  0016  RN
# 7MRL 0104D RJS
# 7BA  0385D BA
# 7RO  0014  RJS
# 7C   0224DPBA
# 7LPX 0007  RN
# 7CAM 0764  RN
# 7PIR 0157D AL
# 7-SMI-16-RN
# 7ET  0645  RN
# 7FZB 0529  CE
# 7ET  0646  RN
# 7FZB 0530  CE
# 7FZB 0531  CE
# 7FZB 0523  CE
# 7ET  0658  RN
# 7MRL 0043D RJS
# 7CN  0052D RN
# 7CN  0056D RN
# 7FZB 0575D CE
# 7FZB 0584D CE
# 7FZB 0587D CE
# 7FZB 0579D CE
# 7FZB 0585D CE
# 7PJ  0022  RN
# 7-OUB-1A-RNS
# 7-BRG-35-SE
# 7-CP-1472D-SE
# 7-CP-1481D-SE
# 7-ARG-649-RN
# 7-SMI-20-RN
# 7-ARG-514-RN
# 7-BAL-41-RN
# 7-FSR-29D-ES
# 7-PJ-41-RN
# 7-ET-865-RN
# 7-DJ-785H-BA
# 7-CP-1534-SE
# 7-ARG-606-RN
# 7-ARG-604-RN
# 7-RBU-89D-BA
# 7-RO-486D-SE
# 7-MA-22HP-ES
# 7ARG 0505  RN
# 7ARG 0495  RN
# 7ARG 0504  RN
# 7-MLS-10HPB-RJS
# 7-ARG-582-RN
# 7-ARG-587-RN
# 7-ARG-586-RN
# 7-ARG-585-RN
# 7-MG-35-SE
# 7-SZ-432-SE
# 7MRL 0102H RJS
# 7MRL 0103  RJS
# 7FP  0210  RN
# 7FAL 0005D ES
# 7-ET-790-RN
# 7CAM 0718  RN
# 7CAM 0719  RN
# 7CAM 0727  RN
# 7CAM 0726  RN
# 7-FAL-44H-ES
# 7-FBM-220D-BA
# 7-DO-26DP-SES
# 7-CAM-857-RN
# 7-CAM-860-RN
# 7-FZB-657-CE
# 7PJ  0024  RN
# 7-FAL-6HP-ES
# 7-FZB-661-CE
# 7-FZB-662-CE
# 7-FZB-655-CE
# 7-CP-1461-SE
# 7-CAM-785-RN
# 7-FP-242-RN
# 7-FAL-13H-ES
# 7-FAL-87H-ES
# 7-SA-5HP-RJS
# 7-BR-27HP-RJS
# 7-PJ-32-RN
# 7-FAL-18H-ES
# 7-RP-165-RN
# 7-SMI-17-RN
# 7-ET-795-RN
# 7-CP-1443-SE
# 7-BAL-47-RN
# 7-BAL-48-RN
# 7-LOR-49-RN
# 7-CAM-868-RN
# 7-RP-175-RN
# 7-CAM-796-RN
# 7-RP-170-RN
# 7-PJ-27-RN
# 7-RP-172-RN
# 7-LOR-48-RN
# 7-LV-46D-RN
# 7PJ  0020  RN
# 7PL  0066  RN
# 7PL  0067  RN
# 7LPX 0003  RN
# 7CAM 0744  RN
# 7-FZB-611-CE
# 7-CP-1478-SE
# 7-SZ-454-SE
# 7-ET-921-RN
# 7-ET-920-RN
# 7-FP-239-RN
# 7-AP-292-RN
# 7-MAG-27-RN
# 7-LV-43-RN
# 7-BAL-39-RN
# 7-CAM-861-RN
# 7-FZB-746-CE
# 7-FZB-745-CE
# 7-ARG-651-RN
# 7-CP-1559-SE
# 7-ARG-667-RN
# 7-RP-171-RN
# 7-LOR-39-RN
# 7-RO-464-SE
# 7-BA-403D-BA
# 7-FC-12-RN
# 7-RPS-11HC-ES
# 7-CD-2HA-ES
# 7-CAM-916-RN
# 7-ARG-592-RN
# 7-ARG-593-RN
# 7-RO-26H-RJS
# 7-CCN-4H-ES
# 7-REP-71D-RN
# 7-ET-773-RN
# 7-PJ-30-RN
# 7LPX 0004  RN
# 7-RP-181-RN
# 7-PJ-31-RN
# 7-AG-373D-BA
# 7-RO-24D-RJS
# 7-FZB-658-CE
# 7-CAM-866-RN
# 7-CAM-867-RN
# 7-CAM-869-RN
# 7-CAM-965-RN
# 7-RO-501D-SE
# 7-BE-18-RN
# 7-JUB-6HB-ESS
# 7BVS 0031  RN
# 7BVS 0037  RN
# 7BVS 0035  RN
# 7BVS 0036  RN
# 7-CP-1464-SE
# 7-PM-40DP-RJS
# 7-FBM-221D-BA
# 7-CP-1457D-SE
# 7-RO-25D-RJS
# 7ET  0762  RN
# 7ET  0761  RN
# 7ET  0764  RN
# 7FP  0197  RN
# 7CAM 0723  RN
# 7-ARG-641-RN
# 7-ABL-68HP-RJS
# 7-BE-22-RN
# 7-FZB-715-CE
# 7-CM-97HP-SES
# 7BA  0382D BA
# 7BA  0386D BA
# 7MRL 0118H RJS
# 7PIR 0153D AL
# 7BA  0377D BA
# 7-BR-53-RN
# 7-BR-54-RN
# 7-ET-867-RN
# 7-ET-941-RN
# 7-CAM-1044D-RN
# 7-BEN-26-RN
# 7BR  0038  RN
# 7PIR 0154D AL
# 7-RP-182-RN
# 7-RP-180-RN
# 7REP 0063  RN
# 7-AP-293-RN
# 7-FAL-11H-ES
# 7-JND-27D-BA
# 7-FP-370-RN
# 7-ET-944-RN
# 7-FZB-744-CE
# 7-FZB-756-CE
# 7-FZB-750-CE
# 7-FSJ-40HP-ES
# 7-ET-849-RN
# 7-ET-852-RN
# 7BVS 0047  RN
# 7FZB 0596  CE
# 7FZB 0595  CE
# 7-AP-295-RN
# 7-MAG-29-RN
# 7FZB 0597  CE
# 7-AP-294-RN
# 7-FAL-29HA-ES
# 7-FP-296-RN
# 7-FP-295-RN
# 7-FP-299-RN
# 7-ET-854-RN
# 7-ET-860-RN
# 7-ET-862-RN
# 7-ET-863-RN
# 7-CAM-905-RN
# 7ARG 0507  RN
# 7ARG 0506  RN
# 7-MLS-16HPB-RJS
# 7RO  0012D RJS
# 7CAM 0739  RN
# 7CAM 0743  RN
# 7-RBU-92D-BA
# 7-FZB-705-CE
# 7-FZB-707-CE
# 7-CAM-1004-RN
# 7-CAM-1008-RN
# 7-CP-1624D-SE
# 7-ARG-645-RN
# 7-FZB-704-CE
# 7-FBM-228D-BA
# 7-FZB-666-CE
# 7-CAM-782-RN
# 7-ARG-594-RN
# 7-ARG-595-RN
# 7-ARG-596-RN
# 7-ARG-597-RN
# 7-ARG-598-RN
# 7-ARG-599-RN
# 7-FP-300-RN
# 7-CAM-892-RN
# 7-JUB-2HPA-ESS
# 7-FP-318-RN
# 7-ARG-701-RN
# 7-CAM-1258-RN
# 7-CAM-1035-RN
# 7-ARG-662-RN
# 7-ARG-660-RN
# 7-ARG-659-RN
# 7-RO-50HPA-RJS
# 7-AG-389D-BA
# 7-BA-415D-BA
# 7-ET-892-RN
# 7-AR-301D-BA
# 7-RI-43D-BA
# 7-JND-13D-BA
# 7-ET-922-RN
# 7-JND-17D-BA
# 7-FBM-235-BA
# 7-RO-443D-SE
# 7-CIO-3HP-RNS
# 7-SZ-452DP-SE
# 7-CP-1527D-SE
# 7-MP-22-BA
# 7-MLS-95H-RJS
# 7-CP-1475D-SE
# 7-FZB-721-CE
# 7-FBE-43D-BA
# 7-FZB-725-CE
# 7-FZB-740-CE
# 7-CP-1779D-SE
# 7-CAM-999-RN
# 7-ARG-692-RN
# 7-ET-1014-RN
# 7-MG-496-BA
# 7-FP-284-RN
# 7-FP-285-RN
# 7-MAG-44-RN
# 7-MOR-16-RN
# 7-SZ-419-SE
# 7-FZB-716-CE
# 7-ARG-647-RN
# 7-ARG-648-RN
# 7-ARG-650-RN
# 7-CP-1550D-SE
# 7-CP-1547D-SE
# 7-FZB-686-CE
# 7-ARG-554-RN
# 7-ARG-555-RN
# 7-ARG-552-RN
# 7-ARG-551-RN
# 7-CL-44-SE
# 7-FP-314-RN
# 7-FP-315-RN
# 7-RFQ-38D-RN
# 7-JND-22D-BA
# 7-JND-23D-BA
# 7-JND-3D-BA
# 7-MP-31D-BA
# 7-OST-6H-ESS
# 7-CAM-1298-RN
# 7-CP-1792D-SE
# 7-SZ-485D-SE
# 7-DJ-821-BA
# 7-POL-16H-RJS
# 7-FZB-731-CE
# 7-FZB-729-CE
# 7-AG-402D-BA
# 7-FZB-722-CE
# 7-ARG-670-RN
# 7-FZB-667-CE
# 7-FZB-672-CE
# 7-REP-74-RN
# 7-REP-73-RN
# 7-LOR-55-RN
# 7-ABL-71HP-RJS
# 7-PJ-43-RN
# 7-PJ-44-RN
# 7-PJ-45-RN
# 7-RO-489D-SE
# 7-ARG-583-RN
# 7-ABL-20HP-RJS
# 7-MLL-10HP-RJS
# 7-BA-410-BA
# 7-ARG-577-RN
# 7-ARG-578-RN
# 7-CAM-968-RN
# 7-SCR-63-RN
# 7-RO-507-SE
# 7-ARG-640-RN
# 7-ARG-638-RN
# 7-CAM-970D-RN
# 7-ET-869-RN
# 7-SZ-440D-SE
# 7-FP-310A-RN
# 7-ET-891-RN
# 7-CAM-888-RN
# 7-RO-42HPB-RJS
# 7-ET-890-RN
# 7-ET-894-RN
# 7-ET-896-RN
# 7-ET-899-RN
# 7-FBM-232D-BA
# 7-ABL-13HP-RJS
# 7-GMR-69-RN
# 7-AR-307H-BA
# 7-CP-1540D-SE
# 7-CP-1558-SE
# 7-FP-346-RN
# 7-BAL-52-RN
# 7-FZB-692-CE
# 7-FZB-691-CE
# 7-JND-10D-BA
# 7-CAM-899-RN
# 7-CAM-901-RN
# 7-ARG-589-RN
# 7-FZB-717-CE
# 7-CP-1473-SE
# 7-CP-1474-SE
# 7-SZ-447D-SE
# 7-RPS-13HA-ES
# 7-ARG-581-RN
# 7-ARG-549-RN
# 7-LOR-52-RN
# 7-LOR-53-RN
# 7-MAG-52-RN
# 7-MAG-47-RN
# 7-MAG-48-RN
# 7-MAG-51-RN
# 7-MAG-49-RN
# 7-ARG-602-RN
# 7-ARG-603-RN
# 7-CL-51HP-SE
# 7-CL-52HP-SE
# 7-CR-28HP-CES
# 7-RO-485D-SE
# 7-FU-134D-AL
# 7-ARG-562-RN
# 7-FZB-699-CE
# 7-FZB-698-CE
# 7-FZB-670-CE
# 7-RO-448-SE
# 7-RO-474-SE
# 7-BA-401D-BA
# 7-CP-1536D-SE
# 7-CP-1537-SE
# 7-ANB-3-AL
# 7-FMQ-31-RN
# 7-CP-1597-SE
# 7-CAM-1001-RN
# 7-BA-416-BA
# 7-ARG-560-RN
# 7-ARG-559-RN
# 7-ARG-558-RN
# 7-ARG-557-RN
# 7-MG-28D-SE
# 7-RFQ-36D-RN
# 7-CAM-948-RN
# 7-MRL-171HP-RJS
# 7-CAM-909-RN
# 7-ARG-600-RN
# 7-ARG-601-RN
# 7-FSJ-43HA-ES
# 7-FZB-682-CE
# 7-FP-343-RN
# 7-RFQ-39D-RN
# 7-ET-874-RN
# 7-CAM-1002-RN
# 7-CAM-990-RN
# 7-FP-358-RN
# 7-FP-359-RN
# 7-ET-885-RN
# 7-ET-886-RN
# 7-ET-887-RN
# 7-ET-889-RN
# 7-MG-29D-SE
# 7-CP-1488-SE
# 7-MLS-45HP-RJS
# 7-GLF-8H-ESS
# 7-ARG-639-RN
# 7-FP-332-RN
# 7-FP-333-RN
# 7-SE-56-RN
# 7-CP-1531D-SE
# 7-CP-1532D-SE
# 7-ARG-609-RN
# 7-ARG-611-RN
# 7-FP-287-RN
# 7-FP-305-RN
# 7-FP-306-RN
# 7-CP-1533-SE
# 7-ARG-590-RN
# 7-LOR-54-RN
# 7-POL-1H-RJS
# 7-ABL-60HP-RJS
# 7-RO-60HP-RJS
# 7-CP-1497D-SE
# 7-CAM-967D-RN
# 7-RO-502-SE
# 7-CP-1507D-SE
# 7-MLS-51HP-RJS
# 7-SER-14D-RNS
# 7-CAM-908-RN
# 7-CAM-960-RN
# 7-CAM-963-RN
# 7-SMI-28-RN
# 7-ABL-16HP-RJS
# 7-FP-282-RN
# 7-FP-309-RN
# 7-FP-311-RN
# 7-SZ-426-SE
# 7-CAM-944-RN
# 7-ARG-612-RN
# 7-LPX-14-RN
# 7-FP-290-RN
# 7-FP-292-RN
# 7-CAM-979-RN
# 7-CAM-980-RN
# 7-FZB-720-CE
# 7-CAM-1016-RN
# 7-CAM-1000-RN
# 7-CAM-1013-RN
# 7-SCR-74D-RN
# 7-CAM-978-RN
# 7-PTS-2-RN
# 7-SCR-75D-RN
# 7-FP-316-RN
# 7-CAM-945-RN
# 7-BA-404D-BA
# 7-FZB-656-CE
# 7-MG-42-SE
# 7-AR-306-BA
# 7-RO-493D-SE
# 7-CP-1526D-SE
# 7-FP-291A-RN
# 7-FP-294-RN
# 7-BA-406D-BA
# 7-ARG-566-RN
# 7-CP-1493-SE
# 7-CP-1545D-SE
# 7-CAM-925-RN
# 7-MG-54-SE
# 7-FP-339-RN
# 7-BE-23-RN
# 7-MAG-55-RN
# 7-FP-351-RN
# 7-ET-876-RN
# 7-ET-878-RN
# 7-CAM-962-RN
# 7-ARG-642-RN
# 7-CAM-974-RN
# 7-FP-335-RN
# 7-AG-18D-SE
# 7-RFQ-35D-RN
# 7-RPS-14-ES
# 7-ARG-567-RN
# 7-ARG-568-RN
# 7-ARG-569-RN
# 7-SER-19D-RNS
# 7-CAM-879-RN
# 7-CAM-877-RN
# 7-SA-3HPA-RJS
# 7-FP-312-RN
# 7-CP-1556D-SE
# 7-CAM-1055-RN
# 7-CAM-1052-RN
# 7-SZ-474D-SE
# 7-CAM-1024-RN
# 7-FZB-710-CE
# 7-FP-354-RN
# 7-FZB-711-CE
# 7-MG-38-SE
# 7-FP-330D-RN
# 7-CAM-959D-RN
# 7-CAM-921-RN
# 7-ARG-636-RN
# 7-ABL-44HP-RJS
# 7-ABL-46HPA-RJS
# 7-ARG-613-RN
# 7-ARG-614-RN
# 7-CP-1539-SE
# 7-BE-13-RN
# 7-RO-514D-SE
# 7-CP-1776D-SE
# 7-MAG-62-RN
# 7-MG-65-SE
# 7-MG-58-SE
# 7-AG-407D-BA
# 7-AB-99HP-RJS
# 7-FP-365-RN
# 7-MP-39D-BA
# 7-FZB-671-CE
# 7-BA-402D-BA
# 7-CAM-880-RN
# 7-BR-52-RN
# 7-FBE-44D-BA
# 7-MLS-79HP-RJS
# 7-FZB-678-CE
# 7-FZB-679-CE
# 7-ET-883-RN
# 7-ARG-624-RN
# 7-CP-1710D-SE
# 7-FZB-723-CE
# 7-ET-959-RN
# 7-ET-957-RN
# 7-IBU-7-ES
# 7-CAM-1222-RN
# 7-CAM-1235-RN
# 7-CAM-1233-RN
# 7-MP-38D-BA
# 7-FP-352-RN
# 7-CAM-1034D-RN
# 7-CAM-1036-RN
# 7-CAM-1041-RN
# 7-AR-299D-BA
# 7-CAM-913-RN
# 7-CAM-918-RN
# 7-RBU-91D-BA
# 7-CP-1538D-SE
# 7-CP-1496D-SE
# 7-FP-302-RN
# 7-ET-843-RN
# 7-ET-844-RN
# 7-ET-850-RN
# 7-SE-54-RN
# 7-FZB-719-CE
# 7-FZB-724-CE
# 7-BE-20-RN
# 7-FP-356-RN
# 7-CAM-977D-RN
# 7-SCR-70D-RN
# 7-JND-24D-BA
# 7-CAM-1011D-RN
# 7-CAM-1045D-RN
# 7-CAM-1049-RN
# 7-CAM-1204-RN
# 7-ARG-698-RN
# 7-ARG-700-RN
# 7-ARG-653-RN
# 7-RO-66D-RJS
# 7-MP-35D-BA
# 7-SZ-443-SE
# 8-RO-89HPA-RJS
# 8-MLS-65HP-RJS
# 8CH  0009D RJS
# 8LV  0040  RN
# 8SZ  0110  SE
# 8CP  0962  SE
# 8MRL 0057DARJS
# 8MLS 0006HPRJS
# 8-BR-61-RN
# 8-MLS-121HPA-RJS
# 8-CP-1616D-SE
# 8CP  0842  SE
# 8CP  0899  SE
# 8CH  0016D RJS
# 8RO  0384  SE
# 8-RO-607D-SE
# 8-RO-552D-SE
# 8-URG-22HPA-RJS
# 8-RO-152H-RJS
# 8-RO-137HP-RJS
# 8-SZ-585-SE
# 8-FBM-276D-BA
# 8-SZ-592-SE
# 8-SZ-586-SE
# 8-SZ-555D-SE
# 8-CS-228-BA
# 8-RO-119HP-RJS
# 8-FBM-274D-BA
# 8-RO-622-SE
# 8-SZ-553-SE
# 8-LL-24D-RJS
# 8-JUB-42DA-ESS
# 8CP  1267  SE
# 8-DJ-859-BA
# 8-RO-553-SE
# 8-SZ-564-SE
# 8-SZ-598-SE
# 8-RO-550D-SE
# 8-SZ-587-SE
# 8-SZ-530D-SE
# 8RO  0137  SE
# 8-JUB-46D-ESS
# 8-SZ-550-SE
# 8-JUB-30HA-ESS
# 8-BA-454D-BA
# 8-JUB-52H-ESS
# 8-RO-604-SE
# 8-RO-688-SE
# 8-RO-664-SE
# 8-CP-1567-SE
# 8-CP-1523-SE
# 8-MJ-84-BA
# 8-FI-120D-BA
# 8-DJ-877H-BA
# 8-BAN-3-SPS
# 8-URG-20H-RJS
# 8-MLL-68HP-RJS
# 8-LL-32D-RJS
# 8-MLS-193HPA-RJS
# 8-RO-670D-SE
# 8-SZ-601D-SE
# 8-RO-608D-SE
# 8-JUB-47D-ESS
# 8-SZ-548-SE
# 8RCB 0036  BA
# 8-CP-1560-SE
# 8-MRL-165HPA-RJS
# 8-LL-35D-RJS
# 8-RO-54HP-RJS
# 8-SZ-583D-SE
# 8-RO-146HP-RJS
# 8-MG-99-SE
# 8-PTS-13-RN
# 8-AB-112HP-RJS
# 8CP  0835  SE
# 8MRL 0041D RJS
# 8-ABL-52HPA-RJS
# 8-MLS-127HP-RJS
# 8RO  0421  SE
# 8CP  1232  SE
# 8RO  0346  SE
# 8-MLL-36H-RJS
# 8-BA-420D-BA
# 8CP  0954  SE
# 8RO  0363  SE
# 8CP  0834  SE
# 8FBM 0210D BA
# 8CAC 0019DPRN
# 8MRL 0045D RJS
# 8-AB-118HP-RJS
# 8-MLS-147HP-RJS
# 8CP  0795  SE
# 8MG  0246  BA
# 8-MLS-81HP-RJS
# 8FBM 0201  BA
# 8-MLL-35DB-RJS
# 8-DJ-836-BA
# 8-CAC-25D-RN
# 8-GLF-17HB-ESS
# 8-DJ-805D-BA
# 8-BA-423D-BA
# 8RO  0135  SE
# 8-RO-81HP-RJS
# 8-DJ-801-BA
# 8-BR-66-RN
# 8-BA-428-BA
# 8-RO-524-SE
# 8-DJ-796-BA
# 8-MLS-125HP-RJS
# 8-SZ-469D-SE
# 8-CER-28D-BA
# 8-AB-113HP-RJS
# 8-MRL-192D-RJS
# 8CP  0765  SE
# 8-BAL-49-RN
# 8SE  0050  RN
# 8-SZ-566-SE
# 8-RO-687D-SE
# 8-RO-91HP-RJS
# 8-MLL-18HP-RJS
# 8-AB-127D-RJS
# 8CAM 0712D RN
# 8-BR-64-RN
# 8CP  0440  SE
# 8CP  0452  SE
# 8CAM 0706D RN
# 8MRL 0093H RJS
# 8CAM 0700D RN
# 8RO  0403  SE
# 8-RO-94HP-RJS
# 8-JUB-29H-ESS
# 8-RO-128HP-RJS
# 8-LL-4D-RJS
# 8-SZ-552-SE
# 8RO  0347  SE
# 8-RO-665-SE
# 8FBM 0110  BA
# 8CH  0019D RJS
# 8-SZ-622D-SE
# 8-ABL-72H-RJS
# 8-RO-611-SE
# 8MG  0151  BA
# 8RO  0372  SE
# 8CP  0993  SE
# 8-PV-14-RN
# 8RO  0385  SE
# 8-MLS-185HP-RJS
# 8-SZ-623D-SE
# 8-MRL-132D-RJS
# 8CP  0826  SE
# 8CP  0828  SE
# 8-LL-56-RJS
# 8-SZ-582D-SE
# 8-JUB-28HA-ESS
# 8-JUB-35-ESS
# 8-SZ-563-SE
# 8-SZ-551-SE
# 8-BAZ-7-ESS
# 8-AB-124HP-RJS
# 8-MLS-181HPA-RJS
# 8-SZ-529D-SE
# 8CAM 0695D RN
# 8CP  0398  SE
# 8-SZ-624-SE
# 8-CP-1572-SE
# 8-SZ-546D-SE
# 8-JUB-23HB-ESS
# 8-DJ-852H-BA
# 8-AB-123HP-RJS
# 8-LL-9-RJS
# 8-RO-117HP-RJS
# 8ML  0024  BA
# 8AR  0145  BA
# 8MRL 0038H RJS
# 8TQIA0005  BA
# 8SZ  0159  SE
# 8CP  0789  SE
# 8MRL 0015D RJS
# 8-DJ-802-BA
# 8-LL-50-RJS
# 8CP  0449  SE
# 8TQIA0002  BA
# 8DJIA0006  BA
# 8CP  1115  SE
# 8RPJ 0036D BA
# 8MRL 0108HPRJS
# 8MRL 0120D RJS
# 8CP  1370D SE
# 8CAM 0669  RN
# 8RO  0396  SE
# 8NA  0018D RJS
# 8LV  0039  RN
# 8CP  0833  SE
# 8-BR-60-RN
# 8-FBM-268D-BA
# 8-FBM-261D-BA
# 8FU  0060  AL
# 8-SZ-526-SE
# 8-MLS-183HP-RJS
# 8-CHT-10HA-ESS
# 8-DJ-855HA-BA
# 8-BR-78HP-RJS
# 8-SZ-460D-SE
# 8-CP-1736D-SE
# 8-CP-1735-SE
# 8-FBE-58D-BA
# 8-MLS-161HP-RJS
# 8CP  0451  SE
# 8RO  0180  SE
# 8-BR-76HP-RJS
# 8-JUB-20H-ESS
# 8-MRL-211DA-RJS
# 8-RO-96HP-RJS
# 8-BA-448-BA
# 8-SZ-621-SE
# 8-JUB-25HA-ESS
# 8-CS-235-BA
# 8-MLS-171HPA-RJS
# 8SZ  0361  SE
# 8-CP-1734-SE
# 8-SZ-461D-SE
# 8-MLS-155HP-RJS
# 8-SZ-599D-SE
# 8-CP-1740D-SE
# 8-MLS-143H-RJS
# 8-JUB-50D-ESS
# 8-RO-606D-SE
# 8CAM 0699D RN
# 8-CS-231-BA
# 8-SZ-591-SE
# 8CP  0417  SE
# 8-MLS-204HP-RJS
# 8MRL 0090D RJS
# 8-LL-5-RJS
# 8CP  0830D SE
# 8-SZ-597D-SE
# 8-SPH-9-SPS
# 8-SZ-580D-SE
# 8MRL 0092H RJS
# 8-RO-706D-SE
# 8-LL-23-RJS
# 8RO  0417  SE
# 8CP  0441  SE
# 8CP  0805  SE
# 8-LL-88D-RJS
# 8-SZ-531D-SE
# 8-LL-55D-RJS
# 8RO  0394  SE
# 8-SZ-545D-SE
# 8SZ  0230  SE
# 8CP  1369D SE
# 8-LL-43D-RJS
# 8FBM 0202  BA
# 8MG  0141  BA
# 8-LL-49D-RJS
# 8-SPH-12DA-SPS
# 8-MRL-191DP-RJS
# 8CP  0799  SE
# 8-CS-232D-BA
# 8CP  0414  SE
# 8-CAM-1505-RN
# 8SZ  0232  SE
# 8CP  0888  SE
# 8-BA-426-BA
# 8RO  0138  SE
# 8-SZ-528-SE
# 8CP  0424  SE
# 8-LL-26D-RJS
# 8-SZ-556-SE
# 8-MLS-123HB-RJS
# 8-LL-78D-RJS
# 8-AR-358D-BA
# 8-LL-65D-RJS
# 8-CP-1795D-SE
# 8-SPH-13-SPS
# 8-SPH-10-SPS
# 8-MLS-191HPA-RJS
# 8DJIA0003  BA
# 8-SPH-21D-SPS
# 8-LL-57D-RJS
# 8-SPH-19D-SPS
# 8-RO-478-SE
# 8-RO-27HP-RJS
# 8-LL-39-RJS
# 8-BR-65HP-RJS
# 8-MLS-77H-RJS
# 8-RO-37-RJS
# 8-CS-214-BA
# 8-LL-86D-RJS
# 8RPJ 0034D BA
# 8MG  0192  BA
# 8BAIA0004  BA
# 8BAIA0007  BA
# 8CP  0182  SE
# 8BAIA0010  BA
# 8TQIA0006  BA
# 8BAIA0009  BA
# 8BA  0111  BA
# 8BAIA0003  BA
# 8CP  0371  SE
# 8RO  0154  SE
# 8SZ  0107  SE
# 8SZ  0109  SE
# 8BA  0162  BA
# 8ML  0022  BA
# 8CP  0402  SE
# 8MG  0167  BA
# 8RO  0181  SE
# 8AR  0098  BA
# 8RO  0161  SE
# 8SZ  0144  SE
# 8CP  0375  SE
# 8FI  0040  BA
# 8AR  0100  BA
# 8SZ  0154  SE
# 8MG  0173  BA
# 8SZ  0141  SE
# 8SZ  0099  SE
# 8RO  0106  SE
# 8CP  0390  SE
# 8CP  0385  SE
# 8AR  0093  BA
# 8SZ  0153  SE
# 8CP  0334  SE
# 8CP  0409  SE
# 8RO  0134  SE
# 8CP  0419  SE
# 8SZ  0147  SE
# 8SZ  0146  SE
# 8CP  0388  SE
# 8SZ  0151  SE
# 8SZ  0148  SE
# 8MG  0142  BA
# 8CP  0406  SE
# 8BA  0158  BA
# 8RO  0151  SE
# 8RO  0152  SE
# 8CP  0432  SE
# 8MJ  0052  BA
# 8CP  0360  SE
# 8RO  0140  SE
# 8RO  0141  SE
# 8CP  0428  SE
# 8BA  0156  BA
# 8RO  0158  SE
# 8SZ  0171  SE
# 8CP  0445  SE
# 8CP  0446  SE
# 8CP  0423  SE
# 8CP  0416  SE
# 8RO  0145  SE
# 8CP  0425  SE
# 8RO  0155  SE
# 8RO  0147  SE
# 8CP  0438  SE
# 8CP  0420  SE
# 8CP  0336  SE
# 8RO  0139  SE
# 8CP  0442  SE
# 8CP  0525  SE
# 8CP  0338  SE
# 8CP  0455  SE
# 8CP  0456D SE
# 8RO  0186  SE
# 8CP  0457  SE
# 8CP  0401  SE
# 8SZ  0182  SE
# 8RO  0108  SE
# 8CP  0380  SE
# 8CP  0381  SE
# 8RO  0133  SE
# 8CP  0517D SE
# 8RO  0104  SE
# 8CP  0533  SE
# 8CP  0393  SE
# 8CP  0450  SE
# 8SZ  0241  SE
# 8RO  0194  SE
# 8SZ  0213  SE
# 8DJ  0732  BA
# 8DJ  0726  BA
# 8RO  0294  SE
# 8RO  0321  SE
# 8TQ  0118  BA
# 8RO  0336  SE
# 8RO  0166  SE
# 8CP  0444  SE
# 8MG  0276  BA
# 8RO  0338  SE
# 8CP  0751  SE
# 8CP  0752  SE
# 8MG  0322  BA
# 8CP  0742  SE
# 8FI  0057  BA
# 8CP  0874  SE
# 8BA  0233  BA
# 8CP  0824  SE
# 8CP  0737  SE
# 8CP  0740  SE
# 8CP  0840D SE
# 8CP  0852  SE
# 8RO  0322  SE
# 8CP  0903  SE
# 8CP  0825  SE
# 8SZ  0242  SE
# 8GO  0019  BA
# 8RO  0334  SE
# 8CP  0757  SE
# 8RO  0335  SE
# 8CP  0829  SE
# 8FI  0058  BA
# 8NA  0020D RJS
# 8CP  0839  SE
# 8CP  0849  SE
# 8CP  0814B SE
# 8CP  0820  SE
# 8CP  0980  SE
# 8RO  0369  SE
# 8RO  0382  SE
# 8RO  0371  SE
# 8NA  0039D RJS
# 8CP  1019  SE
# 8RO  0404  SE
# 8CP  0956  SE
# 8CP  1027  SE
# 8CP  0965  SE
# 8RCB 0054  BA
# 8RO  0392  SE
# 8CP  0915  SE
# 8RO  0397  SE
# 8CP  0969  SE
# 8RCB 0053  BA
# 8CP  1088  SE
# 8CP  0858  SE
# 8CP  0804  SE
# 8CP  0782  SE
# 8NA  0027D RJS
# 8CP  1057D SE
# 8RCB 0034  BA
# 8FI  0060  BA
# 8CP  0784  SE
# 8RP  0032  ES
# 8SZ  0248  SE
# 8RO  0428D SE
# 8CP  1044  SE
# 8RCB 0058  BA
# 8FBM 0146  BA
# 8RO  0386  SE
# 8NA  0032D RJS
# 8NA  0033D RJS
# 8RO  0391  SE
# 8RO  0368  SE
# 8RO  0412  SE
# 8RO  0373  SE
# 8RO  0388  SE
# 8RO  0398  SE
# 8CP  1110  SE
# 8FBM 0161  BA
# 8NA  0023D RJS
# 8CP  1154  SE
# 8RPJ 0033  BA
# 8SZ  0358  SE
# 8RO  0431D SE
# 8RCB 0064  BA
# 8FBM 0113  BA
# 8CP  1275  SE
# 8CP  1339D SE
# 8CP  1008D SE
# 8RO  0406  SE
# 8RO  0411  SE
# 8RO  0416  SE
# 8FBM 0117  BA
# 8RO  0418  SE
# 8SE  0049  RN
# 8RBU 0081D BA
# 8CP  1340D SE
# 8UPN 0031  RN
# 8CP  1288  SE
# 8BAL 0029  RN
# 8SE  0052  RN
# 8RBU 0072D BA
# 8CP  1273  SE
# 8CP  1203D SE
# 8LV  0038  RN
# 8CP  1373D SE
# 8CP  1387D SE
# 8RO  0429  SE
# 8MRL 0031D RJS
# 8CAM 0711D RN
# 8MRL 0030D RJS
# 8SER 0005D RNS
# 8MRL 0036D RJS
# 8AP  0224D RN
# 8CAM 0698D RN
# 8CAM 0701D RN
# 8CAM 0673  RN
# 8BAL 0030  RN
# 8BR  0019DPRJS
# 8CAM 0534  RN
# 8CAM 0535  RN
# 8RBU 0086D BA
# 8CAM 0696  RN
# 8BR  0018D RJS
# 8SER 0006D RNS
# 8MA  0019D RJS
# 8MRL 0052D RJS
# 8SZ  0378D SE
# 8FAV 0120P BA
# 8CAM 0707  RN
# 8FMQ 0024  RN
# 8MRL 0105D RJS
# 8-FMQ-28-RN
# 8AP  0225  RN
# 8CAM 0694  RN
# 8MRL 0039  RJS
# 8SZ  0368  SE
# 8MRL 0095D RJS
# 8BR  0015HPRJS
# 8VR  0017  RN
# 8MA  0020DARJS
# 8MRL 0096D RJS
# 8MLS 0017HPRJS
# 8-VRG-7D-RN
# 8-RO-22D-RJS
# 8-ABL-36HP-RJS
# 8-DJ-795D-BA
# 8-MRL-181D-RJS
# 8-MLS-67HA-RJS
# 8-BR-47HP-RJS
# 8MRL 0097D RJS
# 8-MRL-161HP-RJS
# 8BR  0016WARJS
# 8-GLF-19HPA-ESS
# 8-RO-52HPA-RJS
# 8-AB-85HP-RJS
# 8-CP-1543D-SE
# 8-RO-65D-RJS
# 8-RO-479D-SE
# 8-MRL-175HP-RJS
# 8-MLS-133HPA-RJS
# 8-MLS-47HA-RJS
# 8-MLS-49HPA-RJS
# 8-ABL-26HP-RJS
# 8-ABL-48HP-RJS
# 8-RO-39D-RJS
# 8-CRT-38DP-RJS
# 8-ABL-38HA-RJS
# 8-RO-70HP-RJS
# 8-MLS-141HP-RJS
# 8-ABL-64HP-RJS
# 8-ABL-66HP-RJS
# 8-MLS-137HP-RJS
# 8-CRT-36HPA-RJS
# 8-JND-15D-BA
# 8-ABL-42HPA-RJS
# 8-JND-6D-BA
# 8-BAL-50-RN
# 8-ABL-22HPA-RJS
# 8-MLL-38HP-RJS

# %%
pai2 = pai

for index, row in pai2.iterrows():
    if row['POCO'].lower().replace(' ', '').replace('-', '') in top_10_well:
        print(row['POCO'])

# %%
add_pocos_mapa(
    m,
    pai2,
    'red'
)

# %%
m

# %% [markdown]
# ## Conclusion
#
# In this project, we:
#
# <ul>
# <li>Forecasted the temperature of a given city over a given period of time</li>
# <li>Predicted the top-10 cities in the US which will experience the most temperature change from 2013-2013.</li>
# <li>Analyzed the correlation between pollution levels and temperature, as well as the correlation between Greenhouse gas emissions and temperature, which helped us identify the Greenhouse Gas that has and will have the most impact on temperature change.</li>
# </ul>
